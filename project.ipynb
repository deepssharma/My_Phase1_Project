# %% [markdown]
# ### Final Project Submission

# %% [markdown]
# * Student name:                        Deepali Sharma
# * Student pace:                   Flex
# * Scheduled project review date/time:
# * Instructor name:                     Abhineet Kulkarni/Morgan Jones
# * Blog post URL:

# %% [markdown]
# ### Business Understanding

# %% [markdown]
# The goal of this Project is to make three recommendations/actionable insights for Microsoft that plans to get into the business of movie making. Based on our analysis we need to provide an input about the kind of movies that are profitable and are doing great.
#
# Using the data here which contains information about box earnings, movie names, genres, release time, runtimes, directors, average ratings etc, this analysis will make following recommendations:
# * Most profitable movie based on genre
# * Most profitable director
# * Most profitable time of year to release movies

# %% [markdown]
# ### Methodolgy

# %% [markdown]
# The project will take an in-depth look into the movie data and look/explore the various trends/correlations between different parameters such as **profit**, **average ratings**, **release time** and **popularity**.
# The main steps are highlighed below:
#
# * Import all the needed libraries to be able to read data and make visualizations
# * Clean up the data:
#     * remove duplicate entries,
#     * null entries,
#     * merge entries
#     * merge dataframes
#     * check again if the data looks reasonable after merging
#     * write some functions to convert the columns that are in dollars to convert to float values so that we can       manipulate it
#     * write functions to calculate mean, std values for different genres of movies
#     * write function to calculate quarterly profits
# * Create visulaizations:
#     * looked at means of average ratings for different genres
#     * compared the populartity, profits, average ratings for different genres
#     * look at most profitable movie from this data
#     * look at director vs profit
#     * look at average profit for different time periods of the year.

# %% [markdown]
# ### Final Recommendations

# %% [markdown]
# Based on the below analysis, I have found that sci-fi/animation movies are most profitable and popular movies. This can be seen from the plots that show average profit as a function of profit, and also the plot showing the most profitable movie, **Avatar followed by Averngers Infinity wars**, both of which belong to sci-fi and/pr anime category. **Russo brothers**, on average, are most profitable director duo, and movies released during summer months, **May to July** are on average are more pofitable.
#
# So I would suggest based on these findings to make a **sci-fi/anime movie with Russo brothers and release it during the months from May to July** to maximize the chances of profitabilty

# %% [markdown]
# ## Start of the analysis

# %% [markdown]
# * Import all the needed libraries for this project

# %%
# Run this cell without changes
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Define some functions that I need for the analysis.
# * The function *convert_dollars_to_float* takes a dataframe and a column which is string but contains money in dollars, and converts it into a float value

# %%
def convert_dollars_to_float(df, col):
    df[col] = df[col].str.replace('$', '')
    df[col] = df[col].str.replace(',', '')
    df[col] = df[col].astype(float)
    return df[col]

# %% [markdown]
# * The three functions below are used to get mean, std and sum values for a list of dataframes.

# %%
def get_mean_values(df_list,col):
    mean_vals_list=[]
    for df in df_list:
        mean_vals_list.append(round(df[col].mean(),2))
    return mean_vals_list

# %%
def get_std_values(df_list, col):
    std_vals_list=[]
    for df in df_list:
        std_vals_list.append(round(df[col].std(),2))
    return std_vals_list

# %%
def get_sum_values(df_list,col):
    sum_vals_list=[]
    for df in df_list:
        sum_vals_list.append(round(df[col].sum(),2))
        print(round(df[col].sum(),2))
    return sum_vals_list

# %% [markdown]
# * This function returns me a list of profits from a dataframe that is split into different time periods over a year

# %%
def df_get_monthly_profits(df):
    mask       = (df['release_date'].dt.month >10) | (df['release_date'].dt.month == 1)
    df_nov_jan = df.loc[mask]
    mask       = (df['release_date'].dt.month >1) & (df['release_date'].dt.month <= 4)
    df_feb_apr = df.loc[mask]
    mask       = (df['release_date'].dt.month >4) & (df['release_date'].dt.month <= 7)
    df_may_jul = df.loc[mask]
    mask       = (df['release_date'].dt.month >7) & (df['release_date'].dt.month <= 10)
    df_aug_oct = df.loc[mask]
    list_profit =[df_nov_jan['profit'].mean(),df_feb_apr['profit'].mean(),df_may_jul['profit'].mean(), df_aug_oct['profit'].mean()]
    return list_profit

# %% [markdown]
# * Open the connection to the database and load the sql tables from IMDB database files. I will be using the tables *movie_basics,  movie_ratings, persons* and *directors*. The few cells below are basically to get familarized with different tables and the content stored in them

# %%
conn = sqlite3.Connection("zippedData/im.db")
conn

# %%
q0 = """
SELECT *
FROM movie_basics
;
"""
df_movie_basics=pd.read_sql(q0, conn)
df_movie_basics
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 3                   NaN          Comedy,Drama
# 4                  80.0  Comedy,Drama,Fantasy
# ...                 ...                   ...
# 146139            123.0                 Drama
# 146140              NaN           Documentary
# 146141              NaN                Comedy
# 146142            116.0                  None
# 146143              NaN           Documentary
#
# [146144 rows x 6 columns]

# %%
#df_movie_basics.drop(columns=['runtime_minutes'],axis=1)
df_movie_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   movie_id         146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
q0 = """
SELECT *
FROM movie_ratings
;
"""

df_movie_ratings=pd.read_sql(q0, conn)
df_movie_ratings
# Out:
#          movie_id  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
q0 = """
SELECT *
FROM movie_akas
;
"""

df_movie_akas=pd.read_sql(q0, conn)
df_movie_akas
# Out:
#          movie_id  ordering                                    title region  \
# 0       tt0369610        10                            Джурасик свят     BG
# 1       tt0369610        11                        Jurashikku warudo     JP
# 2       tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3       tt0369610        13                  O Mundo dos Dinossauros     BR
# 4       tt0369610        14                           Jurassic World     FR
# ...           ...       ...                                      ...    ...
# 331698  tt9827784         2                       Sayonara kuchibiru   None
# 331699  tt9827784         3                            Farewell Song    XWW
# 331700  tt9880178         1                              La atención   None
# 331701  tt9880178         2                              La atención     ES
# 331702  tt9880178         3                            The Attention    XWW
#
#        language        types   attributes  is_original_title
# 0            bg         None         None                0.0
# 1          None  imdbDisplay         None                0.0
# 2          None  imdbDisplay         None                0.0
# 3          None         None  short title                0.0
# 4          None  imdbDisplay         None                0.0
# ...         ...          ...          ...                ...
# 331698     None     original         None                1.0
# 331699       en  imdbDisplay         None                0.0
# 331700     None     original         None                1.0
# 331701     None         None         None                0.0
# 331702       en  imdbDisplay         None                0.0
#
# [331703 rows x 8 columns]

# %%
df_movie_akas[df_movie_akas['language']=='en']
# Out:
#           movie_id  ordering                        title region language  \
# 87      tt10027708         2                    Miguelito    XWW       en
# 89      tt10027708         4                    Miguelito     AU       en
# 95       tt1014759        10  Alice Dar Sarzamin E Ajayeb     IE       en
# 127      tt1014759         3          Alice in Wonderland     JP       en
# 142     tt10225354         3               Returning Home    XWW       en
# ...            ...       ...                          ...    ...      ...
# 331679   tt9644084         3                   The Breath    XWW       en
# 331680   tt9654246         1    The Wild Man of the North    XWW       en
# 331683   tt9657946         1                       Homing    XWW       en
# 331699   tt9827784         3                Farewell Song    XWW       en
# 331702   tt9880178         3                The Attention    XWW       en
#
#               types attributes  is_original_title
# 87      imdbDisplay       None                0.0
# 89             None       None                0.0
# 95      imdbDisplay       None                0.0
# 127            None       None                0.0
# 142     alternative       None                0.0
# ...             ...        ...                ...
# 331679  alternative       None                0.0
# 331680  imdbDisplay       None                0.0
# 331683  imdbDisplay       None                0.0
# 331699  imdbDisplay       None                0.0
# 331702  imdbDisplay       None                0.0
#
# [22895 rows x 8 columns]

# %%
df_movie_akas.region.value_counts()
# Out:
# US      51490
# XWW     18467
# RU      13817
# DE      11634
# FR      10990
#         ...
# MQ          1
# SUHH        1
# SB          1
# TM          1
# NC          1
# Name: region, Length: 213, dtype: int64

# %%
df_movie_akas[df_movie_akas['region']=='US']
# Out:
#          movie_id  ordering                                        title  \
# 12      tt0369610        21                            Jurassic World 3D
# 20      tt0369610        29                               Jurassic World
# 21      tt0369610         2                                     Ebb Tide
# 28      tt0369610        36                             Jurassic Park IV
# 37      tt0369610        44                              Jurassic Park 4
# ...           ...       ...                                          ...
# 331645  tt9310460         6  Coconut the Little Dragon 2 Into the Jungle
# 331654  tt9358044         2                                  Hail Satan?
# 331673  tt9562694         5                                Alien Warfare
# 331686  tt9705860         1          Dusan Vukotic Croatian Oscar Winner
# 331694  tt9755806         1                                    Big Shark
#
#        region language        types                  attributes  \
# 12         US     None         None                 3-D version
# 20         US     None         None                        None
# 21         US     None         None          fake working title
# 28         US     None      working                        None
# 37         US     None         None  informal alternative title
# ...       ...      ...          ...                         ...
# 331645     US     None  imdbDisplay                        None
# 331654     US     None  imdbDisplay                        None
# 331673     US     None  imdbDisplay                        None
# 331686     US     None  imdbDisplay                        None
# 331694     US     None         None                        None
#
#         is_original_title
# 12                    0.0
# 20                    0.0
# 21                    0.0
# 28                    0.0
# 37                    0.0
# ...                   ...
# 331645                0.0
# 331654                0.0
# 331673                0.0
# 331686                0.0
# 331694                0.0
#
# [51490 rows x 8 columns]

# %% [markdown]
#  * <span style="color:red"> I wanted to check if using region (USA) brings any change in the distriutions below. For this I would have to join movie_akas sql table. Given the time limitation I am not doing this at this point in time </span>
#
# * Here I am quering over many SQL tables. My goal is to get one table that has info about movies, genres, ratings and directors. This definitely will have less data as compared to individual tables, but we need to have all this info for any given movie to do some sensible analysis.
#
# * I basically want to have movie name, director name, runtime minutes, genre, average rating, num of votes information

# %%
q0 = """
SELECT 
    mbasics.movie_id,
    mbasics.primary_title,
    mbasics.start_year,
    mbasics.genres,
    mbasics.runtime_minutes,
    p.primary_name,
    p.person_id,
    mratings.averagerating,
    mratings.numvotes,
    pr.category
    FROM movie_basics AS mbasics
JOIN
    movie_ratings AS mratings
    USING(movie_id)
JOIN
    directors AS dir
    USING(movie_id)
JOIN
    principals AS pr
    USING(movie_id)    
JOIN
    persons AS p
    USING(person_id)      
WHERE
    pr.category='director'
;
"""
df_movie_db=pd.read_sql(q0, conn)
df_movie_db
# Out:
#          movie_id        primary_title  start_year        genres  \
# 0       tt0323808      The Wicker Tree        2011  Drama,Horror
# 1       tt0417610    Asleep in the Sun        2010       Fantasy
# 2       tt0417610    Asleep in the Sun        2010       Fantasy
# 3       tt0469152  Smoking/Non-Smoking        2011         Drama
# 4       tt0469152  Smoking/Non-Smoking        2011         Drama
# ...           ...                  ...         ...           ...
# 437148  tt9670894             Veergati        2019        Action
# 437149  tt9670894             Veergati        2019        Action
# 437150  tt9670894             Veergati        2019        Action
# 437151  tt9670894             Veergati        2019        Action
# 437152  tt9681728      A Russian Youth        2019     Drama,War
#
#         runtime_minutes          primary_name   person_id  averagerating  \
# 0                  96.0           Robin Hardy   nm0362736            3.9
# 1                  83.0     Alejandro Chomski   nm1145057            6.4
# 2                  83.0     Alejandro Chomski   nm1145057            6.4
# 3                  84.0     Alyssa R. Bennett   nm0707738            7.2
# 4                  84.0     Alyssa R. Bennett   nm0707738            7.2
# ...                 ...                   ...         ...            ...
# 437148             61.0          Vishal Desai   nm4039933            6.9
# 437149             61.0            Raju Desai   nm7840985            6.9
# 437150             61.0            Raju Desai   nm7840985            6.9
# 437151             61.0            Raju Desai   nm7840985            6.9
# 437152             72.0  Alexander Zolotukhin  nm10436661            6.6
#
#         numvotes  category
# 0           2328  director
# 1             80  director
# 2             80  director
# 3             88  director
# 4             88  director
# ...          ...       ...
# 437148        10  director
# 437149        10  director
# 437150        10  director
# 437151        10  director
# 437152        34  director
#
# [437153 rows x 10 columns]

# %% [markdown]
# * Check for the duplicate entries

# %%
df_movie_db[df_movie_db.duplicated()==True]
# Out:
#          movie_id        primary_title  start_year              genres  \
# 2       tt0417610    Asleep in the Sun        2010             Fantasy
# 4       tt0469152  Smoking/Non-Smoking        2011               Drama
# 6       tt0475290        Hail, Caesar!        2016  Comedy,Drama,Music
# 8       tt0475290        Hail, Caesar!        2016  Comedy,Drama,Music
# 9       tt0475290        Hail, Caesar!        2016  Comedy,Drama,Music
# ...           ...                  ...         ...                 ...
# 437147  tt9670894             Veergati        2019              Action
# 437148  tt9670894             Veergati        2019              Action
# 437149  tt9670894             Veergati        2019              Action
# 437150  tt9670894             Veergati        2019              Action
# 437151  tt9670894             Veergati        2019              Action
#
#         runtime_minutes       primary_name  person_id  averagerating  \
# 2                  83.0  Alejandro Chomski  nm1145057            6.4
# 4                  84.0  Alyssa R. Bennett  nm0707738            7.2
# 6                 106.0         Ethan Coen  nm0001053            6.3
# 8                 106.0          Joel Coen  nm0001054            6.3
# 9                 106.0         Ethan Coen  nm0001053            6.3
# ...                 ...                ...        ...            ...
# 437147             61.0       Vishal Desai  nm4039933            6.9
# 437148             61.0       Vishal Desai  nm4039933            6.9
# 437149             61.0         Raju Desai  nm7840985            6.9
# 437150             61.0         Raju Desai  nm7840985            6.9
# 437151             61.0         Raju Desai  nm7840985            6.9
#
#         numvotes  category
# 2             80  director
# 4             88  director
# 6         111422  director
# 8         111422  director
# 9         111422  director
# ...          ...       ...
# 437147        10  director
# 437148        10  director
# 437149        10  director
# 437150        10  director
# 437151        10  director
#
# [356812 rows x 10 columns]

# %% [markdown]
# * Removing some duplicate entries using the umbrella drop_duplicates command.

# %%
df_movie_db=df_movie_db.drop_duplicates()
df_movie_db
# Out:
#          movie_id        primary_title  start_year              genres  \
# 0       tt0323808      The Wicker Tree        2011        Drama,Horror
# 1       tt0417610    Asleep in the Sun        2010             Fantasy
# 3       tt0469152  Smoking/Non-Smoking        2011               Drama
# 5       tt0475290        Hail, Caesar!        2016  Comedy,Drama,Music
# 7       tt0475290        Hail, Caesar!        2016  Comedy,Drama,Music
# ...           ...                  ...         ...                 ...
# 437133  tt9592190          Luonnonlaki        2019         Documentary
# 437139  tt9670776        Code of Tumas        2018           Biography
# 437140  tt9670894             Veergati        2019              Action
# 437143  tt9670894             Veergati        2019              Action
# 437152  tt9681728      A Russian Youth        2019           Drama,War
#
#         runtime_minutes          primary_name   person_id  averagerating  \
# 0                  96.0           Robin Hardy   nm0362736            3.9
# 1                  83.0     Alejandro Chomski   nm1145057            6.4
# 3                  84.0     Alyssa R. Bennett   nm0707738            7.2
# 5                 106.0            Ethan Coen   nm0001053            6.3
# 7                 106.0             Joel Coen   nm0001054            6.3
# ...                 ...                   ...         ...            ...
# 437133             70.0         Verena Netzer   nm7006696            7.4
# 437139             86.0     Eimantas Belickas   nm2277447            8.0
# 437140             61.0          Vishal Desai   nm4039933            6.9
# 437143             61.0            Raju Desai   nm7840985            6.9
# 437152             72.0  Alexander Zolotukhin  nm10436661            6.6
#
#         numvotes  category
# 0           2328  director
# 1             80  director
# 3             88  director
# 5         111422  director
# 7         111422  director
# ...          ...       ...
# 437133         8  director
# 437139         9  director
# 437140        10  director
# 437143        10  director
# 437152        34  director
#
# [80341 rows x 10 columns]

# %%
#df_movie_db[df_movie_db['movie_id']=='tt4050462']

# %%
df_movie_db[df_movie_db["primary_name"]=="Joel Coen"]
# Out:
#          movie_id                 primary_title  start_year  \
# 7       tt0475290                 Hail, Caesar!        2016
# 72519   tt2042568           Inside Llewyn Davis        2013
# 73042   tt1403865                     True Grit        2010
# 403286  tt6412452  The Ballad of Buster Scruggs        2018
#
#                          genres  runtime_minutes primary_name  person_id  \
# 7            Comedy,Drama,Music            106.0    Joel Coen  nm0001054
# 72519               Drama,Music            104.0    Joel Coen  nm0001054
# 73042   Adventure,Drama,Western            110.0    Joel Coen  nm0001054
# 403286     Comedy,Drama,Musical            133.0    Joel Coen  nm0001054
#
#         averagerating  numvotes  category
# 7                 6.3    111422  director
# 72519             7.5    123759  director
# 73042             7.6    284034  director
# 403286            7.3     87418  director

# %%
df_movie_db[df_movie_db["primary_name"]=="Ethan Coen"]
# Out:
#          movie_id                 primary_title  start_year  \
# 5       tt0475290                 Hail, Caesar!        2016
# 72517   tt2042568           Inside Llewyn Davis        2013
# 73039   tt1403865                     True Grit        2010
# 403282  tt6412452  The Ballad of Buster Scruggs        2018
#
#                          genres  runtime_minutes primary_name  person_id  \
# 5            Comedy,Drama,Music            106.0   Ethan Coen  nm0001053
# 72517               Drama,Music            104.0   Ethan Coen  nm0001053
# 73039   Adventure,Drama,Western            110.0   Ethan Coen  nm0001053
# 403282     Comedy,Drama,Musical            133.0   Ethan Coen  nm0001053
#
#         averagerating  numvotes  category
# 5                 6.3    111422  director
# 72517             7.5    123759  director
# 73039             7.6    284034  director
# 403282            7.3     87418  director

# %% [markdown]
# #### Since there are duplicate entries when there is a more than one director for a given movie. I am using the below groupby feature to add the directors in one row

# %%
df_movie_db = df_movie_db.groupby('movie_id').agg({'primary_title':'first',
                                       'averagerating':'first',
                                       'numvotes':'first',
                                       'genres':'first',
                                       'start_year':'first',
                             'primary_name': ', '.join, 
                             'person_id': ', '.join, 
                             }).reset_index()

#df_movie = df_movie_db.groupby(['movie_id','primary_name','person_id','primary_title','start_year',"genres","averagerating","numvotes"])['primary_name'].apply(', '.join).reset_index()

# %%
df_movie_db[df_movie_db.duplicated()==True]
# Out:
# Empty DataFrame
# Columns: [movie_id, primary_title, averagerating, numvotes, genres, start_year, primary_name, person_id]
# Index: []

# %%
df_movie_db
# Out:
#         movie_id                    primary_title  averagerating  numvotes  \
# 0      tt0063540                        Sunghursh            7.0        77
# 1      tt0066787  One Day Before the Rainy Season            7.2        43
# 2      tt0069049       The Other Side of the Wind            6.9      4517
# 3      tt0069204                  Sabse Bada Sukh            6.1        13
# 4      tt0100275         The Wandering Soap Opera            6.5       119
# ...          ...                              ...            ...       ...
# 67746  tt9913056                     Swarm Season            6.2         5
# 67747  tt9913084                 Diabolik sono io            6.2         6
# 67748  tt9914642                        Albatross            8.5         8
# 67749  tt9914942       La vida sense la Sara Amat            6.6         5
# 67750  tt9916160                       Drømmeland            6.5        11
#
#                      genres  start_year                   primary_name  \
# 0        Action,Crime,Drama        2013            Harnam Singh Rawail
# 1           Biography,Drama        2019                      Mani Kaul
# 2                     Drama        2018                   Orson Welles
# 3              Comedy,Drama        2018           Hrishikesh Mukherjee
# 4      Comedy,Drama,Fantasy        2017  Raoul Ruiz, Valeria Sarmiento
# ...                     ...         ...                            ...
# 67746           Documentary        2019                Sarah Christman
# 67747           Documentary        2019                Giancarlo Soldi
# 67748           Documentary        2017                   Chris Jordan
# 67749                  None        2019                      Laura Jou
# 67750           Documentary        2019             Joost van der Wiel
#
#                   person_id
# 0                 nm0712540
# 1                 nm0002411
# 2                 nm0000080
# 3                 nm0611531
# 4      nm0749914, nm0765384
# ...                     ...
# 67746             nm1502645
# 67747             nm0812850
# 67748             nm5300859
# 67749             nm1716653
# 67750             nm5684093
#
# [67751 rows x 8 columns]

# %%
df_movie_db[df_movie_db['primary_name'].str.contains('Joel Coen')]
# Out:
#         movie_id                 primary_title  averagerating  numvotes  \
# 148    tt0475290                 Hail, Caesar!            6.3    111422
# 2401   tt1403865                     True Grit            7.6    284034
# 14543  tt2042568           Inside Llewyn Davis            7.5    123759
# 56437  tt6412452  The Ballad of Buster Scruggs            7.3     87418
#
#                         genres  start_year           primary_name  \
# 148         Comedy,Drama,Music        2016  Ethan Coen, Joel Coen
# 2401   Adventure,Drama,Western        2010  Ethan Coen, Joel Coen
# 14543              Drama,Music        2013  Ethan Coen, Joel Coen
# 56437     Comedy,Drama,Musical        2018  Ethan Coen, Joel Coen
#
#                   person_id
# 148    nm0001053, nm0001054
# 2401   nm0001053, nm0001054
# 14543  nm0001053, nm0001054
# 56437  nm0001053, nm0001054

# %%
df_movie_db[df_movie_db['primary_title']=='Hail, Caesar!']
# Out:
#       movie_id  primary_title  averagerating  numvotes              genres  \
# 148  tt0475290  Hail, Caesar!            6.3    111422  Comedy,Drama,Music
#
#      start_year           primary_name             person_id
# 148        2016  Ethan Coen, Joel Coen  nm0001053, nm0001054

# %%
df_movie_db['movie_id'].value_counts()
# Out:
# tt5424898    1
# tt8892138    1
# tt2373324    1
# tt2844388    1
# tt4138254    1
#             ..
# tt5468728    1
# tt5656126    1
# tt1194577    1
# tt1585660    1
# tt6515458    1
# Name: movie_id, Length: 67751, dtype: int64

# %%
df_movie_db[df_movie_db['movie_id']=='tt4050462']
# Out:
#         movie_id   primary_title  averagerating  numvotes  \
# 38893  tt4050462  World of Death            7.2        31
#
#                      genres  start_year  \
# 38893  Comedy,Horror,Sci-Fi        2016
#
#                                             primary_name  \
# 38893  Paul Campion, Jay Wade Edwards, Shane Free, A ...
#
#                                                person_id
# 38893  nm0133067, nm0250080, nm0293064, nm0340236, nm...

# %%
df_movie_db[df_movie_db['primary_title']=='Together']
# Out:
#         movie_id primary_title  averagerating  numvotes          genres  \
# 10517  tt1826955      Together            7.3       369  Drama,Thriller
# 17940  tt2198824      Together            4.2       204   Drama,Romance
# 18662  tt2235823      Together            7.7        20     Documentary
# 22652  tt2417568      Together            2.1       485           Drama
# 23365  tt2471538      Together            5.3         6  Drama,Thriller
# 23400  tt2473710      Together            6.9         7           Drama
# 36355  tt3753812      Together            6.8         5     Documentary
# 54404  tt6111634      Together            8.5        33         Romance
# 66571  tt9097086      Together            7.2        35           Drama
#
#        start_year            primary_name  person_id
# 10517        2011        Mladen Maticevic  nm1050198
# 17940        2013  Clarence Yiu-leung Fok  nm0284011
# 18662        2010              Liang Zhao  nm2420832
# 22652        2012            Chao-jen Hsu  nm1314647
# 23365        2012              Marcus Lee  nm5402524
# 23400        2011                 Ran Yan  nm8084230
# 36355        2014           Maciej Adamek  nm0010622
# 54404        2018          Paul Duddridge  nm1548930
# 66571        2018            Marko Santic  nm2414753

# %%
df_movie_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67751 entries, 0 to 67750
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   movie_id       67751 non-null  object
#  1   primary_title  67751 non-null  object
#  2   averagerating  67751 non-null  float64
#  3   numvotes       67751 non-null  int64
#  4   genres         67133 non-null  object
#  5   start_year     67751 non-null  int64
#  6   primary_name   67751 non-null  object
#  7   person_id      67751 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 4.1+ MB

# %%
df_movie_db["genres"].value_counts()
# Out:
# Drama                           10917
# Documentary                      9456
# Comedy                           4976
# Comedy,Drama                     2394
# Horror                           2391
#                                 ...
# Documentary,Mystery,News            1
# Crime,Family                        1
# Action,Romance,Western              1
# Adventure,Documentary,Sci-Fi        1
# Family,Horror,Romance               1
# Name: genres, Length: 893, dtype: int64

# %% [markdown]
# * The genres are not so well defined and in many cases a movie falls under more than one category. This means the analysis is going have some uncertanity/errors associated to it.

# %%
#df_movie_db=df_movie_db.drop_duplicates(subset='person_id', keep="first")
#df_movie_db=df_movie_db.drop_duplicates(subset='movie_id', keep="first")
#df_movie_db=df_movie_db.drop_duplicates(subset='primary_title', keep="first")
df_movie_db['primary_title'].value_counts()
# Out:
# The Return                    9
# Together                      9
# Broken                        8
# Lucky                         8
# Homecoming                    8
#                              ..
# Moko Jumbie                   1
# The Fallen Faithful           1
# The School in the Woods       1
# Wonderful Radio               1
# The Children of Dead Roses    1
# Name: primary_title, Length: 64375, dtype: int64

# %% [markdown]
# * Some movies have remakes I guess that is why different years as seen below for movie "Together" which is possible!! So I am going to keep these entries.

# %%
df_movie_db[df_movie_db['primary_title']=='Together']
# Out:
#         movie_id primary_title  averagerating  numvotes          genres  \
# 10517  tt1826955      Together            7.3       369  Drama,Thriller
# 17940  tt2198824      Together            4.2       204   Drama,Romance
# 18662  tt2235823      Together            7.7        20     Documentary
# 22652  tt2417568      Together            2.1       485           Drama
# 23365  tt2471538      Together            5.3         6  Drama,Thriller
# 23400  tt2473710      Together            6.9         7           Drama
# 36355  tt3753812      Together            6.8         5     Documentary
# 54404  tt6111634      Together            8.5        33         Romance
# 66571  tt9097086      Together            7.2        35           Drama
#
#        start_year            primary_name  person_id
# 10517        2011        Mladen Maticevic  nm1050198
# 17940        2013  Clarence Yiu-leung Fok  nm0284011
# 18662        2010              Liang Zhao  nm2420832
# 22652        2012            Chao-jen Hsu  nm1314647
# 23365        2012              Marcus Lee  nm5402524
# 23400        2011                 Ran Yan  nm8084230
# 36355        2014           Maciej Adamek  nm0010622
# 54404        2018          Paul Duddridge  nm1548930
# 66571        2018            Marko Santic  nm2414753

# %%
df_movie_db['numvotes'].value_counts()
# Out:
# 6         2538
# 5         2389
# 7         2199
# 8         1945
# 9         1703
#           ...
# 538720       1
# 4197         1
# 2150         1
# 10402        1
# 4098         1
# Name: numvotes, Length: 7145, dtype: int64

# %%
df_movie_db["primary_name"].value_counts()
# Out:
# Nayato Fio Nuala       35
# David DeCoteau         26
# Larry Rosen            23
# Ram Gopal Varma        20
# Takashi Miike          19
#                        ..
# Arup Kumar De           1
# Rafel Duran Torrent     1
# J. Stephen Maunder      1
# Kelly Nyks              1
# Avinash Kumar Singh     1
# Name: primary_name, Length: 47278, dtype: int64

# %%
df_movie_db[df_movie_db['primary_name']=='Nayato Fio Nuala']
# Out:
#         movie_id                            primary_title  averagerating  \
# 4671   tt1590941                                      18+            6.7
# 5285   tt1620421                                   Affair            4.1
# 5286   tt1620435                         Belum cukup umur            6.3
# 5524   tt1631739                       Kain kafan perawan            4.3
# 5529   tt1631824                                Te[rekam]            3.6
# 6101   tt1657318                   Akibat pergaulan bebas            3.6
# 6986   tt1693035                             Not for Sale            4.0
# 7610   tt1718842                       Nakalnya anak muda            4.0
# 8489   tt1748161                    Pengantin Pantai Biru            2.5
# 8491   tt1748168                      Pocong jumat kliwon            2.6
# 9210   tt1774382                         Gaby dan lagunya            6.9
# 9211   tt1774395                            Heart 2 Heart            8.3
# 10234  tt1817736                      Pocong rumah angker            5.7
# 12596  tt1930443                            Pocong Ngesot            2.1
# 12606  tt1930549  Virgin 3: Satu malam mengubah segalanya            6.0
# 13494  tt1979259                     Kuntilanak kesurupan            2.4
# 14878  tt2062472                   Ada apa dengan pocong?            5.1
# 14898  tt2062618                         Pelet kuntilanak            2.9
# 16213  tt2112178                          Kepergok pocong            3.4
# 16242  tt2112320                       Tumbal jailangkung            5.3
# 17057  tt2156410                             My Last Love            5.8
# 17680  tt2187538                           3 pocong idiot            4.7
# 18374  tt2221713                       Keranda kuntilanak            3.4
# 18380  tt2221819             Tarung: City of the Darkness            6.2
# 19021  tt2251770                               Seandainya            6.3
# 19023  tt2251780                        Santet kuntilanak            3.3
# 19053  tt2254068                       Bangkit dari Kubur            4.9
# 19649  tt2285419                       Bukan pocong biasa            5.2
# 19656  tt2285527                       Kalung jailangkung            5.8
# 19668  tt2285647                        Pocong kesetanan!            4.8
# 20290  tt2316550                    Kuntilanak-kuntilanak            4.9
# 26412  tt2773536                      Dendam dari Kuburan            2.4
# 42353  tt4472678                               3600 Detik            6.5
# 61234  tt7429260                        Hantu Gunung Kawi            6.0
# 61397  tt7472366                    After School Horror 2            4.7
#
#        numvotes           genres  start_year      primary_name  person_id
# 4671         83            Drama        2010  Nayato Fio Nuala  nm2551464
# 5285         58           Horror        2010  Nayato Fio Nuala  nm2551464
# 5286          6            Drama        2010  Nayato Fio Nuala  nm2551464
# 5524         32           Horror        2010  Nayato Fio Nuala  nm2551464
# 5529         13           Horror        2010  Nayato Fio Nuala  nm2551464
# 6101         23            Drama        2010  Nayato Fio Nuala  nm2551464
# 6986         11            Drama        2010  Nayato Fio Nuala  nm2551464
# 7610         12  Horror,Thriller        2010  Nayato Fio Nuala  nm2551464
# 8489         26           Horror        2010  Nayato Fio Nuala  nm2551464
# 8491         16    Comedy,Horror        2010  Nayato Fio Nuala  nm2551464
# 9210         17            Drama        2010  Nayato Fio Nuala  nm2551464
# 9211         72            Drama        2010  Nayato Fio Nuala  nm2551464
# 10234        17           Horror        2010  Nayato Fio Nuala  nm2551464
# 12596        15    Comedy,Horror        2011  Nayato Fio Nuala  nm2551464
# 12606        11            Drama        2011  Nayato Fio Nuala  nm2551464
# 13494        19    Comedy,Horror        2011  Nayato Fio Nuala  nm2551464
# 14878        24    Comedy,Horror        2011  Nayato Fio Nuala  nm2551464
# 14898        10           Horror        2011  Nayato Fio Nuala  nm2551464
# 16213         8    Comedy,Horror        2011  Nayato Fio Nuala  nm2551464
# 16242         9           Horror        2011  Nayato Fio Nuala  nm2551464
# 17057        15            Drama        2012  Nayato Fio Nuala  nm2551464
# 17680        26    Comedy,Horror        2012  Nayato Fio Nuala  nm2551464
# 18374        14    Comedy,Horror        2011  Nayato Fio Nuala  nm2551464
# 18380        69           Action        2011  Nayato Fio Nuala  nm2551464
# 19021         7            Drama        2012  Nayato Fio Nuala  nm2551464
# 19023         6           Horror        2012  Nayato Fio Nuala  nm2551464
# 19053        21           Horror        2012  Nayato Fio Nuala  nm2551464
# 19649        29    Comedy,Horror        2011  Nayato Fio Nuala  nm2551464
# 19656        11           Horror        2011  Nayato Fio Nuala  nm2551464
# 19668        20    Comedy,Horror        2011  Nayato Fio Nuala  nm2551464
# 20290        10           Horror        2012  Nayato Fio Nuala  nm2551464
# 26412        17           Horror        2012  Nayato Fio Nuala  nm2551464
# 42353        22            Drama        2014  Nayato Fio Nuala  nm2551464
# 61234         5           Horror        2017  Nayato Fio Nuala  nm2551464
# 61397        13           Horror        2017  Nayato Fio Nuala  nm2551464

# %%
df_movie_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67751 entries, 0 to 67750
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   movie_id       67751 non-null  object
#  1   primary_title  67751 non-null  object
#  2   averagerating  67751 non-null  float64
#  3   numvotes       67751 non-null  int64
#  4   genres         67133 non-null  object
#  5   start_year     67751 non-null  int64
#  6   primary_name   67751 non-null  object
#  7   person_id      67751 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 4.1+ MB

# %% [markdown]
# * There are some 618 entries for which genres are not defined. I could throw away these entries but the way I am going to look at genres will not affect the analysis. I am going to keep these entries

# %%
df_movie_db[df_movie_db['genres'].isnull()]
# Out:
#          movie_id               primary_title  averagerating  numvotes genres  \
# 16      tt0253093                Gangavataran            6.6         8   None
# 29      tt0326592               The Overnight            7.5        24   None
# 33      tt0330811         Regret Not Speaking            6.2        10   None
# 482    tt10011402     Martha: A Picture Story            8.0         7   None
# 590    tt10122528                  Miel-Emile            8.2         5   None
# ...           ...                         ...            ...       ...    ...
# 67391   tt9615278                  Abou Leila            6.8         6   None
# 67563   tt9742106       The Cat in Their Arms            4.5         8   None
# 67700   tt9866736           Rise: Ini Kalilah            5.8        11   None
# 67707   tt9876160         Koridor bessmertiya            5.4        45   None
# 67749   tt9914942  La vida sense la Sara Amat            6.6         5   None
#
#        start_year                                primary_name  \
# 16           2018  Madhukar Bavdekar, Dhundiraj Govind Phalke
# 29           2010                              Jed I. Goodman
# 33           2011                        Richard Kwietniowski
# 482          2019                                Selina Miles
# 590          2019                            Peter van Houten
# ...           ...                                         ...
# 67391        2019                         Amin Sidi-Boumedine
# 67563        2018                                Isshin Inudô
# 67700        2018                               Teong Hin Saw
# 67707        2019                                Fyodor Popov
# 67749        2019                                   Laura Jou
#
#                   person_id
# 16     nm0062580, nm0679610
# 29                nm1208371
# 33                nm0477193
# 482               nm5817232
# 590              nm10354531
# ...                     ...
# 67391             nm4586902
# 67563             nm0409459
# 67700             nm1672058
# 67707             nm1252857
# 67749             nm1716653
#
# [618 rows x 8 columns]

# %%
df_movie_db.genres.value_counts().head(50)
# Out:
# Drama                            10917
# Documentary                       9456
# Comedy                            4976
# Comedy,Drama                      2394
# Horror                            2391
# Thriller                          1453
# Drama,Romance                     1412
# Comedy,Romance                    1161
# Comedy,Drama,Romance              1096
# Drama,Thriller                     943
# Horror,Thriller                    919
# Action                             842
# Romance                            669
# Biography,Documentary              639
# Documentary,Music                  550
# Documentary,Drama                  540
# Comedy,Horror                      519
# Action,Crime,Drama                 516
# Family                             467
# Crime,Drama,Thriller               464
# Drama,Family                       457
# Crime,Drama                        456
# Biography,Documentary,History      447
# Documentary,History                435
# Action,Drama                       363
# Biography,Documentary,Drama        348
# Horror,Mystery,Thriller            340
# Drama,Horror,Thriller              318
# Action,Thriller                    313
# Animation                          310
# Documentary,Sport                  304
# Comedy,Drama,Family                289
# Drama,Mystery,Thriller             287
# Action,Comedy                      287
# Sci-Fi                             250
# Biography,Drama                    234
# Crime                              233
# Adventure,Animation,Comedy         232
# Biography,Documentary,Music        230
# Action,Crime,Thriller              225
# Action,Adventure,Comedy            218
# Action,Drama,Thriller              214
# Drama,Horror,Mystery               209
# Drama,History                      208
# Comedy,Crime,Drama                 206
# Crime,Drama,Mystery                203
# Documentary,News                   198
# Action,Comedy,Crime                196
# Drama,Mystery                      195
# Crime,Thriller                     187
# Name: genres, dtype: int64

# %%
df_movie_db.sort_values(by=['start_year'], ascending=False).head(20)

# %% [markdown]
# * Here I am just making different dataframes based on some genres that I picked. I am not droping NAN values because I am sliicing dataframe based on certain conditions which wont be affected by NAN values

# %%
df_action_db  =df_movie_db[df_movie_db['genres'].str.contains("Action|Thriller|Crime|Mystery")==True]
df_drama_db   =df_movie_db[df_movie_db['genres'].str.contains("Drama|War|Family")==True]
df_romance_db =df_movie_db[df_movie_db['genres'].str.contains("Romance")==True]
df_horror_db  =df_movie_db[df_movie_db['genres'].str.contains("Horror")==True]
df_comedy_db  =df_movie_db[df_movie_db['genres'].str.contains("Comedy")==True]
df_docu_db    =df_movie_db[df_movie_db['genres'].str.contains("Documentary|Biography|History|News|Music")==True]
df_scifi_db   =df_movie_db[df_movie_db['genres'].str.contains("Sci-Fi")==True]
df_anime_db   =df_movie_db[df_movie_db['genres'].str.contains("Animation")==True]

# %%
df_anime_db
# Out:
#         movie_id                                      primary_title  \
# 11     tt0176694                                 The Tragedy of Man
# 14     tt0249516                                         Foodfight!
# 26     tt0312305             Quantum Quest: A Cassini Space Odyssey
# 34     tt0331314                                    Bunyan and Babe
# 48     tt0377981                                    Gnomeo & Juliet
# ...          ...                                                ...
# 67669  tt9844256  Code Geass: Lelouch of the Rebellion - Glorifi...
# 67679  tt9850064                                Children of the Sea
# 67696  tt9863566                            Urbanus: De Vuilnisheld
# 67724  tt9894394                  Upin & Ipin: The Lone Gibbon Kris
# 67727  tt9896916                             The Pilgrim's Progress
#
#        averagerating  numvotes                       genres  start_year  \
# 11               7.8       584      Animation,Drama,History        2011
# 14               1.9      8248      Action,Animation,Comedy        2012
# 26               5.1       287   Adventure,Animation,Sci-Fi        2010
# 34               5.0       302   Adventure,Animation,Comedy        2017
# 48               6.0     49550   Adventure,Animation,Comedy        2011
# ...              ...       ...                          ...         ...
# 67669            7.5        24      Action,Animation,Sci-Fi        2018
# 67679            5.3         6  Adventure,Animation,Fantasy        2019
# 67696            5.6        31             Animation,Comedy        2019
# 67724            8.1       301                    Animation        2019
# 67727            7.9        61   Adventure,Animation,Family        2019
#
#                                             primary_name  \
# 11                                     Marcell Jankovics
# 14                                     Lawrence Kasanoff
# 26                  Daniel St. Pierre, Harry 'Doc' Kloor
# 34                                            Louis Ross
# 48                                          Kelly Asbury
# ...                                                  ...
# 67669                                     Gorô Taniguchi
# 67679                                     Ayumu Watanabe
# 67696                  Erik Verkerk, Joost Van Den Bosch
# 67724  Adam Bin Amiruddin, Ahmad Razuri bin Roseli, S...
# 67727                                   Robert Fernandez
#
#                                 person_id
# 11                              nm0417757
# 14                              nm0440415
# 26                   nm0820800, nm1004541
# 34                              nm8625898
# 48                              nm0038432
# ...                                   ...
# 67669                           nm0849465
# 67679                           nm2268014
# 67696                nm3972168, nm3978114
# 67724  nm10529303, nm10529304, nm10529305
# 67727                           nm9546685
#
# [1622 rows x 8 columns]

# %% [markdown]
# * I like to look at the distributions of different variables and their properties. Here I am looking at the distributions for average ratings for different genres. My reasoning is that the popular genres would have higher ratings as compared to less popular ones.

# %%
fig, axs = plt.subplots(3, 3, figsize=(10, 6), constrained_layout=True)
axs[0,0].hist(x=df_drama_db['averagerating'], bins=25,align='left', color='blue')
#ax1.hist(x=wins, bins=range(8), align="left", color="green")
#axs[0,0].set_xticks(range(20))
axs[0,0].set_xlabel("Avg. Ratings")
axs[0,0].set_ylabel("Counts")
axs[0,0].set_title("Drama")
axs[0,1].hist(x=df_action_db['averagerating'], bins=20,align='left', color='blue')
axs[0,1].set_xlabel("Avg. Ratings")
axs[0,1].set_ylabel("Counts")
axs[0,1].set_title("Action/Thriller")
axs[0,2].hist(x=df_horror_db['averagerating'], bins=20,align='left', color='blue')
axs[0,2].set_xlabel("Avg. Ratings")
axs[0,2].set_ylabel("Counts")
axs[0,2].set_title("Horror")
axs[1,0].hist(x=df_comedy_db['averagerating'], bins=20,align='left', color='blue')
axs[1,0].set_xlabel("Avg. Ratings")
axs[1,0].set_ylabel("Counts")
axs[1,0].set_title("Comedy")
axs[1,1].hist(x=df_romance_db['averagerating'], bins=20,align='left', color='blue')
axs[1,1].set_xlabel("Avg. Ratings")
axs[1,1].set_ylabel("Frequency")
axs[1,1].set_title("Counts")
axs[1,2].hist(x=df_docu_db['averagerating'], bins=20,align='left', color='blue')
axs[1,2].set_xlabel("Avg. Ratings")
axs[1,2].set_ylabel("Counts")
axs[1,2].set_title("Docu/Bio/Hist")
axs[2,0].hist(x=df_scifi_db['averagerating'], bins=20,align='left', color='blue')
axs[2,0].set_xlabel("Avg. Ratings")
axs[2,0].set_ylabel("Counts")
axs[2,0].set_title("Sci-Fi")
axs[2,1].hist(x=df_anime_db['averagerating'], bins=20,align='left', color='blue')
axs[2,1].set_xlabel("Avg. Ratings")
axs[2,1].set_ylabel("Counts")
axs[2,1].set_title("Animation")
axs[2,2].hist(x=df_scifi_db['numvotes'], align='left', color='blue')
axs[2,2].set_xlabel("Num of Votes")
axs[2,2].set_ylabel("Counts")
axs[2,2].set_title("cumulative # of votes")

axs[0,0].set_xlim([0, 10])
axs[0,1].set_xlim([0, 10])
axs[0,2].set_xlim([0, 10])
axs[1,0].set_xlim([0, 10])
axs[1,1].set_xlim([0, 10])
axs[1,2].set_xlim([0, 10])
axs[2,0].set_xlim([0, 10])
axs[2,1].set_xlim([0, 10])
axs[0,0].grid(True, color = 'DarkTurquoise', alpha=1, linestyle = '--', linewidth = 0.5)
axs[0,1].grid(True, color = 'DarkTurquoise', alpha=1, linestyle = '--', linewidth = 0.5)
axs[0,2].grid(True, color = 'DarkTurquoise', alpha=1, linestyle = '--', linewidth = 0.5)
axs[1,0].grid(True, color = 'DarkTurquoise', alpha=1, linestyle = '--', linewidth = 0.5)
axs[1,1].grid(True, color = 'DarkTurquoise', alpha=1, linestyle = '--', linewidth = 0.5)
axs[1,2].grid(True, color = 'DarkTurquoise', alpha=1, linestyle = '--', linewidth = 0.5)
axs[2,0].grid(True, color = 'DarkTurquoise', alpha=1, linestyle = '--', linewidth = 0.5)
axs[2,1].grid(True, color = 'DarkTurquoise', alpha=1, linestyle = '--', linewidth = 0.5)
axs[2,2].grid(True, color = 'DarkTurquoise', alpha=1, linestyle = '--', linewidth = 0.5)

#axs[2,2].scatter(df_genres['numvotes'], df_genres['averagerating'], color="green")
#axs[2,2].set_xlabel("Num of votes")
#axs[2,2].set_title("Avg. Ratings");
plt.savefig('./figs/imdb_genres_avg_ratings_1D_dist.png')
plt.show()

# %% [markdown]
# * Below I am just preparing the data for a bar chart that will show the mean average ratings for each genre. I also look at the mean number of votes for the above defined genres

# %%
df_list=[df_action_db,df_drama_db,df_horror_db,df_romance_db,df_comedy_db,df_scifi_db,df_docu_db,df_anime_db]
list_genres=['action','drama','horror','romance','comedy','sci-fi','docu','anime']

# %%
means_genres_list = get_mean_values(df_list,'averagerating')
stds_genres_list  = get_std_values(df_list,'averagerating')
sum_votes_list    = get_sum_values(df_list,'numvotes')
means_votes_list  = get_mean_values(df_list,'numvotes')
stds_votes_list   = get_std_values(df_list,'numvotes')
stds_votes_list
# Out:
# 151658512
# 121504905
# 23140666
# 25822393
# 70728116
# 42570948
# 32057806
# 15328640
# [53160.61,
#  28948.46,
#  19410.91,
#  23255.93,
#  29349.09,
#  100869.45,
#  18978.24,
#  46937.48]

# %%
#print("mean # of votes {:0.2f}".format(df_action_db['numvotes'].sum()))
#print("mean # of votes {:0.2f}".format(df_docu_db['numvotes'].sum()))
#print("mean # of votes {:0.2f}".format(df_drama_db['numvotes'].sum()))
#print("mean # of votes {:0.2f}".format(df_scifi_db['numvotes'].sum()))
fig, axs = plt.subplots(2, 2, figsize=(14, 6), constrained_layout=True)
axs[0,0].bar(list_genres, sum_votes_list,  color='green', width=0.35)
axs[0,1].bar(list_genres, means_votes_list,  color='green', width=0.35,)#yerr=stds_votes_list)
axs[1,0].bar(list_genres, means_genres_list,color ='green',width = 0.35,yerr=stds_genres_list)
#axs[1,1].scatter(means_genres_list,mean_votes_list, color ='green', label=list_genres)
axs[0,0].set_ylabel('Sum of all votes')
axs[0,0].set_title('Total Votes for given genre')
#axs[0,0].legend()
axs[0,1].set_ylabel('Mean value of votes')
axs[0,1].set_title('Mean number of Votes')
#axs[0,1].legend()
axs[1,0].set_xlabel("Genres")
axs[1,0].set_ylabel("Mean Values")
axs[1,0].set_title("Mean Avg. Ratings as a function of genres")

axs[0,0].grid(True, color = 'DarkTurquoise', alpha=1, linestyle = '--', linewidth = 0.5)
axs[0,1].grid(True, color = 'DarkTurquoise', alpha=1, linestyle = '--', linewidth = 0.5)
axs[1,0].grid(True, color = 'DarkTurquoise', alpha=1, linestyle = '--', linewidth = 0.5)

#axs[1,1].legend()

fig.delaxes(axs[1,1])
plt.savefig('./figs/imdb_genres_mean_avg_rating_votes_barchart.png')
plt.show()

# %% [markdown]
# * This is not as useful as I had expected it to be. The mean of average ratings for different genres
# is more or less similar. The sci-fi movies seem to get on average more votes followed by action/anime
# movies. However, the cumulative number of votes for action movies exceed rest. This could bw due to a couple
# of movies in this genre performing exceptionally well. Since the average ratings didnt yield a conclusive
# result, I will abandon this variable from here onwards!

# %% [markdown]
# * Now I will look at the *csv* and *tsv (I converted it into csv file)* files. These are from Rotton tomatoes and the movie database
#
# * The usual exercise to explore the datafiles and look at different variables

# %%
# Box office movie files
df_gross_movie = pd.read_csv("zippedData/bom.movie_gross.csv")
df_gross_movie
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# 0        652000000  2010
# 1        691300000  2010
# 2        664300000  2010
# 3        535700000  2010
# 4        513900000  2010
# ...            ...   ...
# 3382           NaN  2018
# 3383           NaN  2018
# 3384           NaN  2018
# 3385           NaN  2018
# 3386           NaN  2018
#
# [3387 rows x 5 columns]

# %%
df_gross_movie.studio.value_counts()
# Out:
# IFC       166
# Uni.      147
# WB        140
# Fox       136
# Magn.     136
#          ...
# FOR         1
# Rocket      1
# U/P         1
# IW          1
# Part.       1
# Name: studio, Length: 257, dtype: int64

# %%
#df_gross_movie[df_gross_movie['title'].str.contains('Harry')=='True']
df_gross_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
# The budgets file from " The Numbers " database
df_budgets_movie = pd.read_csv("zippedData/tn.movie_budgets.csv")
df_budgets_movie
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# 1         $410,600,000   $241,063,875  $1,045,663,875
# 2         $350,000,000    $42,762,350    $149,762,350
# 3         $330,600,000   $459,005,868  $1,403,013,963
# 4         $317,000,000   $620,181,382  $1,316,721,747
# ...                ...            ...             ...
# 5777            $7,000             $0              $0
# 5778            $6,000        $48,482        $240,495
# 5779            $5,000         $1,338          $1,338
# 5780            $1,400             $0              $0
# 5781            $1,100       $181,041        $181,041
#
# [5782 rows x 6 columns]

# %%
df_budgets_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
df_budgets_movie.movie.value_counts()
# Out:
# Halloween                                    3
# Home                                         3
# King Kong                                    3
# Hamlet                                       2
# The Mummy                                    2
#                                             ..
# Arthur Christmas                             1
# Jakob the Liar                               1
# The Cold Light of Day                        1
# The Hobbit: The Battle of the Five Armies    1
# Galaxy Quest                                 1
# Name: movie, Length: 5698, dtype: int64

# %%
df_budgets_movie[df_budgets_movie['movie']=='Halloween']
# Out:
#       id  release_date      movie production_budget domestic_gross  \
# 3014  15  Aug 31, 2007  Halloween       $15,000,000    $58,269,151
# 3535  36  Oct 19, 2018  Halloween       $10,000,000   $159,342,015
# 5536  37  Oct 17, 1978  Halloween          $325,000    $47,000,000
#
#      worldwide_gross
# 3014     $77,514,401
# 3535    $254,900,667
# 5536     $70,000,000

# %%
#check for duplicate entries if any
df_budgets_movie[df_budgets_movie.duplicated()==True]
# Out:
# Empty DataFrame
# Columns: [id, release_date, movie, production_budget, domestic_gross, worldwide_gross]
# Index: []

# %% [markdown]
# * Looking at the two files, one named gross and other named budget, it seems budgets file supersedes the gross movie file (has more entries and it contains production budget as well as gross income). So instead of merging, I will just use budgets file. The gross file might still contain some movies that do not existin budgets file, but without the production budget info, I cant do much there
#
# * Using the functions defined in the beginning of the notebook I will convert the columns with dollars info into floats so that I can calculate profit

# %%
convert_dollars_to_float(df_budgets_movie,'production_budget')
convert_dollars_to_float(df_budgets_movie,'domestic_gross')
convert_dollars_to_float(df_budgets_movie,'worldwide_gross')
# Out:
# 0       2.776345e+09
# 1       1.045664e+09
# 2       1.497624e+08
# 3       1.403014e+09
# 4       1.316722e+09
#             ...
# 5777    0.000000e+00
# 5778    2.404950e+05
# 5779    1.338000e+03
# 5780    0.000000e+00
# 5781    1.810410e+05
# Name: worldwide_gross, Length: 5782, dtype: float64

# %% [markdown]
# * I will define profit (in absolute dollars) using the worldwide gross income  and also domestic profit

# %%
df_budgets_movie['profit']     = df_budgets_movie['worldwide_gross']-df_budgets_movie['production_budget']
df_budgets_movie['profit_dom'] = df_budgets_movie['domestic_gross']-df_budgets_movie['production_budget']
df_budgets_movie
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross        profit  \
# 0           425000000.0     760507625.0     2.776345e+09  2.351345e+09
# 1           410600000.0     241063875.0     1.045664e+09  6.350639e+08
# 2           350000000.0      42762350.0     1.497624e+08 -2.002376e+08
# 3           330600000.0     459005868.0     1.403014e+09  1.072414e+09
# 4           317000000.0     620181382.0     1.316722e+09  9.997217e+08
# ...                 ...             ...              ...           ...
# 5777             7000.0             0.0     0.000000e+00 -7.000000e+03
# 5778             6000.0         48482.0     2.404950e+05  2.344950e+05
# 5779             5000.0          1338.0     1.338000e+03 -3.662000e+03
# 5780             1400.0             0.0     0.000000e+00 -1.400000e+03
# 5781             1100.0        181041.0     1.810410e+05  1.799410e+05
#
#        profit_dom
# 0     335507625.0
# 1    -169536125.0
# 2    -307237650.0
# 3     128405868.0
# 4     303181382.0
# ...           ...
# 5777      -7000.0
# 5778      42482.0
# 5779      -3662.0
# 5780      -1400.0
# 5781     179941.0
#
# [5782 rows x 8 columns]

# %%
df_budgets_movie.sort_values(by=['profit'], ascending=False).head(20)
# Out:
#      id  release_date                                          movie  \
# 0     1  Dec 18, 2009                                         Avatar
# 42   43  Dec 19, 1997                                        Titanic
# 6     7  Apr 27, 2018                         Avengers: Infinity War
# 5     6  Dec 18, 2015           Star Wars Ep. VII: The Force Awakens
# 33   34  Jun 12, 2015                                 Jurassic World
# 66   67   Apr 3, 2015                                      Furious 7
# 26   27   May 4, 2012                                   The Avengers
# 260  61  Jul 15, 2011  Harry Potter and the Deathly Hallows: Part II
# 41   42  Feb 16, 2018                                  Black Panther
# 112  13  Jun 22, 2018                 Jurassic World: Fallen Kingdom
# 155  56  Nov 22, 2013                                         Frozen
# 134  35  Mar 17, 2017                           Beauty and the Beast
# 672  73  Jul 10, 2015                                        Minions
# 3     4   May 1, 2015                        Avengers: Age of Ultron
# 425  26  Dec 17, 2003  The Lord of the Rings: The Return of the King
# 43   44  Jun 15, 2018                                  Incredibles 2
# 47   48   May 3, 2013                                     Iron Man 3
# 4     5  Dec 15, 2017              Star Wars Ep. VIII: The Last Jedi
# 135  36  Dec 21, 2018                                        Aquaman
# 22   23  Apr 14, 2017                        The Fate of the Furious
#
#      production_budget  domestic_gross  worldwide_gross        profit  \
# 0          425000000.0     760507625.0     2.776345e+09  2.351345e+09
# 42         200000000.0     659363944.0     2.208208e+09  2.008208e+09
# 6          300000000.0     678815482.0     2.048134e+09  1.748134e+09
# 5          306000000.0     936662225.0     2.053311e+09  1.747311e+09
# 33         215000000.0     652270625.0     1.648855e+09  1.433855e+09
# 66         190000000.0     353007020.0     1.518723e+09  1.328723e+09
# 26         225000000.0     623279547.0     1.517936e+09  1.292936e+09
# 260        125000000.0     381193157.0     1.341693e+09  1.216693e+09
# 41         200000000.0     700059566.0     1.348258e+09  1.148258e+09
# 112        170000000.0     417719760.0     1.305773e+09  1.135773e+09
# 155        150000000.0     400738009.0     1.272470e+09  1.122470e+09
# 134        160000000.0     504014165.0     1.259200e+09  1.099200e+09
# 672         74000000.0     336045770.0     1.160336e+09  1.086336e+09
# 3          330600000.0     459005868.0     1.403014e+09  1.072414e+09
# 425         94000000.0     377845905.0     1.141403e+09  1.047403e+09
# 43         200000000.0     608581744.0     1.242521e+09  1.042521e+09
# 47         200000000.0     408992272.0     1.215392e+09  1.015392e+09
# 4          317000000.0     620181382.0     1.316722e+09  9.997217e+08
# 135        160000000.0     335061807.0     1.146895e+09  9.868946e+08
# 22         250000000.0     225764765.0     1.234846e+09  9.848463e+08
#
#       profit_dom
# 0    335507625.0
# 42   459363944.0
# 6    378815482.0
# 5    630662225.0
# 33   437270625.0
# 66   163007020.0
# 26   398279547.0
# 260  256193157.0
# 41   500059566.0
# 112  247719760.0
# 155  250738009.0
# 134  344014165.0
# 672  262045770.0
# 3    128405868.0
# 425  283845905.0
# 43   408581744.0
# 47   208992272.0
# 4    303181382.0
# 135  175061807.0
# 22   -24235235.0

# %%
 #dftest.sort_values(by=['popularity'], ascending=False)
#print(df_gross_movie['title'].value_counts(), df_budgets_movie['movie'].value_counts(), df_Movie_comb['title'].value_counts())

# %% [markdown]
# * Reading the other csv files, these files have ids for genres, I probably will have to look at the API for these file at  "TheMovieDB" website/API. however I am short on time and so I will try to figure out some way to make use of this info
#
# * Since I have the movie name and release date, I could use this information to merge this table with the budgets table frm BoxOfficeDB and also the dataframe from IMDB SQL tables

# %%
#TheMovieDB" files
df_tmdb_movie = pd.read_csv("zippedData/tmdb.movies.csv",index_col=0)
df_tmdb_movie.head(50)
# Out:
#                    genre_ids     id original_language  \
# 0            [12, 14, 10751]  12444                en
# 1        [14, 12, 16, 10751]  10191                en
# 2              [12, 28, 878]  10138                en
# 3            [16, 35, 10751]    862                en
# 4              [28, 878, 12]  27205                en
# 5            [12, 14, 10751]  32657                en
# 6          [28, 12, 14, 878]  19995                en
# 7            [16, 10751, 35]  10193                en
# 8            [16, 10751, 35]  20352                en
# 9   [16, 28, 35, 10751, 878]  38055                en
# 10           [16, 35, 10751]    863                en
# 11           [10751, 14, 12]  12155                en
# 12              [53, 12, 28]  27578                en
# 13               [16, 10751]  38757                en
# 14                  [27, 80]  41439                en
# 15       [12, 14, 18, 10749]  24021                en
# 16             [28, 53, 878]  20504                en
# 17            [10402, 10749]  52371                nl
# 18              [28, 18, 53]   2502                en
# 19            [18, 53, 9648]  11324                en
# 20        [28, 18, 9648, 53]   2501                en
# 21                  [28, 35]  37834                en
# 22           [12, 10751, 14]  10140                en
# 23               [18, 10749]  41233                en
# 24      [53, 28, 12, 35, 80]  34544                en
# 25                  [18, 36]  45269                en
# 26          [28, 35, 80, 53]   9737                en
# 27       [28, 12, 10751, 14]  10196                en
# 28         [28, 878, 12, 53]  34851                en
# 29                      [18]  37799                en
# 30                  [28, 53]  38234                en
# 31                  [18, 36]    568                en
# 32         [28, 53, 878, 12]     95                en
# 33        [28, 18, 9648, 53]   2503                en
# 34              [12, 14, 28]  18823                en
# 35               [35, 10749]  34806                en
# 36              [28, 12, 18]  20662                en
# 37           [35, 14, 10751]  35019                en
# 38   [35, 12, 14, 16, 10751]  10192                en
# 39                      [35]  37735                en
# 40      [14, 12, 28, 35, 18]  27022                en
# 41           [28, 35, 10749]  22538                en
# 42                      [35]  38365                en
# 43               [35, 10749]    239                en
# 44          [80, 18, 28, 53]  41283                en
# 45                      [27]   7978                en
# 46                  [28, 53]  44048                en
# 47                  [18, 53]  44214                en
# 48       [16, 12, 10751, 14]  44683                en
# 49               [10749, 18]  61979                es
#
#                                        original_title  popularity  \
# 0        Harry Potter and the Deathly Hallows: Part 1      33.533
# 1                            How to Train Your Dragon      28.734
# 2                                          Iron Man 2      28.515
# 3                                           Toy Story      28.005
# 4                                           Inception      27.920
# 5   Percy Jackson & the Olympians: The Lightning T...      26.691
# 6                                              Avatar      26.526
# 7                                         Toy Story 3      24.445
# 8                                       Despicable Me      23.673
# 9                                            Megamind      22.855
# 10                                        Toy Story 2      22.698
# 11                                Alice in Wonderland      22.020
# 12                                    The Expendables      21.517
# 13                                            Tangled      21.511
# 14                                             Saw 3D      20.370
# 15                         The Twilight Saga: Eclipse      20.340
# 16                                    The Book of Eli      18.985
# 17                                         LelleBelle      18.586
# 18                               The Bourne Supremacy      18.199
# 19                                     Shutter Island      18.060
# 20                                The Bourne Identity      17.935
# 21                                     Knight and Day      17.713
# 22  The Chronicles of Narnia: The Voyage of the Da...      17.382
# 23                                         Step Up 3D      17.174
# 24                                         The A-Team      17.097
# 25                                  The King's Speech      16.798
# 26                                           Bad Boys      16.608
# 27                                 The Last Airbender      16.595
# 28                                          Predators      16.216
# 29                                 The Social Network      15.889
# 30                         Undisputed III: Redemption      15.886
# 31                                          Apollo 13      15.855
# 32                                         Armageddon      15.799
# 33                               The Bourne Ultimatum      15.620
# 34                                Clash of the Titans      15.574
# 35                                   The Back-Up Plan      15.490
# 36                                         Robin Hood      15.444
# 37                      Nanny McPhee and the Big Bang      15.213
# 38                                Shrek Forever After      15.041
# 39                                             Easy A      14.690
# 40                          The Sorcerer's Apprentice      14.463
# 41                        Scott Pilgrim vs. the World      14.383
# 42                                          Grown Ups      14.291
# 43                                   Some Like It Hot      14.200
# 44                                             Faster      14.172
# 45                                        The Wolfman      14.030
# 46                                        Unstoppable      14.010
# 47                                         Black Swan      13.745
# 48             Tinker Bell and the Great Fairy Rescue      13.724
# 49                         Tres metros sobre el cielo      13.721
#
#    release_date                                              title  \
# 0    2010-11-19       Harry Potter and the Deathly Hallows: Part 1
# 1    2010-03-26                           How to Train Your Dragon
# 2    2010-05-07                                         Iron Man 2
# 3    1995-11-22                                          Toy Story
# 4    2010-07-16                                          Inception
# 5    2010-02-11  Percy Jackson & the Olympians: The Lightning T...
# 6    2009-12-18                                             Avatar
# 7    2010-06-17                                        Toy Story 3
# 8    2010-07-09                                      Despicable Me
# 9    2010-11-04                                           Megamind
# 10   1999-11-24                                        Toy Story 2
# 11   2010-03-05                                Alice in Wonderland
# 12   2010-08-03                                    The Expendables
# 13   2010-11-24                                            Tangled
# 14   2010-10-28                             Saw: The Final Chapter
# 15   2010-06-23                         The Twilight Saga: Eclipse
# 16   2010-01-11                                    The Book of Eli
# 17   2010-10-09                                         LelleBelle
# 18   2004-07-23                               The Bourne Supremacy
# 19   2010-02-18                                     Shutter Island
# 20   2002-06-14                                The Bourne Identity
# 21   2010-06-23                                     Knight and Day
# 22   2010-12-10  The Chronicles of Narnia: The Voyage of the Da...
# 23   2010-08-06                                         Step Up 3D
# 24   2010-06-11                                         The A-Team
# 25   2010-09-06                                  The King's Speech
# 26   1995-04-07                                           Bad Boys
# 27   2010-07-01                                 The Last Airbender
# 28   2010-07-03                                          Predators
# 29   2010-10-01                                 The Social Network
# 30   2010-05-22                         Undisputed III: Redemption
# 31   1995-06-30                                          Apollo 13
# 32   1998-07-01                                         Armageddon
# 33   2007-08-03                               The Bourne Ultimatum
# 34   2010-04-02                                Clash of the Titans
# 35   2010-04-23                                   The Back-Up Plan
# 36   2010-05-14                                         Robin Hood
# 37   2010-08-20                      Nanny McPhee and the Big Bang
# 38   2010-05-16                                Shrek Forever After
# 39   2010-09-17                                             Easy A
# 40   2010-07-13                          The Sorcerer's Apprentice
# 41   2010-08-13                        Scott Pilgrim vs. the World
# 42   2010-06-24                                          Grown Ups
# 43   1959-03-18                                   Some Like It Hot
# 44   2010-11-23                                             Faster
# 45   2010-02-12                                        The Wolfman
# 46   2010-11-12                                        Unstoppable
# 47   2010-12-03                                         Black Swan
# 48   2010-09-21             Tinker Bell and the Great Fairy Rescue
# 49   2010-12-20                           Three Steps Above Heaven
#
#     vote_average  vote_count
# 0            7.7       10788
# 1            7.7        7610
# 2            6.8       12368
# 3            7.9       10174
# 4            8.3       22186
# 5            6.1        4229
# 6            7.4       18676
# 7            7.7        8340
# 8            7.2       10057
# 9            6.8        3635
# 10           7.5        7553
# 11           6.6        8713
# 12           6.1        4647
# 13           7.5        6407
# 14           6.0        1488
# 15           6.0        4909
# 16           6.7        3495
# 17           4.5          36
# 18           7.3        4367
# 19           8.1       12625
# 20           7.4        5406
# 21           6.0        2494
# 22           6.3        3196
# 23           6.7        1160
# 24           6.3        2703
# 25           7.7        5013
# 26           6.6        2936
# 27           4.6        2143
# 28           6.1        1979
# 29           7.2        6116
# 30           7.4         302
# 31           7.4        2821
# 32           6.7        4267
# 33           7.4        4440
# 34           5.7        3714
# 35           6.0         806
# 36           6.3        2569
# 37           6.1         953
# 38           6.1        3843
# 39           6.8        4168
# 40           5.9        2879
# 41           7.3        3882
# 42           6.1        3171
# 43           8.2        1562
# 44           6.2         895
# 45           5.7        1009
# 46           6.4        1913
# 47           7.6        8374
# 48           6.5         451
# 49           7.5         960

# %%
df_tmdb_movie[df_tmdb_movie["original_title"]!=df_tmdb_movie["title"]]
# Out:
#                    genre_ids      id original_language  \
# 14                  [27, 80]   41439                en
# 49               [10749, 18]   61979                es
# 67       [16, 12, 14, 10751]   42949                en
# 70     [80, 18, 9648, 10749]   25376                es
# 75                      [16]   28874                ja
# ...                      ...     ...               ...
# 26409            [10749, 18]  551634                zh
# 26422                   [14]  517676                es
# 26432               [18, 35]  467746                fr
# 26494                   [18]  567020                es
# 26507                   [99]  545555                ar
#
#                             original_title  popularity release_date  \
# 14                                  Saw 3D      20.370   2010-10-28
# 49              Tres metros sobre el cielo      13.721   2010-12-20
# 67     Arthur 3: la guerre des deux mondes      12.679   2010-08-22
# 70                  El secreto de sus ojos      12.531   2010-04-16
# 75                                 サマーウォーズ      12.275   2010-10-13
# ...                                    ...         ...          ...
# 26409                                你好，之华       0.600   2018-11-09
# 26422         El verano del león eléctrico       0.600   2018-11-12
# 26432                    Contes de Juillet       0.600   2018-03-09
# 26494                     La última virgen       0.600   2018-05-26
# 26507                            Dreamaway       0.600   2018-10-14
#
#                                      title  vote_average  vote_count
# 14                  Saw: The Final Chapter           6.0        1488
# 49                Three Steps Above Heaven           7.5         960
# 67     Arthur 3: The War of the Two Worlds           5.6         865
# 70                The Secret in Their Eyes           7.9        1141
# 75                             Summer Wars           7.5         447
# ...                                    ...           ...         ...
# 26409                          Last Letter           6.0           1
# 26422      The Summer of the Electric Lion           6.0           1
# 26432                           July Tales           6.0           1
# 26494                      The Last Virgin           2.0           1
# 26507                           Dream Away           0.0           2
#
# [2544 rows x 9 columns]

# %%
#This gives strange output, I dont see any duplicates
df_tmdb_movie[df_tmdb_movie.duplicated()==True]
# Out:
#                     genre_ids      id original_language  \
# 2473          [16, 35, 10751]     862                en
# 2477          [16, 35, 10751]     863                en
# 2536            [12, 28, 878]   20526                en
# 2673              [18, 10749]   46705                en
# 2717   [35, 18, 14, 27, 9648]   45649                en
# ...                       ...     ...               ...
# 26481                [35, 18]  270805                en
# 26485                [27, 53]  453259                en
# 26504            [27, 35, 27]  534282                en
# 26510                    [99]  495045                en
# 26511                    [99]  492837                en
#
#                original_title  popularity release_date  \
# 2473                Toy Story      28.005   1995-11-22
# 2477              Toy Story 2      22.698   1999-11-24
# 2536             TRON: Legacy      13.459   2010-12-10
# 2673           Blue Valentine       8.994   2010-12-29
# 2717                   Rubber       8.319   2010-09-01
# ...                       ...         ...          ...
# 26481           Summer League       0.600   2013-03-18
# 26485  Devils in the Darkness       0.600   2013-05-15
# 26504                    Head       0.600   2015-03-28
# 26510              Fail State       0.600   2018-10-19
# 26511       Making Filmmakers       0.600   2018-04-07
#
#                         title  vote_average  vote_count
# 2473                Toy Story           7.9       10174
# 2477              Toy Story 2           7.5        7553
# 2536             TRON: Legacy           6.3        4387
# 2673           Blue Valentine           6.9        1677
# 2717                   Rubber           5.9         417
# ...                       ...           ...         ...
# 26481           Summer League           4.0           3
# 26485  Devils in the Darkness           3.5           1
# 26504                    Head           1.0           1
# 26510              Fail State           0.0           1
# 26511       Making Filmmakers           0.0           1
#
# [907 rows x 9 columns]

# %%
df_tmdb_movie=df_tmdb_movie[df_tmdb_movie["original_language"]=="en"]

# %%
df_tmdb_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23291 entries, 0 to 26516
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   genre_ids          23291 non-null  object
#  1   id                 23291 non-null  int64
#  2   original_language  23291 non-null  object
#  3   original_title     23291 non-null  object
#  4   popularity         23291 non-null  float64
#  5   release_date       23291 non-null  object
#  6   title              23291 non-null  object
#  7   vote_average       23291 non-null  float64
#  8   vote_count         23291 non-null  int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 1.8+ MB

# %%
df_tmdb_movie['title'].value_counts()
# Out:
# Eden                                                        7
# Home                                                        6
# The Gift                                                    5
# Legend                                                      5
# Lucky                                                       5
#                                                            ..
# Present                                                     1
# Repatriation                                                1
# Morgan and Destiny's Eleventeenth Date: The Zeppelin Zoo    1
# B.B. King: The Life of Riley                                1
# Moontrap: Target Earth                                      1
# Name: title, Length: 21771, dtype: int64

# %%
df_tmdb_movie[df_tmdb_movie["original_title"]!=df_tmdb_movie["title"]]
# Out:
#                  genre_ids      id original_language  \
# 14                [27, 80]   41439                en
# 67     [16, 12, 14, 10751]   42949                en
# 191           [28, 12, 53]   44918                en
# 568               [27, 53]   57018                en
# 578    [10752, 14, 28, 18]   36699                en
# ...                    ...     ...               ...
# 25791          [53, 10770]  555185                en
# 25824                 [18]  416369                en
# 26252          [99, 10402]  501350                en
# 26365             [27, 35]  536638                en
# 26368             [35, 14]  528229                en
#
#                                           original_title  popularity  \
# 14                                                Saw 3D      20.370
# 67                   Arthur 3: la guerre des deux mondes      12.679
# 191                                           Titanic II       8.729
# 568                                              Captifs       3.353
# 578                                  My Iz Budushchego 2       3.275
# ...                                                  ...         ...
# 25791                                   Eve of Abduction       1.480
# 25824                                       Migas de pan       1.400
# 26252  The Doors: Live at the Isle of Wight Festival ...       0.600
# 26365                                     Holy Pepperoni       0.600
# 26368                                     Super-Vieillot       0.600
#
#       release_date                                              title  \
# 14      2010-10-28                             Saw: The Final Chapter
# 67      2010-08-22                Arthur 3: The War of the Two Worlds
# 191     2010-08-24                                          Titanic 2
# 568     2010-10-16                                              Caged
# 578     2010-11-11                           We Are from the Future 2
# ...            ...                                                ...
# 25791   2018-06-01                             My Little Girl Is Gone
# 25824   2018-08-14                                        Breadcrumbs
# 26252   2018-02-23  The Doors - Live at the Isle of Wight Festival...
# 26365   2018-07-19                                        Deliverynce
# 26368   2018-02-10                                        The Old Men
#
#        vote_average  vote_count
# 14              6.0        1488
# 67              5.6         865
# 191             3.2          90
# 568             5.5          47
# 578             5.3          25
# ...             ...         ...
# 25791           5.0           1
# 25824           6.0           2
# 26252          10.0           1
# 26365           7.0           1
# 26368           7.0           1
#
# [335 rows x 9 columns]

# %%
df_tmdb_movie[df_tmdb_movie['title']=='Home']
# Out:
#                       genre_ids      id original_language original_title  \
# 9651                         []  237303                en           Home
# 14262  [14, 35, 16, 878, 10751]  228161                en           Home
# 19580                        []  409371                en           Home
# 20446           [27, 18, 10751]  381507                en           Home
# 20455                      [18]  388223                en           Home
# 23694                     [878]  496256                en           Home
#
#        popularity release_date title  vote_average  vote_count
# 9651        0.840   2013-11-22  Home           7.0           2
# 14262      12.835   2015-03-27  Home           6.8        2372
# 19580       0.672   2016-08-01  Home           7.0           1
# 20446       0.600   2016-03-01  Home           4.7          14
# 20455       0.600   2016-03-17  Home           4.5           2
# 23694       0.600   2017-04-30  Home           4.0           1

# %% [markdown]
# * This output above for "Home" movie has some strange entries with release dates different only by days. I dont know what to do with this type of outputs

# %%
#df.style.format({"DOB": lambda t: t.strftime("%m/%d/%Y")})
#df_budgets_movie.style.format({"release_date": lambda t: t.strftime("%Y-%m-%d")})
#df_budgets_movie['release_date'] = pd.to_datetime(df_budgets_movie['release_date'])

# %% [markdown]
# * Changing the release_date column to datetime object and a format that I plan to use for tmdb data table as well so that I can merge on them

# %%
df_budgets_movie['release_date'] = pd.to_datetime(df_budgets_movie['release_date'])
df_budgets_movie.style.format({"release_date": lambda t: t.strftime("%Y-%m-%d")})
df_budgets_movie
# Out:
#       id release_date                                        movie  \
# 0      1   2009-12-18                                       Avatar
# 1      2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2      3   2019-06-07                                 Dark Phoenix
# 3      4   2015-05-01                      Avengers: Age of Ultron
# 4      5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
# ...   ..          ...                                          ...
# 5777  78   2018-12-31                                       Red 11
# 5778  79   1999-04-02                                    Following
# 5779  80   2005-07-13                Return to the Land of Wonders
# 5780  81   2015-09-29                         A Plague So Pleasant
# 5781  82   2005-08-05                            My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross        profit  \
# 0           425000000.0     760507625.0     2.776345e+09  2.351345e+09
# 1           410600000.0     241063875.0     1.045664e+09  6.350639e+08
# 2           350000000.0      42762350.0     1.497624e+08 -2.002376e+08
# 3           330600000.0     459005868.0     1.403014e+09  1.072414e+09
# 4           317000000.0     620181382.0     1.316722e+09  9.997217e+08
# ...                 ...             ...              ...           ...
# 5777             7000.0             0.0     0.000000e+00 -7.000000e+03
# 5778             6000.0         48482.0     2.404950e+05  2.344950e+05
# 5779             5000.0          1338.0     1.338000e+03 -3.662000e+03
# 5780             1400.0             0.0     0.000000e+00 -1.400000e+03
# 5781             1100.0        181041.0     1.810410e+05  1.799410e+05
#
#        profit_dom
# 0     335507625.0
# 1    -169536125.0
# 2    -307237650.0
# 3     128405868.0
# 4     303181382.0
# ...           ...
# 5777      -7000.0
# 5778      42482.0
# 5779      -3662.0
# 5780      -1400.0
# 5781     179941.0
#
# [5782 rows x 8 columns]

# %%
df_tmdb_movie['release_date'] = pd.to_datetime(df_tmdb_movie['release_date'])
df_tmdb_movie.style.format({"release_date": lambda t: t.strftime("%Y-%m-%d")})
df_tmdb_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23291 entries, 0 to 26516
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   genre_ids          23291 non-null  object
#  1   id                 23291 non-null  int64
#  2   original_language  23291 non-null  object
#  3   original_title     23291 non-null  object
#  4   popularity         23291 non-null  float64
#  5   release_date       23291 non-null  datetime64[ns]
#  6   title              23291 non-null  object
#  7   vote_average       23291 non-null  float64
#  8   vote_count         23291 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 2.4+ MB

# %% [markdown]
# * Lets merge budgets information with popularity and vote info from tmdb file

# %%
df_budg_tmdb=pd.merge(df_budgets_movie,df_tmdb_movie,how='inner',left_on='movie', right_on='title')
df_budg_tmdb
# Out:
#       id_x release_date_x                                        movie  \
# 0        1     2009-12-18                                       Avatar
# 1        2     2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2        4     2015-05-01                      Avengers: Age of Ultron
# 3        7     2018-04-27                       Avengers: Infinity War
# 4        9     2017-11-17                               Justice League
# ...    ...            ...                                          ...
# 2250    49     2015-09-01                                       Exeter
# 2251    51     2015-04-21                                          Ten
# 2252    54     2014-12-31                                    Dry Spell
# 2253    56     2013-01-04                     All Superheroes Must Die
# 2254    73     2012-01-13                                    Newlyweds
#
#       production_budget  domestic_gross  worldwide_gross        profit  \
# 0           425000000.0     760507625.0     2.776345e+09  2.351345e+09
# 1           410600000.0     241063875.0     1.045664e+09  6.350639e+08
# 2           330600000.0     459005868.0     1.403014e+09  1.072414e+09
# 3           300000000.0     678815482.0     2.048134e+09  1.748134e+09
# 4           300000000.0     229024295.0     6.559452e+08  3.559452e+08
# ...                 ...             ...              ...           ...
# 2250            25000.0             0.0     4.897920e+05  4.647920e+05
# 2251            25000.0             0.0     0.000000e+00 -2.500000e+04
# 2252            22000.0             0.0     0.000000e+00 -2.200000e+04
# 2253            20000.0             0.0     0.000000e+00 -2.000000e+04
# 2254             9000.0          4584.0     4.584000e+03 -4.416000e+03
#
#        profit_dom           genre_ids    id_y original_language  \
# 0     335507625.0   [28, 12, 14, 878]   19995                en
# 1    -169536125.0        [12, 28, 14]    1865                en
# 2     128405868.0       [28, 12, 878]   99861                en
# 3     378815482.0        [12, 28, 14]  299536                en
# 4     -70975705.0   [28, 12, 14, 878]  141052                en
# ...           ...                 ...     ...               ...
# 2250     -25000.0            [53, 27]  226458                en
# 2251     -25000.0  [12, 27, 9648, 53]  279516                en
# 2252     -22000.0         [35, 10749]  255266                en
# 2253     -20000.0           [878, 53]   86304                en
# 2254      -4416.0         [35, 10749]   72766                en
#
#                                    original_title  popularity release_date_y  \
# 0                                          Avatar      26.526     2009-12-18
# 1     Pirates of the Caribbean: On Stranger Tides      30.579     2011-05-20
# 2                         Avengers: Age of Ultron      44.383     2015-05-01
# 3                          Avengers: Infinity War      80.773     2018-04-27
# 4                                  Justice League      34.953     2017-11-17
# ...                                           ...         ...            ...
# 2250                                       Exeter       5.934     2015-03-26
# 2251                                          Ten       1.575     2014-03-28
# 2252                                    Dry Spell       0.600     2013-02-14
# 2253                     All Superheroes Must Die       2.078     2013-01-04
# 2254                                    Newlyweds       1.973     2011-12-26
#
#                                             title  vote_average  vote_count
# 0                                          Avatar           7.4       18676
# 1     Pirates of the Caribbean: On Stranger Tides           6.4        8571
# 2                         Avengers: Age of Ultron           7.3       13457
# 3                          Avengers: Infinity War           8.3       13948
# 4                                  Justice League           6.2        7510
# ...                                           ...           ...         ...
# 2250                                       Exeter           4.7         121
# 2251                                          Ten           5.4           5
# 2252                                    Dry Spell           6.0           1
# 2253                     All Superheroes Must Die           3.9          19
# 2254                                    Newlyweds           5.4           7
#
# [2255 rows x 17 columns]

# %%
df_budg_tmdb[df_budg_tmdb.duplicated()==True]
df_budg_tmdb[df_budg_tmdb['title']=='Justice League']
# Out:
#    id_x release_date_x           movie  production_budget  domestic_gross  \
# 4     9     2017-11-17  Justice League        300000000.0     229024295.0
# 5     9     2017-11-17  Justice League        300000000.0     229024295.0
#
#    worldwide_gross       profit  profit_dom          genre_ids    id_y  \
# 4      655945209.0  355945209.0 -70975705.0  [28, 12, 14, 878]  141052
# 5      655945209.0  355945209.0 -70975705.0  [28, 12, 14, 878]  141052
#
#   original_language  original_title  popularity release_date_y  \
# 4                en  Justice League      34.953     2017-11-17
# 5                en  Justice League      34.953     2017-11-17
#
#             title  vote_average  vote_count
# 4  Justice League           6.2        7510
# 5  Justice League           6.2        7510

# %%
# the merged tables from those two dataframes has some wrong entries when the names of the movie were identical
# but they were released in different years (remakes etc). To get rid of those, I restrict to only those entries
# where release dates are exact same
dftest2=df_budg_tmdb[df_budg_tmdb['release_date_x']==df_budg_tmdb['release_date_y']]
dftest2
# Out:
#       id_x release_date_x                                        movie  \
# 0        1     2009-12-18                                       Avatar
# 1        2     2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2        4     2015-05-01                      Avengers: Age of Ultron
# 3        7     2018-04-27                       Avengers: Infinity War
# 4        9     2017-11-17                               Justice League
# ...    ...            ...                                          ...
# 2235    22     2014-02-14                           Down and Dangerous
# 2237    25     2015-09-01                               Run, Hide, Die
# 2247    38     2016-03-18                                       Krisha
# 2248    38     2016-03-18                                       Krisha
# 2253    56     2013-01-04                     All Superheroes Must Die
#
#       production_budget  domestic_gross  worldwide_gross        profit  \
# 0           425000000.0     760507625.0     2.776345e+09  2.351345e+09
# 1           410600000.0     241063875.0     1.045664e+09  6.350639e+08
# 2           330600000.0     459005868.0     1.403014e+09  1.072414e+09
# 3           300000000.0     678815482.0     2.048134e+09  1.748134e+09
# 4           300000000.0     229024295.0     6.559452e+08  3.559452e+08
# ...                 ...             ...              ...           ...
# 2235            50000.0             0.0     0.000000e+00 -5.000000e+04
# 2237            50000.0             0.0     0.000000e+00 -5.000000e+04
# 2247            30000.0        144822.0     1.448220e+05  1.148220e+05
# 2248            30000.0        144822.0     1.448220e+05  1.148220e+05
# 2253            20000.0             0.0     0.000000e+00 -2.000000e+04
#
#        profit_dom          genre_ids    id_y original_language  \
# 0     335507625.0  [28, 12, 14, 878]   19995                en
# 1    -169536125.0       [12, 28, 14]    1865                en
# 2     128405868.0      [28, 12, 878]   99861                en
# 3     378815482.0       [12, 28, 14]  299536                en
# 4     -70975705.0  [28, 12, 14, 878]  141052                en
# ...           ...                ...     ...               ...
# 2235     -50000.0       [80, 53, 18]  164286                en
# 2237     -50000.0           [53, 27]  290391                en
# 2247     114822.0               [18]  323929                en
# 2248     114822.0               [18]  323929                en
# 2253     -20000.0          [878, 53]   86304                en
#
#                                    original_title  popularity release_date_y  \
# 0                                          Avatar      26.526     2009-12-18
# 1     Pirates of the Caribbean: On Stranger Tides      30.579     2011-05-20
# 2                         Avengers: Age of Ultron      44.383     2015-05-01
# 3                          Avengers: Infinity War      80.773     2018-04-27
# 4                                  Justice League      34.953     2017-11-17
# ...                                           ...         ...            ...
# 2235                           Down and Dangerous       2.621     2014-02-14
# 2237                               Run, Hide, Die       0.600     2015-09-01
# 2247                                       Krisha       5.288     2016-03-18
# 2248                                       Krisha       5.288     2016-03-18
# 2253                     All Superheroes Must Die       2.078     2013-01-04
#
#                                             title  vote_average  vote_count
# 0                                          Avatar           7.4       18676
# 1     Pirates of the Caribbean: On Stranger Tides           6.4        8571
# 2                         Avengers: Age of Ultron           7.3       13457
# 3                          Avengers: Infinity War           8.3       13948
# 4                                  Justice League           6.2        7510
# ...                                           ...           ...         ...
# 2235                           Down and Dangerous           4.3           9
# 2237                               Run, Hide, Die           3.5           2
# 2247                                       Krisha           6.8          86
# 2248                                       Krisha           6.8          86
# 2253                     All Superheroes Must Die           3.9          19
#
# [1373 rows x 17 columns]

# %%
df_budg_tmdb.shape
# Out:
# (2255, 17)

# %%
dftest2.shape
# Out:
# (1373, 17)

# %%
df_budg_tmdb[df_budg_tmdb['title']=='Justice League']
# Out:
#    id_x release_date_x           movie  production_budget  domestic_gross  \
# 4     9     2017-11-17  Justice League        300000000.0     229024295.0
# 5     9     2017-11-17  Justice League        300000000.0     229024295.0
#
#    worldwide_gross       profit  profit_dom          genre_ids    id_y  \
# 4      655945209.0  355945209.0 -70975705.0  [28, 12, 14, 878]  141052
# 5      655945209.0  355945209.0 -70975705.0  [28, 12, 14, 878]  141052
#
#   original_language  original_title  popularity release_date_y  \
# 4                en  Justice League      34.953     2017-11-17
# 5                en  Justice League      34.953     2017-11-17
#
#             title  vote_average  vote_count
# 4  Justice League           6.2        7510
# 5  Justice League           6.2        7510

# %%
dftest2[dftest2['title']=='Avatar']
# Out:
#    id_x release_date_x   movie  production_budget  domestic_gross  \
# 0     1     2009-12-18  Avatar        425000000.0     760507625.0
#
#    worldwide_gross        profit   profit_dom          genre_ids   id_y  \
# 0     2.776345e+09  2.351345e+09  335507625.0  [28, 12, 14, 878]  19995
#
#   original_language original_title  popularity release_date_y   title  \
# 0                en         Avatar      26.526     2009-12-18  Avatar
#
#    vote_average  vote_count
# 0           7.4       18676

# %%
df_budg_tmdb = df_budg_tmdb.drop_duplicates()
dftest2      = dftest2.drop_duplicates()

# %%
print(df_budg_tmdb.shape,dftest2.shape)
# Out:
# (2087, 17) (1244, 17)

# %%
dftest2['movie'].value_counts()
# Out:
# Legend                2
# Robin Hood            2
# Survivor              1
# The Three Stooges     1
# Stranded              1
#                      ..
# Blended               1
# Walter                1
# Paterson              1
# The First Time        1
# I Can Only Imagine    1
# Name: movie, Length: 1242, dtype: int64

# %%
dftest2=dftest2[dftest2['original_language']=='en']
dftest2['movie'].value_counts()
# Out:
# Legend                2
# Robin Hood            2
# Survivor              1
# The Three Stooges     1
# Stranded              1
#                      ..
# Blended               1
# Walter                1
# Paterson              1
# The First Time        1
# I Can Only Imagine    1
# Name: movie, Length: 1242, dtype: int64

# %%
#dftest2=dftest2.drop_duplicates(subset='release_date_y', keep="first & last")
#dftest2=dftest2.drop_duplicates()
#dftest2[dftest2['title']=='Robin Hood']
dftest2
# Out:
#       id_x release_date_x                                        movie  \
# 0        1     2009-12-18                                       Avatar
# 1        2     2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2        4     2015-05-01                      Avengers: Age of Ultron
# 3        7     2018-04-27                       Avengers: Infinity War
# 4        9     2017-11-17                               Justice League
# ...    ...            ...                                          ...
# 2234    20     2015-07-31                                     Counting
# 2235    22     2014-02-14                           Down and Dangerous
# 2237    25     2015-09-01                               Run, Hide, Die
# 2247    38     2016-03-18                                       Krisha
# 2253    56     2013-01-04                     All Superheroes Must Die
#
#       production_budget  domestic_gross  worldwide_gross        profit  \
# 0           425000000.0     760507625.0     2.776345e+09  2.351345e+09
# 1           410600000.0     241063875.0     1.045664e+09  6.350639e+08
# 2           330600000.0     459005868.0     1.403014e+09  1.072414e+09
# 3           300000000.0     678815482.0     2.048134e+09  1.748134e+09
# 4           300000000.0     229024295.0     6.559452e+08  3.559452e+08
# ...                 ...             ...              ...           ...
# 2234            50000.0          8374.0     8.374000e+03 -4.162600e+04
# 2235            50000.0             0.0     0.000000e+00 -5.000000e+04
# 2237            50000.0             0.0     0.000000e+00 -5.000000e+04
# 2247            30000.0        144822.0     1.448220e+05  1.148220e+05
# 2253            20000.0             0.0     0.000000e+00 -2.000000e+04
#
#        profit_dom          genre_ids    id_y original_language  \
# 0     335507625.0  [28, 12, 14, 878]   19995                en
# 1    -169536125.0       [12, 28, 14]    1865                en
# 2     128405868.0      [28, 12, 878]   99861                en
# 3     378815482.0       [12, 28, 14]  299536                en
# 4     -70975705.0  [28, 12, 14, 878]  141052                en
# ...           ...                ...     ...               ...
# 2234     -41626.0               [99]  322745                en
# 2235     -50000.0       [80, 53, 18]  164286                en
# 2237     -50000.0           [53, 27]  290391                en
# 2247     114822.0               [18]  323929                en
# 2253     -20000.0          [878, 53]   86304                en
#
#                                    original_title  popularity release_date_y  \
# 0                                          Avatar      26.526     2009-12-18
# 1     Pirates of the Caribbean: On Stranger Tides      30.579     2011-05-20
# 2                         Avengers: Age of Ultron      44.383     2015-05-01
# 3                          Avengers: Infinity War      80.773     2018-04-27
# 4                                  Justice League      34.953     2017-11-17
# ...                                           ...         ...            ...
# 2234                                     Counting       0.600     2015-07-31
# 2235                           Down and Dangerous       2.621     2014-02-14
# 2237                               Run, Hide, Die       0.600     2015-09-01
# 2247                                       Krisha       5.288     2016-03-18
# 2253                     All Superheroes Must Die       2.078     2013-01-04
#
#                                             title  vote_average  vote_count
# 0                                          Avatar           7.4       18676
# 1     Pirates of the Caribbean: On Stranger Tides           6.4        8571
# 2                         Avengers: Age of Ultron           7.3       13457
# 3                          Avengers: Infinity War           8.3       13948
# 4                                  Justice League           6.2        7510
# ...                                           ...           ...         ...
# 2234                                     Counting           8.3           3
# 2235                           Down and Dangerous           4.3           9
# 2237                               Run, Hide, Die           3.5           2
# 2247                                       Krisha           6.8          86
# 2253                     All Superheroes Must Die           3.9          19
#
# [1244 rows x 17 columns]

# %% [markdown]
# * Create a small dataframe with only a few columns that I want to use

# %%
df_budg_tmdb[df_budg_tmdb['title']=='Legend']
# Out:
#       id_x release_date_x   movie  production_budget  domestic_gross  \
# 999     63     1986-04-18  Legend         25000000.0      15502112.0
# 1001    63     1986-04-18  Legend         25000000.0      15502112.0
# 1004    10     2015-11-20  Legend         25000000.0       1872994.0
# 1006    10     2015-11-20  Legend         25000000.0       1872994.0
#
#       worldwide_gross      profit  profit_dom genre_ids    id_y  \
# 999        23506237.0  -1493763.0  -9497888.0  [12, 14]   11976
# 1001       23506237.0  -1493763.0  -9497888.0  [80, 53]  276907
# 1004       42425450.0  17425450.0 -23127006.0  [12, 14]   11976
# 1006       42425450.0  17425450.0 -23127006.0  [80, 53]  276907
#
#      original_language original_title  popularity release_date_y   title  \
# 999                 en         Legend      10.542     1986-04-18  Legend
# 1001                en         Legend      10.195     2015-11-20  Legend
# 1004                en         Legend      10.542     1986-04-18  Legend
# 1006                en         Legend      10.195     2015-11-20  Legend
#
#       vote_average  vote_count
# 999            6.2         509
# 1001           6.8        1692
# 1004           6.2         509
# 1006           6.8        1692

# %%
dftest2[dftest2['title']=='Legend']
# Out:
#       id_x release_date_x   movie  production_budget  domestic_gross  \
# 999     63     1986-04-18  Legend         25000000.0      15502112.0
# 1006    10     2015-11-20  Legend         25000000.0       1872994.0
#
#       worldwide_gross      profit  profit_dom genre_ids    id_y  \
# 999        23506237.0  -1493763.0  -9497888.0  [12, 14]   11976
# 1006       42425450.0  17425450.0 -23127006.0  [80, 53]  276907
#
#      original_language original_title  popularity release_date_y   title  \
# 999                 en         Legend      10.542     1986-04-18  Legend
# 1006                en         Legend      10.195     2015-11-20  Legend
#
#       vote_average  vote_count
# 999            6.2         509
# 1006           6.8        1692

# %%
df_profit_pop =dftest2[['movie','profit','profit_dom','popularity','vote_average']].copy()

# %%
#dftest_new.sort_values(by=['profit','popularity','vote_average'], ascending=False,inplace=True)
df_profit_pop.sort_values(by=['profit'], ascending=False,inplace=True)
df_profit_pop =df_profit_pop.reset_index()
df_small=df_profit_pop.loc[0:20]
df_small
# Out:
#     index                            movie        profit   profit_dom  \
# 0       0                           Avatar  2.351345e+09  335507625.0
# 1       3           Avengers: Infinity War  1.748134e+09  378815482.0
# 2      26                   Jurassic World  1.433855e+09  437270625.0
# 3      59                        Furious 7  1.328723e+09  163007020.0
# 4      20                     The Avengers  1.292936e+09  398279547.0
# 5      36                    Black Panther  1.148258e+09  500059566.0
# 6      96   Jurassic World: Fallen Kingdom  1.135773e+09  247719760.0
# 7     115             Beauty and the Beast  1.099200e+09  344014165.0
# 8     402                          Minions  1.086336e+09  262045770.0
# 9       2          Avengers: Age of Ultron  1.072414e+09  128405868.0
# 10     37                    Incredibles 2  1.042521e+09  408581744.0
# 11     42                       Iron Man 3  1.015392e+09  208992272.0
# 12    118                          Aquaman  9.868946e+08  175061807.0
# 13     18          The Fate of the Furious  9.848463e+08  -24235235.0
# 14    388                  Despicable Me 3  9.597278e+08  189624300.0
# 15    384                  Despicable Me 2  8.992168e+08  292065385.0
# 16     28  Transformers: Age of Extinction  8.940391e+08   35439076.0
# 17     13       Captain America: Civil War  8.900694e+08  158084349.0
# 18    317   Jumanji: Welcome to the Jungle  8.744962e+08  314508916.0
# 19    136                         Zootopia  8.694296e+08  191268248.0
# 20     38     Rogue One: A Star Wars Story  8.491029e+08  332177324.0
#
#     popularity  vote_average
# 0       26.526           7.4
# 1       80.773           8.3
# 2       20.709           6.6
# 3       20.396           7.3
# 4       50.289           7.6
# 5       44.140           7.4
# 6       34.958           6.5
# 7       31.793           6.9
# 8        9.338           6.4
# 9       44.383           7.3
# 10      36.286           7.6
# 11      32.093           6.9
# 12      38.102           6.8
# 13      28.668           6.9
# 14      16.407           6.3
# 15      19.014           6.9
# 16      20.961           5.8
# 17      39.137           7.4
# 18      20.395           6.7
# 19      27.549           7.7
# 20      21.401           7.5

# %% [markdown]
# * I am normalizing each column by its mean value so that I can plot popularity, profit and vote average on same plot. This may not be very kosher but I think its okay for this study. I could have used pandas/numpy normalization function but at th

# %%
df_small['profit']      =df_small['profit']/df_small['profit'].mean()
df_small['profit_dom']  =df_small['profit_dom']/df_small['profit_dom'].mean()
df_small['popularity']  =df_small['popularity']/df_small['popularity'].mean()
df_small['vote_average'] =df_small['vote_average']/df_small['vote_average'].mean()
# Out:
# <ipython-input-147-ca237730ed85>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_small['profit']      =df_small['profit']/df_small['profit'].mean()
# <ipython-input-147-ca237730ed85>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_small['profit_dom']  =df_small['profit_dom']/df_small['profit_dom'].mean()
# <ipython-input-147-ca237730ed85>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_small['popularity']  =df_small['popularity']/df_small['popularity'].mean()
# <ipython-input-147-ca237730ed85>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_small['vote_average'] =df_small['vote_average']/df_small['vote_average'].mean()

# %%
import seaborn as sns
sns.set_style("whitegrid")
#ax1 = plt.figure(figsize=(30, 16))
plt.rcParams.update({'font.size': 14})

ax1 = df_small.plot(x="movie", y=["popularity", "vote_average", "profit"], figsize=(14,8),kind="bar")
ax1.set_ylabel('Normalized value by mean (see text for details )')
ax1.set_xlabel('Movie')
#ax1.grid(linestyle='--', linewidth='0.2', color='blue')
ax1.grid(True, color = 'DarkTurquoise', alpha=1, linestyle = '--', linewidth = 0.5)
plt.savefig('./figs/most_profitable_movie.png')
plt.show()

# %% [markdown]
# * Based on the above plot Avatar turns out to be most profitable movie followed by Abbengers infinity wars.
# However Avengers seems to be most popular and having higher vote average. I can think of one reason for this
# discrepancy. Avatar was released in 2009 and Avengers in 2018. In 2009 I would guess fraction of people who were social media savvy was small and so the votes garnered by Avatar are less.
#
# * The values on y-axis are normalized values by mean for the given variable (i.e. profit, popualrity, vote average). What I mean by this is as follows: e.g. profit for each movie was divided by average profit dervied by all the movies, and likewise for popularity, vote average etc. I did this so that I can overlay all three variables on the same plot. Afterwards I relaised that I could use the normalize function from numpy.
#
# * Both these and the next couple of movies in order are either sci-fi or action thriller. Lets look at profit vs genre to confirm this prediction

# %%
* Based on the above plotAvatar
#df_small.plot(x="movie", y=["popularity", "vote_average","profit"], kind="bar", figsize=(9, 8))

# %%
#dftest=dftest.drop_duplicates(subset='release_date_x', keep="first")
ax2 = df_profit_pop.plot.scatter(x='profit',
                    y='profit_dom',
                    colormap='viridis')
ax2.set_ylabel("Domestic Profit")
ax2.set_xlabel("Total Profit")
# Out:
# Text(0.5, 0, 'Total Profit')

# %% [markdown]
# * It looks like there is a correlation between profits in domestic markets and worldwide profit. Not a surprise, but probably better is to plot domestic vs (total-domestic) to see if that is true.

# %%
# Rotten Tomatoes review files
df_rt_reviews_movie = pd.read_csv("zippedData/rt.reviews.csv")
df_rt_reviews_movie#['review'][0]
# Out:
#          id                                             review rating   fresh  \
# 0         3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1         3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2         3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3         3  Continuing along a line introduced in last yea...    NaN   fresh
# 4         3             ... a perverse twist on neorealism...     NaN   fresh
# ...     ...                                                ...    ...     ...
# 54427  2000  The real charm of this trifle is the deadpan c...    NaN   fresh
# 54428  2000                                                NaN    1/5  rotten
# 54429  2000                                                NaN    2/5  rotten
# 54430  2000                                                NaN  2.5/5  rotten
# 54431  2000                                                NaN    3/5   fresh
#
#                   critic  top_critic         publisher                date
# 0             PJ Nabarro           0   Patrick Nabarro   November 10, 2018
# 1         Annalee Newitz           0           io9.com        May 23, 2018
# 2           Sean Axmaker           0  Stream on Demand     January 4, 2018
# 3          Daniel Kasman           0              MUBI   November 16, 2017
# 4                    NaN           0      Cinema Scope    October 12, 2017
# ...                  ...         ...               ...                 ...
# 54427      Laura Sinagra           1     Village Voice  September 24, 2002
# 54428  Michael Szymanski           0        Zap2it.com  September 21, 2005
# 54429       Emanuel Levy           0   EmanuelLevy.Com       July 17, 2005
# 54430   Christopher Null           0    Filmcritic.com   September 7, 2003
# 54431    Nicolas Lacroix           0      Showbizz.net   November 12, 2002
#
# [54432 rows x 8 columns]

# %%
df_rt_info_movie = pd.read_csv("zippedData/rt.movie_info.tsv",sep='\t')
df_rt_info_movie
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# 0                   Action and Adventure|Classics|Drama    William Friedkin
# 1                     Drama|Science Fiction and Fantasy    David Cronenberg
# 2                     Drama|Musical and Performing Arts      Allison Anders
# 3                            Drama|Mystery and Suspense      Barry Levinson
# 4                                         Drama|Romance      Rodney Bennett
# ...                                                 ...                 ...
# 1555   Action and Adventure|Horror|Mystery and Suspense                 NaN
# 1556                 Comedy|Science Fiction and Fantasy        Steve Barron
# 1557  Classics|Comedy|Drama|Musical and Performing Arts      Gordon Douglas
# 1558    Comedy|Drama|Kids and Family|Sports and Fitness  David Mickey Evans
# 1559  Action and Adventure|Art House and Internation...                 NaN
#
#                                                 writer  theater_date  \
# 0                                       Ernest Tidyman   Oct 9, 1971
# 1                         David Cronenberg|Don DeLillo  Aug 17, 2012
# 2                                       Allison Anders  Sep 13, 1996
# 3                      Paul Attanasio|Michael Crichton   Dec 9, 1994
# 4                                         Giles Cooper           NaN
# ...                                                ...           ...
# 1555                                               NaN  Aug 18, 2006
# 1556  Terry Turner|Tom Davis|Dan Aykroyd|Bonnie Turner  Jul 23, 1993
# 1557                                               NaN   Jan 1, 1962
# 1558                  David Mickey Evans|Robert Gunter   Apr 1, 1993
# 1559                                        Luc Besson  Sep 27, 2001
#
#           dvd_date currency  box_office      runtime             studio
# 0     Sep 25, 2001      NaN         NaN  104 minutes                NaN
# 1      Jan 1, 2013        $     600,000  108 minutes  Entertainment One
# 2     Apr 18, 2000      NaN         NaN  116 minutes                NaN
# 3     Aug 27, 1997      NaN         NaN  128 minutes                NaN
# 4              NaN      NaN         NaN  200 minutes                NaN
# ...            ...      ...         ...          ...                ...
# 1555   Jan 2, 2007        $  33,886,034  106 minutes    New Line Cinema
# 1556  Apr 17, 2001      NaN         NaN   88 minutes  Paramount Vantage
# 1557  May 11, 2004      NaN         NaN  111 minutes                NaN
# 1558  Jan 29, 2002      NaN         NaN  101 minutes                NaN
# 1559  Feb 11, 2003      NaN         NaN   94 minutes  Columbia Pictures
#
# [1560 rows x 12 columns]

# %%
df_rt_info_movie['genre'].value_counts().head(20)
# Out:
# Drama                                               151
# Comedy                                              110
# Comedy|Drama                                         80
# Drama|Mystery and Suspense                           67
# Art House and International|Drama                    62
# Action and Adventure|Drama                           42
# Action and Adventure|Drama|Mystery and Suspense      40
# Drama|Romance                                        35
# Comedy|Romance                                       32
# Art House and International|Comedy|Drama             31
# Horror                                               31
# Action and Adventure|Science Fiction and Fantasy     24
# Comedy|Drama|Romance                                 23
# Classics|Drama                                       21
# Action and Adventure|Mystery and Suspense            20
# Action and Adventure                                 19
# Classics|Drama|Mystery and Suspense                  18
# Horror|Mystery and Suspense                          17
# Drama|Musical and Performing Arts                    14
# Documentary|Special Interest                         14
# Name: genre, dtype: int64

# %%
df_rt_info_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1560 non-null   int64
#  1   synopsis      1498 non-null   object
#  2   rating        1557 non-null   object
#  3   genre         1552 non-null   object
#  4   director      1361 non-null   object
#  5   writer        1111 non-null   object
#  6   theater_date  1201 non-null   object
#  7   dvd_date      1201 non-null   object
#  8   currency      340 non-null    object
#  9   box_office    340 non-null    object
#  10  runtime       1530 non-null   object
#  11  studio        494 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 146.4+ KB

# %%
df_rt_info_movie.dropna(subset=['director','genre'],inplace=True)
df_rt_info_movie['theater_date'] = pd.to_datetime(df_rt_info_movie['theater_date'])
df_rt_info_movie.style.format({"theater_date": lambda t: t.strftime("%Y-%m-%d")})
df_rt_info_movie

# %%
#df_rt_info_movie[df_rt_info_movie['director']=='Woody Allen']

# %%
df_rt_info_movie.director.value_counts()
# Out:
# Steven Spielberg    10
# Clint Eastwood       8
# Ridley Scott         4
# Barry Levinson       4
# Yimou Zhang          4
#                     ..
# Roger Vadim          1
# Otto Preminger       1
# Tim Burstall         1
# Paddy Breathnach     1
# Karl Zwicky          1
# Name: director, Length: 1125, dtype: int64

# %%
df_rt_info_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1560 non-null   int64
#  1   synopsis      1498 non-null   object
#  2   rating        1557 non-null   object
#  3   genre         1552 non-null   object
#  4   director      1361 non-null   object
#  5   writer        1111 non-null   object
#  6   theater_date  1201 non-null   object
#  7   dvd_date      1201 non-null   object
#  8   currency      340 non-null    object
#  9   box_office    340 non-null    object
#  10  runtime       1530 non-null   object
#  11  studio        494 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 146.4+ KB

# %%
#df_rt_info_movie.groupby('genres')
df_genres=df_rt_info_movie.groupby(['genre']).sum()
df_genres
# Out:
#                                                        id
# genre
# Action and Adventure                                19320
# Action and Adventure|Animation|Art House and In...    135
# Action and Adventure|Animation|Classics|Comedy|...   1156
# Action and Adventure|Animation|Comedy                 564
# Action and Adventure|Animation|Comedy|Drama|Kid...   1418
# ...                                                   ...
# Science Fiction and Fantasy                          8036
# Science Fiction and Fantasy|Romance                  1908
# Special Interest                                      636
# Special Interest|Sports and Fitness                   265
# Western                                              6300
#
# [299 rows x 1 columns]

# %%
df_rt_info_movie[df_rt_info_movie['id']==3]
# Out:
#    id                                           synopsis rating  \
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
#
#                                genre          director  \
# 1  Drama|Science Fiction and Fantasy  David Cronenberg
#
#                          writer  theater_date     dvd_date currency  \
# 1  David Cronenberg|Don DeLillo  Aug 17, 2012  Jan 1, 2013        $
#
#   box_office      runtime             studio
# 1    600,000  108 minutes  Entertainment One

# %%
df_rt_reviews_movie[df_rt_reviews_movie['id']==3]
# Out:
#      id                                             review rating   fresh  \
# 0     3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1     3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2     3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3     3  Continuing along a line introduced in last yea...    NaN   fresh
# 4     3             ... a perverse twist on neorealism...     NaN   fresh
# ..   ..                                                ...    ...     ...
# 158   3  Beyond its withering critique of contemporary ...    NaN   fresh
# 159   3  Threatens to soar and to be important, but it ...    3/5   fresh
# 160   3            A parade of hollow didactic encounters.    NaN  rotten
# 161   3  [An] agonisingly self-conscious and meagre pie...    2/5  rotten
# 162   3                                                NaN      B   fresh
#
#               critic  top_critic             publisher               date
# 0         PJ Nabarro           0       Patrick Nabarro  November 10, 2018
# 1     Annalee Newitz           0               io9.com       May 23, 2018
# 2       Sean Axmaker           0      Stream on Demand    January 4, 2018
# 3      Daniel Kasman           0                  MUBI  November 16, 2017
# 4                NaN           0          Cinema Scope   October 12, 2017
# ..               ...         ...                   ...                ...
# 158    David Jenkins           0     Little White Lies       May 25, 2012
# 159     Dave Calhoun           1              Time Out       May 25, 2012
# 160  Owen Gleiberman           1  Entertainment Weekly       May 25, 2012
# 161   Peter Bradshaw           0              Guardian       May 25, 2012
# 162     Emanuel Levy           0       EmanuelLevy.Com  December 25, 2012
#
# [163 rows x 8 columns]

# %% [markdown]
#  <span style="color:red"> I will need more information from rotton tomatoes to properly decode these two tables (for future ). </span>
#
# * For now I will use the "df_rt_info_movie" table and study different genres and  be directors.

# %%
df_sql_budgets_db =pd.merge(df_budgets_movie,df_movie_db,how='inner',left_on='movie', right_on='primary_title')
df_sql_budgets_db
# Out:
#       id release_date                                        movie  \
# 0      1   2009-12-18                                       Avatar
# 1      2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2      3   2019-06-07                                 Dark Phoenix
# 3      4   2015-05-01                      Avengers: Age of Ultron
# 4      7   2018-04-27                       Avengers: Infinity War
# ...   ..          ...                                          ...
# 2721  59   2011-11-25                                   The Ridges
# 2722  62   2014-12-31                         Stories of Our Lives
# 2723  68   2001-07-06                                         Cure
# 2724  78   2018-12-31                                       Red 11
# 2725  81   2015-09-29                         A Plague So Pleasant
#
#       production_budget  domestic_gross  worldwide_gross        profit  \
# 0           425000000.0     760507625.0     2.776345e+09  2.351345e+09
# 1           410600000.0     241063875.0     1.045664e+09  6.350639e+08
# 2           350000000.0      42762350.0     1.497624e+08 -2.002376e+08
# 3           330600000.0     459005868.0     1.403014e+09  1.072414e+09
# 4           300000000.0     678815482.0     2.048134e+09  1.748134e+09
# ...                 ...             ...              ...           ...
# 2721            17300.0             0.0     0.000000e+00 -1.730000e+04
# 2722            15000.0             0.0     0.000000e+00 -1.500000e+04
# 2723            10000.0         94596.0     9.459600e+04  8.459600e+04
# 2724             7000.0             0.0     0.000000e+00 -7.000000e+03
# 2725             1400.0             0.0     0.000000e+00 -1.400000e+03
#
#        profit_dom   movie_id                                primary_title  \
# 0     335507625.0  tt1775309                                       Avatar
# 1    -169536125.0  tt1298650  Pirates of the Caribbean: On Stranger Tides
# 2    -307237650.0  tt6565702                                 Dark Phoenix
# 3     128405868.0  tt2395427                      Avengers: Age of Ultron
# 4     378815482.0  tt4154756                       Avengers: Infinity War
# ...           ...        ...                                          ...
# 2721     -17300.0  tt1781935                                   The Ridges
# 2722     -15000.0  tt3973612                         Stories of Our Lives
# 2723      84596.0  tt1872026                                         Cure
# 2724      -7000.0  tt7837402                                       Red 11
# 2725      -1400.0  tt2107644                         A Plague So Pleasant
#
#       averagerating  numvotes                    genres  start_year  \
# 0               6.1        43                    Horror        2011
# 1               6.6    447624  Action,Adventure,Fantasy        2011
# 2               6.0     24451   Action,Adventure,Sci-Fi        2019
# 3               7.3    665594   Action,Adventure,Sci-Fi        2015
# 4               8.5    670926   Action,Adventure,Sci-Fi        2018
# ...             ...       ...                       ...         ...
# 2721            2.9       127     Drama,Horror,Thriller        2011
# 2722            7.5        85                     Drama        2014
# 2723            4.9        11                     Drama        2011
# 2724            5.6        43    Horror,Sci-Fi,Thriller        2019
# 2725            5.4        72     Drama,Horror,Thriller        2013
#
#                         primary_name             person_id
# 0                       Atsushi Wada             nm3786927
# 1                       Rob Marshall             nm0551128
# 2                      Simon Kinberg             nm1334526
# 3                        Joss Whedon             nm0923736
# 4           Anthony Russo, Joe Russo  nm0751577, nm0751648
# ...                              ...                   ...
# 2721                 Brandon Landers             nm4192760
# 2722                      Jim Chuchu             nm5874888
# 2723                        Bill Yip             nm0948107
# 2724                Robert Rodriguez             nm0001675
# 2725  Benjamin Roberds, Jordan Reyes  nm4766951, nm5792320
#
# [2726 rows x 16 columns]

# %%
df_sql_budgets_db["start_year"] = df_sql_budgets_db["start_year"].astype(float)

# %%
df_sql_budgets_db["year"]=pd.DatetimeIndex(df_sql_budgets_db['release_date']).year.astype(float)

# %%
df_sql_budgets_db=df_sql_budgets_db[df_sql_budgets_db['year']==df_sql_budgets_db['start_year']]

# %%
df_sql_budgets_db[df_sql_budgets_db.duplicated()==True]
# Out:
# Empty DataFrame
# Columns: [id, release_date, movie, production_budget, domestic_gross, worldwide_gross, profit, profit_dom, movie_id, primary_title, averagerating, numvotes, genres, start_year, primary_name, person_id, year]
# Index: []

# %%
df_sql_budgets_db
# Out:
#       id release_date                                        movie  \
# 1      2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2      3   2019-06-07                                 Dark Phoenix
# 3      4   2015-05-01                      Avengers: Age of Ultron
# 4      7   2018-04-27                       Avengers: Infinity War
# 5      9   2017-11-17                               Justice League
# ...   ..          ...                                          ...
# 2712  45   2017-01-27                                        Emily
# 2714  49   2015-09-01                                       Exeter
# 2719  52   2015-12-01                                  Dutch Kills
# 2721  59   2011-11-25                                   The Ridges
# 2722  62   2014-12-31                         Stories of Our Lives
#
#       production_budget  domestic_gross  worldwide_gross        profit  \
# 1           410600000.0     241063875.0     1.045664e+09  6.350639e+08
# 2           350000000.0      42762350.0     1.497624e+08 -2.002376e+08
# 3           330600000.0     459005868.0     1.403014e+09  1.072414e+09
# 4           300000000.0     678815482.0     2.048134e+09  1.748134e+09
# 5           300000000.0     229024295.0     6.559452e+08  3.559452e+08
# ...                 ...             ...              ...           ...
# 2712            27000.0          3547.0     3.547000e+03 -2.345300e+04
# 2714            25000.0             0.0     4.897920e+05  4.647920e+05
# 2719            25000.0             0.0     0.000000e+00 -2.500000e+04
# 2721            17300.0             0.0     0.000000e+00 -1.730000e+04
# 2722            15000.0             0.0     0.000000e+00 -1.500000e+04
#
#        profit_dom   movie_id                                primary_title  \
# 1    -169536125.0  tt1298650  Pirates of the Caribbean: On Stranger Tides
# 2    -307237650.0  tt6565702                                 Dark Phoenix
# 3     128405868.0  tt2395427                      Avengers: Age of Ultron
# 4     378815482.0  tt4154756                       Avengers: Infinity War
# 5     -70975705.0  tt0974015                               Justice League
# ...           ...        ...                                          ...
# 2712     -23453.0  tt4393036                                        Emily
# 2714     -25000.0  tt1945044                                       Exeter
# 2719     -25000.0  tt2759066                                  Dutch Kills
# 2721     -17300.0  tt1781935                                   The Ridges
# 2722     -15000.0  tt3973612                         Stories of Our Lives
#
#       averagerating  numvotes                    genres  start_year  \
# 1               6.6    447624  Action,Adventure,Fantasy      2011.0
# 2               6.0     24451   Action,Adventure,Sci-Fi      2019.0
# 3               7.3    665594   Action,Adventure,Sci-Fi      2015.0
# 4               8.5    670926   Action,Adventure,Sci-Fi      2018.0
# 5               6.5    329135  Action,Adventure,Fantasy      2017.0
# ...             ...       ...                       ...         ...
# 2712            6.8        13                     Drama      2017.0
# 2714            4.5      5156   Horror,Mystery,Thriller      2015.0
# 2719            5.1        82      Crime,Drama,Thriller      2015.0
# 2721            2.9       127     Drama,Horror,Thriller      2011.0
# 2722            7.5        85                     Drama      2014.0
#
#                   primary_name             person_id    year
# 1                 Rob Marshall             nm0551128  2011.0
# 2                Simon Kinberg             nm1334526  2019.0
# 3                  Joss Whedon             nm0923736  2015.0
# 4     Anthony Russo, Joe Russo  nm0751577, nm0751648  2018.0
# 5                  Zack Snyder             nm0811583  2017.0
# ...                        ...                   ...     ...
# 2712               Ryan Graves             nm6254824  2017.0
# 2714             Marcus Nispel             nm1197971  2015.0
# 2719           Joseph Mazzella             nm3556672  2015.0
# 2721           Brandon Landers             nm4192760  2011.0
# 2722                Jim Chuchu             nm5874888  2014.0
#
# [1445 rows x 17 columns]

# %%
df_sql_budgets_db[df_sql_budgets_db['primary_name'].str.contains('Russo')]
# Out:
#       id release_date                                movie  production_budget  \
# 4      7   2018-04-27               Avengers: Infinity War        300000000.0
# 12    17   2016-05-06           Captain America: Civil War        250000000.0
# 98    16   2014-04-04  Captain America: The Winter Soldier        170000000.0
# 2054  12   2017-03-03                        Before I Fall          5000000.0
#
#       domestic_gross  worldwide_gross        profit   profit_dom   movie_id  \
# 4        678815482.0     2.048134e+09  1.748134e+09  378815482.0  tt4154756
# 12       408084349.0     1.140069e+09  8.900694e+08  158084349.0  tt3498820
# 98       259746958.0     7.144019e+08  5.444019e+08   89746958.0  tt1843866
# 2054      12241072.0     1.894568e+07  1.394568e+07    7241072.0  tt1691916
#
#                             primary_title  averagerating  numvotes  \
# 4                  Avengers: Infinity War            8.5    670926
# 12             Captain America: Civil War            7.8    583507
# 98    Captain America: The Winter Soldier            7.8    666252
# 2054                        Before I Fall            6.4     39282
#
#                        genres  start_year              primary_name  \
# 4     Action,Adventure,Sci-Fi      2018.0  Anthony Russo, Joe Russo
# 12    Action,Adventure,Sci-Fi      2016.0  Anthony Russo, Joe Russo
# 98    Action,Adventure,Sci-Fi      2014.0  Anthony Russo, Joe Russo
# 2054    Drama,Fantasy,Mystery      2017.0            Ry Russo-Young
#
#                  person_id    year
# 4     nm0751577, nm0751648  2018.0
# 12    nm0751577, nm0751648  2016.0
# 98    nm0751577, nm0751648  2014.0
# 2054             nm1735543  2017.0

# %%
df_sql_budgets_db[df_sql_budgets_db['primary_name'].str.contains('James Wan')]
# Out:
#       id release_date          movie  production_budget  domestic_gross  \
# 56    67   2015-04-03      Furious 7        190000000.0     353007020.0
# 118   36   2018-12-21        Aquaman        160000000.0     335061807.0
# 1230  93   2013-07-19  The Conjuring         20000000.0     137400141.0
#
#       worldwide_gross        profit   profit_dom   movie_id  primary_title  \
# 56       1.518723e+09  1.328723e+09  163007020.0  tt2820852      Furious 7
# 118      1.146895e+09  9.868946e+08  175061807.0  tt1477834        Aquaman
# 1230     3.180001e+08  2.980001e+08  117400141.0  tt1457767  The Conjuring
#
#       averagerating  numvotes                    genres  start_year  \
# 56              7.2    335074     Action,Crime,Thriller      2015.0
# 118             7.1    263328  Action,Adventure,Fantasy      2018.0
# 1230            7.5    397233   Horror,Mystery,Thriller      2013.0
#
#      primary_name  person_id    year
# 56      James Wan  nm1490123  2015.0
# 118     James Wan  nm1490123  2018.0
# 1230    James Wan  nm1490123  2013.0

# %%
(df_sql_budgets_db.groupby(['primary_name']).sum()).sort_values(by='profit',ascending=False).head(20)
# Out:
#                               id  production_budget  domestic_gross  \
# primary_name
# Anthony Russo, Joe Russo      40        720000000.0    1.346647e+09
# James Wan                    196        370000000.0    8.254690e+08
# Joss Whedon                   31        555600000.0    1.082285e+09
# Christopher Nolan            150        750000000.0    1.118801e+09
# Michael Bay                  167        648000000.0    7.778736e+08
# Peter Jackson                 62        750000000.0    8.164902e+08
# Francis Lawrence             254        522000000.0    1.149112e+09
# Bryan Singer                 298        628000000.0    6.708550e+08
# Sam Mendes                    62        500000000.0    5.044345e+08
# Zack Snyder                  208        950000000.0    9.424978e+08
# Colin Trevorrow              111        215750000.0    6.562816e+08
# Chris Renaud, Pierre Coffin   72        145000000.0    6.195794e+08
# Ryan Coogler                 171        237900000.0    8.259261e+08
# Steven Spielberg             251        645000000.0    6.870743e+08
# J.A. Bayona                  113        210000000.0    4.367396e+08
# Ridley Scott                 246        705000000.0    6.166482e+08
# David Yates                  233        560000000.0    5.202365e+08
# Jon Favreau                  112        345000000.0    6.764345e+08
# Gareth Edwards               136        360500000.0    7.330907e+08
# F. Gary Gray                  58        278000000.0    3.869626e+08
#
#                              worldwide_gross        profit   profit_dom  \
# primary_name
# Anthony Russo, Joe Russo        3.902606e+09  3.182606e+09  626646789.0
# James Wan                       2.983618e+09  2.613618e+09  455468968.0
# Joss Whedon                     2.920950e+09  2.365350e+09  526685415.0
# Christopher Nolan               3.086180e+09  2.336180e+09  368801468.0
# Michael Bay                     2.911998e+09  2.263998e+09  129873593.0
# Peter Jackson                   2.922948e+09  2.172948e+09   66490211.0
# Francis Lawrence                2.543192e+09  2.021192e+09  627112056.0
# Bryan Singer                    2.383073e+09  1.755073e+09   42854965.0
# Sam Mendes                      1.990148e+09  1.490148e+09    4434452.0
# Zack Snyder                     2.420920e+09  1.470920e+09   -7502178.0
# Colin Trevorrow                 1.653277e+09  1.437527e+09  440531582.0
# Chris Renaud, Pierre Coffin     1.518681e+09  1.373681e+09  474579370.0
# Ryan Coogler                    1.539375e+09  1.301475e+09  588026145.0
# Steven Spielberg                1.925340e+09  1.280340e+09   42074317.0
# J.A. Bayona                     1.475363e+09  1.265363e+09  226739642.0
# Ridley Scott                    1.958024e+09  1.253024e+09  -88351846.0
# David Yates                     1.803525e+09  1.243525e+09  -39763463.0
# Jon Favreau                     1.584011e+09  1.239011e+09  331434454.0
# Gareth Edwards                  1.583819e+09  1.223319e+09  372590694.0
# F. Gary Gray                    1.437029e+09  1.159029e+09  108962550.0
#
#                              averagerating  numvotes  start_year     year
# primary_name
# Anthony Russo, Joe Russo              24.1   1920685      6048.0   6048.0
# James Wan                             21.8    995635      6046.0   6046.0
# Joss Whedon                           15.4   1849249      4027.0   4027.0
# Christopher Nolan                     33.7   4994749      8053.0   8053.0
# Michael Bay                           23.5    956722      8055.0   8055.0
# Peter Jackson                         23.1   1723813      6039.0   6039.0
# Francis Lawrence                      34.2   1449439     10071.0  10071.0
# Bryan Singer                          29.3   1445228      8061.0   8061.0
# Sam Mendes                            14.6    944725      4027.0   4027.0
# Zack Snyder                           33.2   1845493     10067.0  10067.0
# Colin Trevorrow                       14.0    651245      4027.0   4027.0
# Chris Renaud, Pierre Coffin           15.1    808741      4023.0   4023.0
# Ryan Coogler                          22.4    809006      6046.0   6046.0
# Steven Spielberg                      50.6   1309599     14100.0  14100.0
# J.A. Bayona                           13.8    396887      4030.0   4030.0
# Ridley Scott                          39.3   1928190     12081.0  12081.0
# David Yates                           20.2    678658      6050.0   6050.0
# Jon Favreau                           14.4    898511      4026.0   4026.0
# Gareth Edwards                        20.6    913611      6040.0   6040.0
# F. Gary Gray                          14.6    345081      4032.0   4032.0

# %%
df_sql_budgets_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1445 entries, 1 to 2722
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 1445 non-null   int64
#  1   release_date       1445 non-null   datetime64[ns]
#  2   movie              1445 non-null   object
#  3   production_budget  1445 non-null   float64
#  4   domestic_gross     1445 non-null   float64
#  5   worldwide_gross    1445 non-null   float64
#  6   profit             1445 non-null   float64
#  7   profit_dom         1445 non-null   float64
#  8   movie_id           1445 non-null   object
#  9   primary_title      1445 non-null   object
#  10  averagerating      1445 non-null   float64
#  11  numvotes           1445 non-null   int64
#  12  genres             1444 non-null   object
#  13  start_year         1445 non-null   float64
#  14  primary_name       1445 non-null   object
#  15  person_id          1445 non-null   object
#  16  year               1445 non-null   float64
# dtypes: datetime64[ns](1), float64(8), int64(2), object(6)
# memory usage: 203.2+ KB

# %%
df_sql_budgets_db.primary_name.value_counts().head(20)
# Out:
# Steven Spielberg      7
# Jon M. Chu            6
# Ridley Scott          6
# Clint Eastwood        6
# Jonathan Levine       5
# David Ayer            5
# Brad Peyton           5
# Antoine Fuqua         5
# Ron Howard            5
# Jaume Collet-Serra    5
# Denis Villeneuve      5
# Peter Berg            5
# Zack Snyder           5
# Francis Lawrence      5
# Tim Burton            5
# Steven Soderbergh     5
# David O. Russell      5
# Tim Story             4
# Baltasar Kormákur     4
# Frank Coraci          4
# Name: primary_name, dtype: int64

# %%
ax2 = df_sql_budgets_db.plot.scatter(x='averagerating',
                    y='profit',
                    colormap='viridis')

# %% [markdown]
# * There doesn't seem like a clear correlation between an average rating of movie and its profit. So the most profitable movies may not be rated higher. I would guess the content is always not best and may be thats what is the cause for this discrepancy

# %%
df_sql_budtmdb_db =pd.merge(df_budg_tmdb,df_movie_db,how='inner',left_on='movie', right_on='primary_title')
df_sql_budtmdb_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2754 entries, 0 to 2753
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id_x               2754 non-null   int64
#  1   release_date_x     2754 non-null   datetime64[ns]
#  2   movie              2754 non-null   object
#  3   production_budget  2754 non-null   float64
#  4   domestic_gross     2754 non-null   float64
#  5   worldwide_gross    2754 non-null   float64
#  6   profit             2754 non-null   float64
#  7   profit_dom         2754 non-null   float64
#  8   genre_ids          2754 non-null   object
#  9   id_y               2754 non-null   int64
#  10  original_language  2754 non-null   object
#  11  original_title     2754 non-null   object
#  12  popularity         2754 non-null   float64
#  13  release_date_y     2754 non-null   datetime64[ns]
#  14  title              2754 non-null   object
#  15  vote_average       2754 non-null   float64
#  16  vote_count         2754 non-null   int64
#  17  movie_id           2754 non-null   object
#  18  primary_title      2754 non-null   object
#  19  averagerating      2754 non-null   float64
#  20  numvotes           2754 non-null   int64
#  21  genres             2749 non-null   object
#  22  start_year         2754 non-null   int64
#  23  primary_name       2754 non-null   object
#  24  person_id          2754 non-null   object
# dtypes: datetime64[ns](2), float64(8), int64(5), object(10)
# memory usage: 559.4+ KB

# %%
#ax2 = df_sql_budtmdb_db.plot.scatter(x='runtime_minutes',
#                    y='profit',
#                    colormap='viridis')

# %%
#df_sql_budtmdb_db.info()
df_rt_info_movie['theater_date'] = pd.to_datetime(df_rt_info_movie['theater_date'])
df_rt_info_movie.style.format({"release_date": lambda t: t.strftime("%Y-%m-%d")})
df_rt_info_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1560 non-null   int64
#  1   synopsis      1498 non-null   object
#  2   rating        1557 non-null   object
#  3   genre         1552 non-null   object
#  4   director      1361 non-null   object
#  5   writer        1111 non-null   object
#  6   theater_date  1201 non-null   datetime64[ns]
#  7   dvd_date      1201 non-null   object
#  8   currency      340 non-null    object
#  9   box_office    340 non-null    object
#  10  runtime       1530 non-null   object
#  11  studio        494 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 146.4+ KB

# %%
df_sql_rt_db =pd.merge(df_sql_budtmdb_db, df_rt_info_movie,how='inner',right_on='theater_date', left_on='release_date_x')
df_budg_rt_db =pd.merge(df_budgets_movie, df_rt_info_movie,how='inner',right_on='theater_date', left_on='release_date')
df_sql_rt_db
# Out:
#      id_x release_date_x                      movie  production_budget  \
# 0      14     2012-03-09                John Carter        275000000.0
# 1      14     2012-03-09                John Carter        275000000.0
# 2       1     2012-03-09           A Thousand Words         40000000.0
# 3       1     2012-03-09           A Thousand Words         40000000.0
# 4      97     2012-03-09               Silent House          2000000.0
# ..    ...            ...                        ...                ...
# 889    26     2010-05-01  My Girlfriend's Boyfriend          1400000.0
# 890    17     2001-07-27                    Jackpot           400000.0
# 891    17     2001-07-27                    Jackpot           400000.0
# 892    17     2001-07-27                    Jackpot           400000.0
# 893    69     1981-05-01             Graduation Day           250000.0
#
#      domestic_gross  worldwide_gross      profit   profit_dom      genre_ids  \
# 0        73058679.0      282778100.0   7778100.0 -201941321.0  [28, 12, 878]
# 1        73058679.0      282778100.0   7778100.0 -201941321.0  [28, 12, 878]
# 2        18450127.0       20790486.0 -19209514.0  -21549873.0       [18, 35]
# 3        18450127.0       20790486.0 -19209514.0  -21549873.0       [18, 35]
# 4        12739737.0       16610760.0  14610760.0   10739737.0     [27, 9648]
# ..              ...              ...         ...          ...            ...
# 889             0.0              0.0  -1400000.0   -1400000.0           [35]
# 890         44452.0          44452.0   -355548.0    -355548.0           [35]
# 891         44452.0          44452.0   -355548.0    -355548.0           [35]
# 892         44452.0          44452.0   -355548.0    -355548.0           [35]
# 893      23894000.0       23894000.0  23644000.0   23644000.0             []
#
#        id_y  ... rating                                              genre  \
# 0     49529  ...      R                                       Comedy|Drama
# 1     49529  ...  PG-13  Action and Adventure|Horror|Kids and Family|Sc...
# 2     72358  ...      R                                       Comedy|Drama
# 3     72358  ...  PG-13  Action and Adventure|Horror|Kids and Family|Sc...
# 4     92182  ...      R                                       Comedy|Drama
# ..      ...  ...    ...                                                ...
# 889   46198  ...     NR                          Animation|Kids and Family
# 890  241151  ...     NR                               Comedy|Drama|Romance
# 891  241151  ...     NR                               Comedy|Drama|Romance
# 892  241151  ...     NR                               Comedy|Drama|Romance
# 893  450254  ...      R                                             Horror
#
#                        director  \
# 0            Jennifer Westfeldt
# 1    Andrew Stanton|Mark Atkins
# 2            Jennifer Westfeldt
# 3    Andrew Stanton|Mark Atkins
# 4            Jennifer Westfeldt
# ..                          ...
# 889                         NaN
# 890              Jae-young Kwak
# 891              Jae-young Kwak
# 892              Jae-young Kwak
# 893                 Steve Miner
#
#                                                 writer theater_date  \
# 0                                   Jennifer Westfeldt   2012-03-09
# 1    Mark Atkins|Mark Andrews|Michael Chabon|Andrew...   2012-03-09
# 2                                   Jennifer Westfeldt   2012-03-09
# 3    Mark Atkins|Mark Andrews|Michael Chabon|Andrew...   2012-03-09
# 4                                   Jennifer Westfeldt   2012-03-09
# ..                                                 ...          ...
# 889                                        Elise Allen   2010-05-01
# 890                          Jae-young Kwak|Ho-sik Kim   2001-07-27
# 891                          Jae-young Kwak|Ho-sik Kim   2001-07-27
# 892                          Jae-young Kwak|Ho-sik Kim   2001-07-27
# 893                                 Ron Kurz|Ron Kurtz   1981-05-01
#
#          dvd_date  currency  box_office      runtime                studio
# 0    Jul 17, 2012         $   5,600,000  107 minutes  Roadside Attractions
# 1     Jun 5, 2012         $  73,058,679  118 minutes  Walt Disney Pictures
# 2    Jul 17, 2012         $   5,600,000  107 minutes  Roadside Attractions
# 3     Jun 5, 2012         $  73,058,679  118 minutes  Walt Disney Pictures
# 4    Jul 17, 2012         $   5,600,000  107 minutes  Roadside Attractions
# ..            ...       ...         ...          ...                   ...
# 889   Mar 9, 2010       NaN         NaN   75 minutes                   NaN
# 890  Feb 19, 2013       NaN         NaN  123 minutes                   NaN
# 891  Feb 19, 2013       NaN         NaN  123 minutes                   NaN
# 892  Feb 19, 2013       NaN         NaN  123 minutes                   NaN
# 893  May 23, 2006       NaN         NaN   87 minutes                   NaN
#
# [894 rows x 37 columns]

# %%
df_budg_rt_db
# Out:
#       id_x release_date                                   movie  \
# 0        6   2015-12-18    Star Wars Ep. VII: The Force Awakens
# 1       56   2015-12-18  Alvin and the Chipmunks: The Road Chip
# 2       57   2015-12-18                                 Sisters
# 3       45   2015-12-18                                Saul fia
# 4       14   2012-03-09                             John Carter
# ...    ...          ...                                     ...
# 2067    15   1983-01-01      E tu vivrai nel terrore - L'aldilÃ
# 2068    60   1975-04-01                         Death Race 2000
# 2069    69   1981-05-01                          Graduation Day
# 2070    12   1953-06-13           The Beast from 20,000 Fathoms
# 2071    19   1933-02-09                      She Done Him Wrong
#
#       production_budget  domestic_gross  worldwide_gross        profit  \
# 0           306000000.0     936662225.0     2.053311e+09  1.747311e+09
# 1            90000000.0      85886987.0     2.495180e+08  1.595180e+08
# 2            30000000.0      87044645.0     1.060307e+08  7.603066e+07
# 3             1700000.0       1777043.0     9.696537e+06  7.996537e+06
# 4           275000000.0      73058679.0     2.827781e+08  7.778100e+06
# ...                 ...             ...              ...           ...
# 2067           400000.0        126387.0     1.263870e+05 -2.736130e+05
# 2068           300000.0             0.0     0.000000e+00 -3.000000e+05
# 2069           250000.0      23894000.0     2.389400e+07  2.364400e+07
# 2070           210000.0       5000000.0     5.000000e+06  4.790000e+06
# 2071           200000.0       2000000.0     2.000000e+06  1.800000e+06
#
#        profit_dom  id_y                                           synopsis  \
# 0     630662225.0  1383  Through a series of misunderstandings, Alvin, ...
# 1      -4113013.0  1383  Through a series of misunderstandings, Alvin, ...
# 2      57044645.0  1383  Through a series of misunderstandings, Alvin, ...
# 3         77043.0  1383  Through a series of misunderstandings, Alvin, ...
# 4    -201941321.0   304  Friends with Kids is a daring and poignant ens...
# ...           ...   ...                                                ...
# 2067    -273613.0  1861  For those with a taste for the repugnant comes...
# 2068    -300000.0  1090  Voter apathy in the United States is at an all...
# 2069   23644000.0  1870  Two months after the events of the original Fr...
# 2070    4790000.0   350  An atomic bomb test in the Arctic Circle awake...
# 2071    1800000.0   216  "I'm the finest woman who walked the streets,"...
#
#      rating                                              genre  \
# 0        PG                   Animation|Comedy|Kids and Family
# 1        PG                   Animation|Comedy|Kids and Family
# 2        PG                   Animation|Comedy|Kids and Family
# 3        PG                   Animation|Comedy|Kids and Family
# 4         R                                       Comedy|Drama
# ...     ...                                                ...
# 2067      R  Art House and International|Horror|Science Fic...
# 2068      R                                    Classics|Comedy
# 2069      R                                             Horror
# 2070     NR        Classics|Horror|Science Fiction and Fantasy
# 2071     NR                                    Classics|Comedy
#
#                      director                            writer theater_date  \
# 0                 Walt Becker                               NaN   2015-12-18
# 1                 Walt Becker                               NaN   2015-12-18
# 2                 Walt Becker                               NaN   2015-12-18
# 3                 Walt Becker                               NaN   2015-12-18
# 4          Jennifer Westfeldt                Jennifer Westfeldt   2012-03-09
# ...                       ...                               ...          ...
# 2067  Harry Bromley Davenport           Harry Bromley Davenport   1983-01-01
# 2068                      NaN                     Jack Margolis   1975-04-01
# 2069              Steve Miner                Ron Kurz|Ron Kurtz   1981-05-01
# 2070                      NaN                               NaN   1953-06-13
# 2071           Lowell Sherman  Mae West|Harvey Thew|John Bright   1933-02-09
#
#           dvd_date currency  box_office      runtime                studio
# 0     Mar 15, 2016        $  66,580,191   86 minutes      20th Century Fox
# 1     Mar 15, 2016        $  66,580,191   86 minutes      20th Century Fox
# 2     Mar 15, 2016        $  66,580,191   86 minutes      20th Century Fox
# 3     Mar 15, 2016        $  66,580,191   86 minutes      20th Century Fox
# 4     Jul 17, 2012        $   5,600,000  107 minutes  Roadside Attractions
# ...            ...      ...         ...          ...                   ...
# 2067  Sep 20, 2005      NaN         NaN   80 minutes                   NaN
# 2068   Sep 2, 2008      NaN         NaN   95 minutes                   NaN
# 2069  May 23, 2006      NaN         NaN   87 minutes                   NaN
# 2070  Oct 21, 2003      NaN         NaN   80 minutes                   NaN
# 2071  Apr 22, 2008      NaN         NaN   65 minutes                   NaN
#
# [2072 rows x 20 columns]

# %%
df_budg_rt_db[df_budg_rt_db.duplicated()==True]
# Out:
# Empty DataFrame
# Columns: [id_x, release_date, movie, production_budget, domestic_gross, worldwide_gross, profit, profit_dom, id_y, synopsis, rating, genre, director, writer, theater_date, dvd_date, currency, box_office, runtime, studio]
# Index: []

# %%
df_budg_rt_db.id_x.value_counts()
# Out:
# 67     35
# 12     32
# 71     30
# 4      30
# 11     30
#        ..
# 83     13
# 72     13
# 44     12
# 100    12
# 41     10
# Name: id_x, Length: 100, dtype: int64

# %%
df_budgets_movie[df_budgets_movie['id']==44]
# Out:
#       id release_date                                              movie  \
# 43    44   2018-06-15                                      Incredibles 2
# 143   44   2010-07-14                          The Sorcerer's Apprentice
# 243   44   2015-03-27                                               Home
# 343   44   2003-11-21                                 The Cat in the Hat
# 443   44   2018-12-14               Spider-Man: Into The Spider-Verse 3D
# 543   44   1999-05-07                                          The Mummy
# 643   44   1999-07-23                                   Inspector Gadget
# 743   44   2002-09-20                          Ballistic: Ecks vs. Sever
# 843   44   2014-02-07                                     The Lego Movie
# 943   44   1998-10-09                                           Holy Man
# 1043  44   2004-07-30                                       Thunderbirds
# 1143  44   1998-07-29                                     The Negotiator
# 1243  44   1997-06-20                           My Best Friend's Wedding
# 1343  44   2012-03-16                                     21 Jump Street
# 1443  44   2008-05-02                                      Made of Honor
# 1543  44   2019-12-31                                   Down Under Cover
# 1643  44   2005-03-25                                          Guess Who
# 1743  44   2011-01-28                                           Biutiful
# 1843  44   1990-03-02                           The Hunt for Red October
# 1943  44   1998-09-18                                     One True Thing
# 2043  44   2014-10-10  Alexander and the Terrible, Horrible, No Good,...
# 2143  44   2001-08-03                                       Original Sin
# 2243  44   2010-04-23                                         The Losers
# 2343  44   2007-11-21                                             Hitman
# 2443  44   2017-12-08                               Just Getting Started
# 2543  44   1982-05-14                                Conan the Barbarian
# 2643  44   1989-12-15                                    We're No Angels
# 2743  44   1962-11-08                               Mutiny on The Bounty
# 2843  44   2002-04-26                                     The Salton Sea
# 2943  44   2001-04-11                                           Joe Dirt
# 3043  44   2009-03-13                         The Last House on the Left
# 3143  44   2003-07-25                                   Buffalo Soldiers
# 3243  44   2014-09-12                                       No Good Deed
# 3343  44   1999-07-09                                       American Pie
# 3443  44   2001-03-09                                        Company Man
# 3543  44   2000-08-25                                        Bring it On
# 3643  44   2014-03-14                                          Bad Words
# 3743  44   2007-02-02                                          Partition
# 3843  44   2004-02-27                                         Club Dread
# 3943  44   2015-02-24                Green Street Hooligans: Underground
# 4043  44   2007-02-02                                       Factory Girl
# 4143  44   1995-05-24                                Tales from the Hood
# 4243  44   1944-08-01                                             Wilson
# 4343  44   1982-08-27                  Jekyll and Hyde... Together Again
# 4443  44   2010-07-23                                Life During Wartime
# 4543  44   2000-12-22                               An Everlasting Piece
# 4643  44   2007-10-26                                              Bella
# 4743  44   2012-03-02                Tim and Eric's Billion Dollar Movie
# 4843  44   2013-06-21                                     Alien Uprising
# 4943  44   2010-09-24                                  The Virginity Hit
# 5043  44   1999-10-01                                       Happy, Texas
# 5143  44   2011-05-24                                      Forget Me Not
# 5243  44   2008-08-01                                       Frozen River
# 5343  44   2013-04-05                                   The Brass Teapot
# 5443  44   2004-08-20                                         Mean Creek
# 5543  44   1996-09-20                                When The Cat's Away
# 5643  44   1999-01-22                                  Bacheha-Ye aseman
# 5743  44   1999-12-24                                     Pink Narcissus
#
#       production_budget  domestic_gross  worldwide_gross        profit  \
# 43          200000000.0     608581744.0     1.242521e+09  1.042521e+09
# 143         160000000.0      63150991.0     2.179863e+08  5.798632e+07
# 243         130000000.0     177397510.0     3.859979e+08  2.559979e+08
# 343         109000000.0     101018283.0     1.338183e+08  2.481828e+07
# 443          90000000.0     190173195.0     3.753818e+08  2.853818e+08
# 543          80000000.0     155385488.0     4.163855e+08  3.363855e+08
# 643          75000000.0      97387965.0     9.738796e+07  2.238796e+07
# 743          70000000.0      14294842.0     1.429484e+07 -5.570516e+07
# 843          60000000.0     257784718.0     4.577294e+08  3.977294e+08
# 943          60000000.0      12069719.0     1.206972e+07 -4.793028e+07
# 1043         55000000.0       6768055.0     2.823144e+07 -2.676856e+07
# 1143         50000000.0      44705766.0     4.910577e+07 -8.942340e+05
# 1243         46000000.0     126813153.0     2.989234e+08  2.529234e+08
# 1343         42000000.0     138447667.0     2.028124e+08  1.608124e+08
# 1443         40000000.0      46012734.0     1.065487e+08  6.654874e+07
# 1543         40000000.0             0.0     0.000000e+00 -4.000000e+07
# 1643         35000000.0      68915888.0     1.021159e+08  6.711589e+07
# 1743         35000000.0       5101237.0     2.468752e+07 -1.031248e+07
# 1843         30000000.0     120709866.0     2.005000e+08  1.705000e+08
# 1943         30000000.0      23337196.0     2.670820e+07 -3.291804e+06
# 2043         28000000.0      66954149.0     1.013793e+08  7.337929e+07
# 2143         26000000.0      16521410.0     1.652141e+07 -9.478590e+06
# 2243         25000000.0      23591432.0     2.986384e+07  4.863840e+06
# 2343         24000000.0      39687694.0     9.913557e+07  7.513557e+07
# 2443         22000000.0       6069605.0     6.756412e+06 -1.524359e+07
# 2543         20000000.0      38264085.0     7.911408e+07  5.911408e+07
# 2643         20000000.0      10555348.0     1.055535e+07 -9.444652e+06
# 2743         19000000.0      13680000.0     1.368000e+07 -5.320000e+06
# 2843         18000000.0        676698.0     6.766980e+05 -1.732330e+07
# 2943         16000000.0      27087695.0     3.098770e+07  1.498770e+07
# 3043         15000000.0      32752215.0     4.652624e+07  3.152624e+07
# 3143         15000000.0        353743.0     3.537430e+05 -1.464626e+07
# 3243         13200000.0      52543632.0     5.432321e+07  4.112321e+07
# 3343         12000000.0     101800948.0     2.347231e+08  2.227231e+08
# 3443         12000000.0        146028.0     6.222730e+05 -1.137773e+07
# 3543         10000000.0      68353550.0     9.045355e+07  8.045355e+07
# 3643         10000000.0       7779614.0     7.843145e+06 -2.156855e+06
# 3743         10000000.0             0.0     0.000000e+00 -1.000000e+07
# 3843          8500000.0       5001655.0     7.573551e+06 -9.264490e+05
# 3943          8000000.0             0.0     0.000000e+00 -8.000000e+06
# 4043          7000000.0       1661464.0     1.661464e+06 -5.338536e+06
# 4143          6000000.0      11784569.0     1.178457e+07  5.784569e+06
# 4243          5200000.0       2000000.0     2.000000e+06 -3.200000e+06
# 4343          5000000.0       3707583.0     3.707583e+06 -1.292417e+06
# 4443          4500000.0        281447.0     2.814470e+05 -4.218553e+06
# 4543          4000000.0         75078.0     7.507800e+04 -3.924922e+06
# 4643          3300000.0       8093373.0     1.240547e+07  9.105473e+06
# 4743          3000000.0        201436.0     2.236520e+05 -2.776348e+06
# 4843          2500000.0             0.0     0.000000e+00 -2.500000e+06
# 4943          2000000.0        636706.0     6.367060e+05 -1.363294e+06
# 5043          1700000.0       2039192.0     2.891228e+06  1.191228e+06
# 5143          1300000.0             0.0     1.346500e+04 -1.286535e+06
# 5243          1000000.0       2511476.0     6.030129e+06  5.030129e+06
# 5343           900000.0          6997.0     4.137330e+05 -4.862670e+05
# 5443           500000.0        603951.0     1.348750e+06  8.487500e+05
# 5543           300000.0       1652472.0     2.525984e+06  2.225984e+06
# 5643           180000.0        933933.0     1.628579e+06  1.448579e+06
# 5743            27000.0          8231.0     8.231000e+03 -1.876900e+04
#
#        profit_dom
# 43    408581744.0
# 143   -96849009.0
# 243    47397510.0
# 343    -7981717.0
# 443   100173195.0
# 543    75385488.0
# 643    22387965.0
# 743   -55705158.0
# 843   197784718.0
# 943   -47930281.0
# 1043  -48231945.0
# 1143   -5294234.0
# 1243   80813153.0
# 1343   96447667.0
# 1443    6012734.0
# 1543  -40000000.0
# 1643   33915888.0
# 1743  -29898763.0
# 1843   90709866.0
# 1943   -6662804.0
# 2043   38954149.0
# 2143   -9478590.0
# 2243   -1408568.0
# 2343   15687694.0
# 2443  -15930395.0
# 2543   18264085.0
# 2643   -9444652.0
# 2743   -5320000.0
# 2843  -17323302.0
# 2943   11087695.0
# 3043   17752215.0
# 3143  -14646257.0
# 3243   39343632.0
# 3343   89800948.0
# 3443  -11853972.0
# 3543   58353550.0
# 3643   -2220386.0
# 3743  -10000000.0
# 3843   -3498345.0
# 3943   -8000000.0
# 4043   -5338536.0
# 4143    5784569.0
# 4243   -3200000.0
# 4343   -1292417.0
# 4443   -4218553.0
# 4543   -3924922.0
# 4643    4793373.0
# 4743   -2798564.0
# 4843   -2500000.0
# 4943   -1363294.0
# 5043     339192.0
# 5143   -1300000.0
# 5243    1511476.0
# 5343    -893003.0
# 5443     103951.0
# 5543    1352472.0
# 5643     753933.0
# 5743     -18769.0

# %%
df_budg_rt_db[df_budg_rt_db['id_x']==44]
# Out:
#       id_x release_date                                movie  \
# 504     44   2003-07-25                     Buffalo Soldiers
# 530     44   2007-11-21                               Hitman
# 531     44   2007-11-21                               Hitman
# 824     44   2002-09-20            Ballistic: Ecks vs. Sever
# 861     44   2012-03-02  Tim and Eric's Billion Dollar Movie
# 873     44   2014-03-14                            Bad Words
# 874     44   2014-03-14                            Bad Words
# 1329    44   1999-10-01                         Happy, Texas
# 1484    44   2002-04-26                       The Salton Sea
# 1485    44   2002-04-26                       The Salton Sea
# 1834    44   2017-12-08                 Just Getting Started
# 1873    44   1989-12-15                      We're No Angels
#
#       production_budget  domestic_gross  worldwide_gross      profit  \
# 504          15000000.0        353743.0         353743.0 -14646257.0
# 530          24000000.0      39687694.0       99135571.0  75135571.0
# 531          24000000.0      39687694.0       99135571.0  75135571.0
# 824          70000000.0      14294842.0       14294842.0 -55705158.0
# 861           3000000.0        201436.0         223652.0  -2776348.0
# 873          10000000.0       7779614.0        7843145.0  -2156855.0
# 874          10000000.0       7779614.0        7843145.0  -2156855.0
# 1329          1700000.0       2039192.0        2891228.0   1191228.0
# 1484         18000000.0        676698.0         676698.0 -17323302.0
# 1485         18000000.0        676698.0         676698.0 -17323302.0
# 1834         22000000.0       6069605.0        6756412.0 -15243588.0
# 1873         20000000.0      10555348.0       10555348.0  -9444652.0
#
#       profit_dom  id_y                                           synopsis  \
# 504  -14646257.0  1610  In a northern coastal city of Spain, which tur...
# 530   15687694.0    65  A classic Disney fairytale collides with moder...
# 531   15687694.0  1777  When a Vietnam veteran discovers two million d...
# 824  -55705158.0   398  At an isolated mansion in the snowy countrysid...
# 861   -2798564.0   285  An all new feature film from the twisted minds...
# 873   -2220386.0   345  When five struggling single moms put aside the...
# 874   -2220386.0   646  On the eve of graduating law school, Veronica ...
# 1329    339192.0   639  Abel Ferrara directed this erotic thriller ada...
# 1484 -17323302.0   626  Popular bogeymen Jason Voorhees terrorizes a g...
# 1485 -17323302.0   814  An egotistical TV reporter learns to appreciat...
# 1834 -15930395.0  1389  From Ron Shelton, writer/director of Tin Cup a...
# 1873  -9444652.0  1503  You've probably already guessed that the Famil...
#
#      rating                                              genre  \
# 504       R                                       Comedy|Drama
# 530      PG                     Comedy|Kids and Family|Romance
# 531       R    Action and Adventure|Drama|Mystery and Suspense
# 824       R                  Comedy|Drama|Mystery and Suspense
# 861       R                                             Comedy
# 873   PG-13                                       Comedy|Drama
# 874   PG-13                  Comedy|Drama|Mystery and Suspense
# 1329      R  Drama|Mystery and Suspense|Science Fiction and...
# 1484      R  Horror|Mystery and Suspense|Science Fiction an...
# 1485  PG-13                                     Comedy|Romance
# 1834  PG-13                        Action and Adventure|Comedy
# 1873      R                  Action and Adventure|Comedy|Drama
#
#                          director  \
# 504                           NaN
# 530                    Kevin Lima
# 531          Joel Coen|Ethan Coen
# 824                           NaN
# 861   Tim Heidecker|Eric Wareheim
# 873                   Tyler Perry
# 874                           NaN
# 1329                 Abel Ferrara
# 1484                  James Isaac
# 1485                Stephen Herek
# 1834                  Ron Shelton
# 1873                 Sidney Lumet
#
#                                                  writer theater_date  \
# 504                                                 NaN   2003-07-25
# 530                                                 NaN   2007-11-21
# 531                                Ethan Coen|Joel Coen   2007-11-21
# 824                                                 NaN   2002-09-20
# 861   Doug Lussenhop|Tim Heidecker|Jonathan Krisel|E...   2012-03-02
# 873                                         Tyler Perry   2014-03-14
# 874                                                 NaN   2014-03-14
# 1329                           Abel Ferrara|Christ Zois   1999-10-01
# 1484                                        Todd Farmer   2002-04-26
# 1485                   John Scott Shepherd|Dana Stevens   2002-04-26
# 1834                                        Ron Shelton   2017-12-08
# 1873                   Vincent Patrick|Richard Burridge   1989-12-15
#
#           dvd_date currency   box_office      runtime                studio
# 504   Nov 18, 2003      NaN          NaN  113 minutes      Lions Gate Films
# 530   Mar 18, 2008        $  127,706,877  108 minutes  Walt Disney Pictures
# 531    Apr 7, 2009        $   74,223,625  122 minutes         Miramax Films
# 824   Feb 11, 2003      NaN          NaN  103 minutes             USA Films
# 861    May 8, 2012        $      145,778   94 minutes     Magnolia Pictures
# 873   Jul 22, 2014        $   15,986,272  111 minutes       Lionsgate Films
# 874    May 6, 2014        $    2,664,765  108 minutes          Warner Bros.
# 1329   Dec 7, 1999      NaN          NaN   93 minutes                   NaN
# 1484   Jun 1, 2004        $   12,610,731   91 minutes       New Line Cinema
# 1485  Oct 15, 2002        $   14,400,987  103 minutes      20th Century Fox
# 1834  Feb 27, 2018      NaN          NaN          NaN  Broad Green Pictures
# 1873  May 20, 2003      NaN          NaN  114 minutes                   NaN

# %%
#This database cant work as based on release date, there are some wrong entries because there can be 
#more than one movie for a given date
df_budg_rt_db=df_budg_rt_db.drop_duplicates(subset='release_date', keep="first")

# %%
df_budg_rt_db[df_budg_rt_db['id_x']==44]
# Out:
#       id_x release_date                      movie  production_budget  \
# 824     44   2002-09-20  Ballistic: Ecks vs. Sever         70000000.0
# 1834    44   2017-12-08       Just Getting Started         22000000.0
# 1873    44   1989-12-15            We're No Angels         20000000.0
#
#       domestic_gross  worldwide_gross      profit  profit_dom  id_y  \
# 824       14294842.0       14294842.0 -55705158.0 -55705158.0   398
# 1834       6069605.0        6756412.0 -15243588.0 -15930395.0  1389
# 1873      10555348.0       10555348.0  -9444652.0  -9444652.0  1503
#
#                                                synopsis rating  \
# 824   At an isolated mansion in the snowy countrysid...      R
# 1834  From Ron Shelton, writer/director of Tin Cup a...  PG-13
# 1873  You've probably already guessed that the Famil...      R
#
#                                   genre      director  \
# 824   Comedy|Drama|Mystery and Suspense           NaN
# 1834        Action and Adventure|Comedy   Ron Shelton
# 1873  Action and Adventure|Comedy|Drama  Sidney Lumet
#
#                                 writer theater_date      dvd_date currency  \
# 824                                NaN   2002-09-20  Feb 11, 2003      NaN
# 1834                       Ron Shelton   2017-12-08  Feb 27, 2018      NaN
# 1873  Vincent Patrick|Richard Burridge   1989-12-15  May 20, 2003      NaN
#
#      box_office      runtime                studio
# 824         NaN  103 minutes             USA Films
# 1834        NaN          NaN  Broad Green Pictures
# 1873        NaN  114 minutes                   NaN

# %%
df_sql_rt_db.director.value_counts()
# Out:
# David Hillenbrand|Scott Hillenbrand    14
# Neil Jordan                            13
# Darko Lungulov                         11
# Eleanor Coppola                        11
# Gary Winick                            11
#                                        ..
# Mark Neveldine|Brian Taylor             1
# Michel Hazanavicius                     1
# David Fincher                           1
# Sean Penn                               1
# Shana Feste                             1
# Name: director, Length: 207, dtype: int64

# %%
#df_sql_rt_db.info()
df_sql_rt_db.release_date_x.value_counts()
# Out:
# 2009-12-04    28
# 2013-11-22    27
# 2018-04-13    22
# 2010-05-14    22
# 2015-11-20    20
#               ..
# 2010-02-05     1
# 2017-12-01     1
# 2017-05-26     1
# 2016-07-13     1
# 1993-09-03     1
# Name: release_date_x, Length: 197, dtype: int64

# %%
df_sql_rt_db[df_sql_rt_db['release_date_x']=='2009-12-04']
# Out:
#      id_x release_date_x     movie  production_budget  domestic_gross  \
# 709    41     2009-12-04  Brothers         26000000.0      28544157.0
# 710    41     2009-12-04  Brothers         26000000.0      28544157.0
# 711    41     2009-12-04  Brothers         26000000.0      28544157.0
# 712    41     2009-12-04  Brothers         26000000.0      28544157.0
# 713    41     2009-12-04  Brothers         26000000.0      28544157.0
# 714    41     2009-12-04  Brothers         26000000.0      28544157.0
# 715    41     2009-12-04  Brothers         26000000.0      28544157.0
# 716    41     2009-12-04  Brothers         26000000.0      28544157.0
# 717    41     2009-12-04  Brothers         26000000.0      28544157.0
# 718    41     2009-12-04  Brothers         26000000.0      28544157.0
# 719    41     2009-12-04  Brothers         26000000.0      28544157.0
# 720    41     2009-12-04  Brothers         26000000.0      28544157.0
# 721    41     2009-12-04  Brothers         26000000.0      28544157.0
# 722    41     2009-12-04  Brothers         26000000.0      28544157.0
# 723    41     2009-12-04  Brothers         26000000.0      28544157.0
# 724    41     2009-12-04  Brothers         26000000.0      28544157.0
# 725    41     2009-12-04  Brothers         26000000.0      28544157.0
# 726    41     2009-12-04  Brothers         26000000.0      28544157.0
# 727    41     2009-12-04  Brothers         26000000.0      28544157.0
# 728    41     2009-12-04  Brothers         26000000.0      28544157.0
# 729    41     2009-12-04  Brothers         26000000.0      28544157.0
# 730    41     2009-12-04  Brothers         26000000.0      28544157.0
# 731    41     2009-12-04  Brothers         26000000.0      28544157.0
# 732    41     2009-12-04  Brothers         26000000.0      28544157.0
# 733    41     2009-12-04  Brothers         26000000.0      28544157.0
# 734    41     2009-12-04  Brothers         26000000.0      28544157.0
# 735    41     2009-12-04  Brothers         26000000.0      28544157.0
# 736    41     2009-12-04  Brothers         26000000.0      28544157.0
#
#      worldwide_gross      profit  profit_dom genre_ids    id_y  ... rating  \
# 709       45043870.0  19043870.0   2544157.0      [18]  397805  ...  PG-13
# 710       45043870.0  19043870.0   2544157.0      [18]  397805  ...      R
# 711       45043870.0  19043870.0   2544157.0      [18]  397805  ...  PG-13
# 712       45043870.0  19043870.0   2544157.0      [18]  397805  ...      R
# 713       45043870.0  19043870.0   2544157.0      [18]  397805  ...  PG-13
# 714       45043870.0  19043870.0   2544157.0      [18]  397805  ...      R
# 715       45043870.0  19043870.0   2544157.0      [18]  397805  ...  PG-13
# 716       45043870.0  19043870.0   2544157.0      [18]  397805  ...      R
# 717       45043870.0  19043870.0   2544157.0      [18]  397805  ...  PG-13
# 718       45043870.0  19043870.0   2544157.0      [18]  397805  ...      R
# 719       45043870.0  19043870.0   2544157.0      [18]  397805  ...  PG-13
# 720       45043870.0  19043870.0   2544157.0      [18]  397805  ...      R
# 721       45043870.0  19043870.0   2544157.0      [18]  397805  ...  PG-13
# 722       45043870.0  19043870.0   2544157.0      [18]  397805  ...      R
# 723       45043870.0  19043870.0   2544157.0  [80, 18]  382659  ...  PG-13
# 724       45043870.0  19043870.0   2544157.0  [80, 18]  382659  ...      R
# 725       45043870.0  19043870.0   2544157.0  [80, 18]  382659  ...  PG-13
# 726       45043870.0  19043870.0   2544157.0  [80, 18]  382659  ...      R
# 727       45043870.0  19043870.0   2544157.0  [80, 18]  382659  ...  PG-13
# 728       45043870.0  19043870.0   2544157.0  [80, 18]  382659  ...      R
# 729       45043870.0  19043870.0   2544157.0  [80, 18]  382659  ...  PG-13
# 730       45043870.0  19043870.0   2544157.0  [80, 18]  382659  ...      R
# 731       45043870.0  19043870.0   2544157.0  [80, 18]  382659  ...  PG-13
# 732       45043870.0  19043870.0   2544157.0  [80, 18]  382659  ...      R
# 733       45043870.0  19043870.0   2544157.0  [80, 18]  382659  ...  PG-13
# 734       45043870.0  19043870.0   2544157.0  [80, 18]  382659  ...      R
# 735       45043870.0  19043870.0   2544157.0  [80, 18]  382659  ...  PG-13
# 736       45043870.0  19043870.0   2544157.0  [80, 18]  382659  ...      R
#
#                           genre                             director  \
# 709  Drama|Mystery and Suspense                                  NaN
# 710                      Comedy  David Hillenbrand|Scott Hillenbrand
# 711  Drama|Mystery and Suspense                                  NaN
# 712                      Comedy  David Hillenbrand|Scott Hillenbrand
# 713  Drama|Mystery and Suspense                                  NaN
# 714                      Comedy  David Hillenbrand|Scott Hillenbrand
# 715  Drama|Mystery and Suspense                                  NaN
# 716                      Comedy  David Hillenbrand|Scott Hillenbrand
# 717  Drama|Mystery and Suspense                                  NaN
# 718                      Comedy  David Hillenbrand|Scott Hillenbrand
# 719  Drama|Mystery and Suspense                                  NaN
# 720                      Comedy  David Hillenbrand|Scott Hillenbrand
# 721  Drama|Mystery and Suspense                                  NaN
# 722                      Comedy  David Hillenbrand|Scott Hillenbrand
# 723  Drama|Mystery and Suspense                                  NaN
# 724                      Comedy  David Hillenbrand|Scott Hillenbrand
# 725  Drama|Mystery and Suspense                                  NaN
# 726                      Comedy  David Hillenbrand|Scott Hillenbrand
# 727  Drama|Mystery and Suspense                                  NaN
# 728                      Comedy  David Hillenbrand|Scott Hillenbrand
# 729  Drama|Mystery and Suspense                                  NaN
# 730                      Comedy  David Hillenbrand|Scott Hillenbrand
# 731  Drama|Mystery and Suspense                                  NaN
# 732                      Comedy  David Hillenbrand|Scott Hillenbrand
# 733  Drama|Mystery and Suspense                                  NaN
# 734                      Comedy  David Hillenbrand|Scott Hillenbrand
# 735  Drama|Mystery and Suspense                                  NaN
# 736                      Comedy  David Hillenbrand|Scott Hillenbrand
#
#                                  writer theater_date      dvd_date  currency  \
# 709                                 NaN   2009-12-04  Mar 16, 2010         $
# 710  Patrick Casey|Joshua "Worm" Miller   2009-12-04  Apr 27, 2010       NaN
# 711                                 NaN   2009-12-04  Mar 16, 2010         $
# 712  Patrick Casey|Joshua "Worm" Miller   2009-12-04  Apr 27, 2010       NaN
# 713                                 NaN   2009-12-04  Mar 16, 2010         $
# 714  Patrick Casey|Joshua "Worm" Miller   2009-12-04  Apr 27, 2010       NaN
# 715                                 NaN   2009-12-04  Mar 16, 2010         $
# 716  Patrick Casey|Joshua "Worm" Miller   2009-12-04  Apr 27, 2010       NaN
# 717                                 NaN   2009-12-04  Mar 16, 2010         $
# 718  Patrick Casey|Joshua "Worm" Miller   2009-12-04  Apr 27, 2010       NaN
# 719                                 NaN   2009-12-04  Mar 16, 2010         $
# 720  Patrick Casey|Joshua "Worm" Miller   2009-12-04  Apr 27, 2010       NaN
# 721                                 NaN   2009-12-04  Mar 16, 2010         $
# 722  Patrick Casey|Joshua "Worm" Miller   2009-12-04  Apr 27, 2010       NaN
# 723                                 NaN   2009-12-04  Mar 16, 2010         $
# 724  Patrick Casey|Joshua "Worm" Miller   2009-12-04  Apr 27, 2010       NaN
# 725                                 NaN   2009-12-04  Mar 16, 2010         $
# 726  Patrick Casey|Joshua "Worm" Miller   2009-12-04  Apr 27, 2010       NaN
# 727                                 NaN   2009-12-04  Mar 16, 2010         $
# 728  Patrick Casey|Joshua "Worm" Miller   2009-12-04  Apr 27, 2010       NaN
# 729                                 NaN   2009-12-04  Mar 16, 2010         $
# 730  Patrick Casey|Joshua "Worm" Miller   2009-12-04  Apr 27, 2010       NaN
# 731                                 NaN   2009-12-04  Mar 16, 2010         $
# 732  Patrick Casey|Joshua "Worm" Miller   2009-12-04  Apr 27, 2010       NaN
# 733                                 NaN   2009-12-04  Mar 16, 2010         $
# 734  Patrick Casey|Joshua "Worm" Miller   2009-12-04  Apr 27, 2010       NaN
# 735                                 NaN   2009-12-04  Mar 16, 2010         $
# 736  Patrick Casey|Joshua "Worm" Miller   2009-12-04  Apr 27, 2010       NaN
#
#      box_office     runtime                 studio
# 709  15,988,876  88 minutes                    NaN
# 710         NaN  92 minutes  Full Circle Releasing
# 711  15,988,876  88 minutes                    NaN
# 712         NaN  92 minutes  Full Circle Releasing
# 713  15,988,876  88 minutes                    NaN
# 714         NaN  92 minutes  Full Circle Releasing
# 715  15,988,876  88 minutes                    NaN
# 716         NaN  92 minutes  Full Circle Releasing
# 717  15,988,876  88 minutes                    NaN
# 718         NaN  92 minutes  Full Circle Releasing
# 719  15,988,876  88 minutes                    NaN
# 720         NaN  92 minutes  Full Circle Releasing
# 721  15,988,876  88 minutes                    NaN
# 722         NaN  92 minutes  Full Circle Releasing
# 723  15,988,876  88 minutes                    NaN
# 724         NaN  92 minutes  Full Circle Releasing
# 725  15,988,876  88 minutes                    NaN
# 726         NaN  92 minutes  Full Circle Releasing
# 727  15,988,876  88 minutes                    NaN
# 728         NaN  92 minutes  Full Circle Releasing
# 729  15,988,876  88 minutes                    NaN
# 730         NaN  92 minutes  Full Circle Releasing
# 731  15,988,876  88 minutes                    NaN
# 732         NaN  92 minutes  Full Circle Releasing
# 733  15,988,876  88 minutes                    NaN
# 734         NaN  92 minutes  Full Circle Releasing
# 735  15,988,876  88 minutes                    NaN
# 736         NaN  92 minutes  Full Circle Releasing
#
# [28 rows x 37 columns]

# %%
#Most profitable genre

# %%
df_sql_budgets_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1445 entries, 1 to 2722
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 1445 non-null   int64
#  1   release_date       1445 non-null   datetime64[ns]
#  2   movie              1445 non-null   object
#  3   production_budget  1445 non-null   float64
#  4   domestic_gross     1445 non-null   float64
#  5   worldwide_gross    1445 non-null   float64
#  6   profit             1445 non-null   float64
#  7   profit_dom         1445 non-null   float64
#  8   movie_id           1445 non-null   object
#  9   primary_title      1445 non-null   object
#  10  averagerating      1445 non-null   float64
#  11  numvotes           1445 non-null   int64
#  12  genres             1444 non-null   object
#  13  start_year         1445 non-null   float64
#  14  primary_name       1445 non-null   object
#  15  person_id          1445 non-null   object
#  16  year               1445 non-null   float64
# dtypes: datetime64[ns](1), float64(8), int64(2), object(6)
# memory usage: 203.2+ KB

# %% [markdown]
# ### Most profitable Genre of the movies

# %%
#Most profitable genre
df_action  =df_sql_budgets_db[df_sql_budgets_db['genres'].str.contains("Action|Thriller|Crime|Mystery")==True]
df_drama   =df_sql_budgets_db[df_sql_budgets_db['genres'].str.contains("Drama|War|Family")==True]
df_romance =df_sql_budgets_db[df_sql_budgets_db['genres'].str.contains("Romance")==True]
df_horror  =df_sql_budgets_db[df_sql_budgets_db['genres'].str.contains("Horror")==True]
df_comedy  =df_sql_budgets_db[df_sql_budgets_db['genres'].str.contains("Comedy")==True]
df_docu    =df_sql_budgets_db[df_sql_budgets_db['genres'].str.contains("Documentary|Biography|History|News|Music")==True]
df_scifi   =df_sql_budgets_db[df_sql_budgets_db['genres'].str.contains("Sci-Fi")==True]
df_anime   =df_sql_budgets_db[df_sql_budgets_db['genres'].str.contains("Animation")==True]

# %%
df_list2  =[df_action,df_drama,df_horror,df_romance,df_comedy,df_scifi,df_docu,df_anime]
list_genres=['action','drama','horror','romance','comedy','sci-fi','docu','anime']

# %%
Lmeans_genre  = get_mean_values(df_list2,'profit')
Lstds_genres  = get_std_values(df_list2,'profit')
Lmeans_AR     = get_sum_values(df_list2,'averagerating')
Lstds_AR      = get_std_values(df_list2,'averagerating')
#Lmeans_runtime  = get_mean_values(df_list2,'runtime')
#Lstds_runtime   = get_std_values(df_list2,'runtime')
#Lstds_votes
# Out:
# 4528.0
# 4928.4
# 976.4
# 1128.9
# 3035.8
# 850.2
# 1523.1
# 658.5

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 4), constrained_layout=True)
#axs[0,0].bar(list_genres, sum_votes_list,  color='green', width=0.35)
axs[1].bar(list_genres, Lmeans_AR,  color='green', width=0.35)#,yerr=Lstds_AR)
axs[0].bar(list_genres, Lmeans_genre,color ='green',width = 0.35)#,yerr=Lstds_genres)
#axs[1,1].scatter(means_genres_list,mean_votes_list, color ='green', label=list_genres)
axs[0].set_ylabel('Mean Profit Value')
axs[0].set_title('Profit Vs Genres')
axs[0].grid(True, color = 'DarkTurquoise', alpha=1, linestyle = '--', linewidth = 0.5)

axs[1].set_ylabel('Mean Average Rating')
axs[1].set_title('Average Ratings Vs Genre')
axs[1].grid(True, color = 'DarkTurquoise', alpha=1, linestyle = '--', linewidth = 0.5)
plt.savefig('./figs/genres_profits_ratings.png')
plt.show()

# %% [markdown]
# ### Most Profitable director

# %%
#Most Profitable director/runtime/writer/actor
df_profit_dir = (df_sql_budgets_db.groupby(['primary_name']).sum()).sort_values(by='profit',
                                                                    ascending=False).head(10)

# %%
df_profit_dir
# Out:
#                            id  production_budget  domestic_gross  \
# primary_name
# Anthony Russo, Joe Russo   40        720000000.0    1.346647e+09
# James Wan                 196        370000000.0    8.254690e+08
# Joss Whedon                31        555600000.0    1.082285e+09
# Christopher Nolan         150        750000000.0    1.118801e+09
# Michael Bay               167        648000000.0    7.778736e+08
# Peter Jackson              62        750000000.0    8.164902e+08
# Francis Lawrence          254        522000000.0    1.149112e+09
# Bryan Singer              298        628000000.0    6.708550e+08
# Sam Mendes                 62        500000000.0    5.044345e+08
# Zack Snyder               208        950000000.0    9.424978e+08
#
#                           worldwide_gross        profit   profit_dom  \
# primary_name
# Anthony Russo, Joe Russo     3.902606e+09  3.182606e+09  626646789.0
# James Wan                    2.983618e+09  2.613618e+09  455468968.0
# Joss Whedon                  2.920950e+09  2.365350e+09  526685415.0
# Christopher Nolan            3.086180e+09  2.336180e+09  368801468.0
# Michael Bay                  2.911998e+09  2.263998e+09  129873593.0
# Peter Jackson                2.922948e+09  2.172948e+09   66490211.0
# Francis Lawrence             2.543192e+09  2.021192e+09  627112056.0
# Bryan Singer                 2.383073e+09  1.755073e+09   42854965.0
# Sam Mendes                   1.990148e+09  1.490148e+09    4434452.0
# Zack Snyder                  2.420920e+09  1.470920e+09   -7502178.0
#
#                           averagerating  numvotes  start_year     year
# primary_name
# Anthony Russo, Joe Russo           24.1   1920685      6048.0   6048.0
# James Wan                          21.8    995635      6046.0   6046.0
# Joss Whedon                        15.4   1849249      4027.0   4027.0
# Christopher Nolan                  33.7   4994749      8053.0   8053.0
# Michael Bay                        23.5    956722      8055.0   8055.0
# Peter Jackson                      23.1   1723813      6039.0   6039.0
# Francis Lawrence                   34.2   1449439     10071.0  10071.0
# Bryan Singer                       29.3   1445228      8061.0   8061.0
# Sam Mendes                         14.6    944725      4027.0   4027.0
# Zack Snyder                        33.2   1845493     10067.0  10067.0

# %% [markdown]
# RGB is a way of making colors. You have to to provide an amount of red, green, blue, and the transparency value to the

# %%
import seaborn as sns
sns.set_style("whitegrid")
ax1 = df_profit_dir.reset_index().plot(x='primary_name', y='profit', figsize=(12,6),kind="bar",
                                      rot =90, title="Profit Vs Director",color=(0.2, 0.4, 0.6, 0.6),  edgecolor='blue')
ax1.set_ylabel('Profit')
ax1.set_xlabel('Director')
#ax1.grid(linestyle='--', linewidth='0.2', color='blue') 
ax1.grid(True, color = 'DarkTurquoise', alpha=1, linestyle = '--', linewidth = 0.5)
plt.savefig('./figs/most_profitable_director.png')
plt.show()

# %% [markdown]
# * Based on the above plot that shows the top 10 most profitable directors , Russo brothers look like the most profitable director duo.

# %% [markdown]
# ### Most profitable time of the year to release the movies

# %%
#Most profitable time of the year
Lets use the dataframe that has profit and year information but also has most number of entries

# %%
df_budgets_movie
# Out:
#       id release_date                                        movie  \
# 0      1   2009-12-18                                       Avatar
# 1      2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2      3   2019-06-07                                 Dark Phoenix
# 3      4   2015-05-01                      Avengers: Age of Ultron
# 4      5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
# ...   ..          ...                                          ...
# 5777  78   2018-12-31                                       Red 11
# 5778  79   1999-04-02                                    Following
# 5779  80   2005-07-13                Return to the Land of Wonders
# 5780  81   2015-09-29                         A Plague So Pleasant
# 5781  82   2005-08-05                            My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross        profit  \
# 0           425000000.0     760507625.0     2.776345e+09  2.351345e+09
# 1           410600000.0     241063875.0     1.045664e+09  6.350639e+08
# 2           350000000.0      42762350.0     1.497624e+08 -2.002376e+08
# 3           330600000.0     459005868.0     1.403014e+09  1.072414e+09
# 4           317000000.0     620181382.0     1.316722e+09  9.997217e+08
# ...                 ...             ...              ...           ...
# 5777             7000.0             0.0     0.000000e+00 -7.000000e+03
# 5778             6000.0         48482.0     2.404950e+05  2.344950e+05
# 5779             5000.0          1338.0     1.338000e+03 -3.662000e+03
# 5780             1400.0             0.0     0.000000e+00 -1.400000e+03
# 5781             1100.0        181041.0     1.810410e+05  1.799410e+05
#
#        profit_dom
# 0     335507625.0
# 1    -169536125.0
# 2    -307237650.0
# 3     128405868.0
# 4     303181382.0
# ...           ...
# 5777      -7000.0
# 5778      42482.0
# 5779      -3662.0
# 5780      -1400.0
# 5781     179941.0
#
# [5782 rows x 8 columns]

# %%
list_month  =["Nov-Jan","Feb-Apr","May-Jul","Aug-Oct"]

# %%
profit1   =df_get_monthly_profits(df_budgets_movie)
profit2   =df_get_monthly_profits(df_sql_budgets_db)

# %%
profit1
# Out:
# [66654451.67617237, 43220879.69148936, 103911604.85897435, 29765619.056978233]

# %%
profit2
# Out:
# [93004913.53488372, 108768044.76567657, 156302981.1810089, 48948611.167464115]

# %%
fig, ax1 = plt.subplots(figsize=(12,6))
x_axis = np.arange(len(list_month))
hhbars = ax1.bar(x_axis-0.2, profit1, width=0.4, color=(0.4, 0.4, 0.8, 0.8), edgecolor='black',label   ='DataFrame 1')
hhbars = ax1.bar(x_axis+0.2, profit2, width=0.4, color=(0.8, 0.2, 0.2, 0.8),  edgecolor='black', label ='DataFrame 2')

ax1.set_ylabel("Average Profit")
ax1.set_xlabel("Range of Months")
ax1.set_xticks(x_axis)
ax1.grid(True, color = 'DarkTurquoise', alpha=1, linestyle = '--', linewidth = 0.5)
ax1.set_xticklabels(list_month) # labels
plt.legend()
# Show graph
plt.savefig('./figs/most_profitable_time_of_year.png')
plt.show()

# %% [markdown]
# * The plot above shows the average profit for different time periods of an year. Summer months between
# May to July seem to be most profitable. This makes sense as that is the time when people are having vacations
# and enjoying. The second most profitable months seem to be Nov to Jan which are holiday months.

# %% [markdown]
# ### Conclusions

# %% [markdown]
# Based on the above analysis, I have found that sci-fi/animation movies are most profitable and popular movies. This can be seen from the plots that show average profit as a function of profit, and also the plot showing the most profitable movie, **Avatar followed by Averngers Infinity wars**, both of which belong to sci-fi and/pr anime category. **Russo brothers**, on average, are most profitable director duo, and movies released during summer months, **May to July** are on average are more pofitable.
#
# So I would suggest based on these findings to make a **sci-fi/anime movie with Russo brothers and release it during the months from May to July** to maximize the chances of profitabilty
