# %% [markdown]
# ## The goal of this Project is to make three recommendations for Microsoft that plans to get into the business of movie making. Based on our analysis we need to provide an input about the kind of movies that are profitable and are doing great

# %% [markdown]
# Import all the needed libraries for this project

# %%
# Run this cell without changes
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Define some functions that I need for the analysis.
# The function *convert_dollars_to_float* takes a dataframe and a column which is string but contains money in dollars, and converts it into a float

# %%
def convert_dollars_to_float(df, col):
    df[col] = df[col].str.replace('$', '')
    df[col] = df[col].str.replace(',', '')
    df[col] = df[col].astype(float)
    return df[col]

# %% [markdown]
# The three functions below are used to get mean, std and sum values for a list of dataframes.

# %%
def get_mean_values(df_list,col):
    mean_vals_list=[]
    for df in df_list:
        mean_vals_list.append(round(df[col].mean(),2))
    return mean_vals_list

# %%
def get_std_values(df_list, col):
    std_vals_list=[]
    for df in df_list:
        std_vals_list.append(round(df[col].std(),2))
    return std_vals_list

# %%
def get_sum_values(df_list,col):
    sum_vals_list=[]
    for df in df_list:
        sum_vals_list.append(round(df[col].sum(),2))
        print(round(df[col].sum(),2))
    return sum_vals_list

# %% [markdown]
# Open the connection to the database and load the sql tables. I will be using the tables *movie_basics,
# movie_ratings, persons* and *directors*.

# %%
conn = sqlite3.Connection("zippedData/im.db")
conn

# %%
q0 = """
SELECT *
FROM movie_basics
;
"""
df_movie_basics=pd.read_sql(q0, conn)
df_movie_basics
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 3                   NaN          Comedy,Drama
# 4                  80.0  Comedy,Drama,Fantasy
# ...                 ...                   ...
# 146139            123.0                 Drama
# 146140              NaN           Documentary
# 146141              NaN                Comedy
# 146142            116.0                  None
# 146143              NaN           Documentary
#
# [146144 rows x 6 columns]

# %%
#df_movie_basics.drop(columns=['runtime_minutes'],axis=1)
df_movie_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   movie_id         146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
q0 = """
SELECT *
FROM movie_ratings
;
"""

df_movie_ratings=pd.read_sql(q0, conn)
df_movie_ratings
# Out:
#          movie_id  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
q0 = """
SELECT *
FROM movie_akas
;
"""

df_movie_akas=pd.read_sql(q0, conn)
df_movie_akas
# Out:
#          movie_id  ordering                                    title region  \
# 0       tt0369610        10                            Джурасик свят     BG
# 1       tt0369610        11                        Jurashikku warudo     JP
# 2       tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3       tt0369610        13                  O Mundo dos Dinossauros     BR
# 4       tt0369610        14                           Jurassic World     FR
# ...           ...       ...                                      ...    ...
# 331698  tt9827784         2                       Sayonara kuchibiru   None
# 331699  tt9827784         3                            Farewell Song    XWW
# 331700  tt9880178         1                              La atención   None
# 331701  tt9880178         2                              La atención     ES
# 331702  tt9880178         3                            The Attention    XWW
#
#        language        types   attributes  is_original_title
# 0            bg         None         None                0.0
# 1          None  imdbDisplay         None                0.0
# 2          None  imdbDisplay         None                0.0
# 3          None         None  short title                0.0
# 4          None  imdbDisplay         None                0.0
# ...         ...          ...          ...                ...
# 331698     None     original         None                1.0
# 331699       en  imdbDisplay         None                0.0
# 331700     None     original         None                1.0
# 331701     None         None         None                0.0
# 331702       en  imdbDisplay         None                0.0
#
# [331703 rows x 8 columns]

# %%
df_movie_akas[df_movie_akas['language']=='en']
# Out:
#           movie_id  ordering                        title region language  \
# 87      tt10027708         2                    Miguelito    XWW       en
# 89      tt10027708         4                    Miguelito     AU       en
# 95       tt1014759        10  Alice Dar Sarzamin E Ajayeb     IE       en
# 127      tt1014759         3          Alice in Wonderland     JP       en
# 142     tt10225354         3               Returning Home    XWW       en
# ...            ...       ...                          ...    ...      ...
# 331679   tt9644084         3                   The Breath    XWW       en
# 331680   tt9654246         1    The Wild Man of the North    XWW       en
# 331683   tt9657946         1                       Homing    XWW       en
# 331699   tt9827784         3                Farewell Song    XWW       en
# 331702   tt9880178         3                The Attention    XWW       en
#
#               types attributes  is_original_title
# 87      imdbDisplay       None                0.0
# 89             None       None                0.0
# 95      imdbDisplay       None                0.0
# 127            None       None                0.0
# 142     alternative       None                0.0
# ...             ...        ...                ...
# 331679  alternative       None                0.0
# 331680  imdbDisplay       None                0.0
# 331683  imdbDisplay       None                0.0
# 331699  imdbDisplay       None                0.0
# 331702  imdbDisplay       None                0.0
#
# [22895 rows x 8 columns]

# %%
df_movie_akas.region.value_counts()
# Out:
# US     51490
# XWW    18467
# RU     13817
# DE     11634
# FR     10990
#        ...
# CF         1
# NC         1
# KN         1
# MQ         1
# LY         1
# Name: region, Length: 213, dtype: int64

# %%
df_movie_akas[df_movie_akas['region']=='US']
# Out:
#          movie_id  ordering                                        title  \
# 12      tt0369610        21                            Jurassic World 3D
# 20      tt0369610        29                               Jurassic World
# 21      tt0369610         2                                     Ebb Tide
# 28      tt0369610        36                             Jurassic Park IV
# 37      tt0369610        44                              Jurassic Park 4
# ...           ...       ...                                          ...
# 331645  tt9310460         6  Coconut the Little Dragon 2 Into the Jungle
# 331654  tt9358044         2                                  Hail Satan?
# 331673  tt9562694         5                                Alien Warfare
# 331686  tt9705860         1          Dusan Vukotic Croatian Oscar Winner
# 331694  tt9755806         1                                    Big Shark
#
#        region language        types                  attributes  \
# 12         US     None         None                 3-D version
# 20         US     None         None                        None
# 21         US     None         None          fake working title
# 28         US     None      working                        None
# 37         US     None         None  informal alternative title
# ...       ...      ...          ...                         ...
# 331645     US     None  imdbDisplay                        None
# 331654     US     None  imdbDisplay                        None
# 331673     US     None  imdbDisplay                        None
# 331686     US     None  imdbDisplay                        None
# 331694     US     None         None                        None
#
#         is_original_title
# 12                    0.0
# 20                    0.0
# 21                    0.0
# 28                    0.0
# 37                    0.0
# ...                   ...
# 331645                0.0
# 331654                0.0
# 331673                0.0
# 331686                0.0
# 331694                0.0
#
# [51490 rows x 8 columns]

# %% [markdown]
# # <span style="color:red"> **I should check if using region (USA) brings any change in the distriutions below. For this I will have to Join movie_akas sql table. I may come back to this if I have some more time** text</span>
# #### Here I am quering over maby SQL tables. My goal is to get one table that has info about movies, genres, ratings and directors. This definitely will have less data as compared to individual tables, but we need to have all this info for any given movie to do some sensible analysis.

# %%
q0 = """
SELECT 
    mbasics.movie_id,
    mbasics.primary_title,
    mbasics.start_year,
    mbasics.genres,
    mbasics.runtime_minutes,
    p.primary_name,
    p.person_id,
    mratings.averagerating,
    mratings.numvotes,
    pr.category
    FROM movie_basics AS mbasics
JOIN
    movie_ratings AS mratings
    USING(movie_id)
JOIN
    directors AS dir
    USING(movie_id)
JOIN
    principals AS pr
    USING(movie_id)    
JOIN
    persons AS p
    USING(person_id)      
WHERE
    pr.category='director'
;
"""
df_movie_db=pd.read_sql(q0, conn)
df_movie_db
# Out:
#          movie_id        primary_title  start_year        genres  \
# 0       tt0323808      The Wicker Tree        2011  Drama,Horror
# 1       tt0417610    Asleep in the Sun        2010       Fantasy
# 2       tt0417610    Asleep in the Sun        2010       Fantasy
# 3       tt0469152  Smoking/Non-Smoking        2011         Drama
# 4       tt0469152  Smoking/Non-Smoking        2011         Drama
# ...           ...                  ...         ...           ...
# 437148  tt9670894             Veergati        2019        Action
# 437149  tt9670894             Veergati        2019        Action
# 437150  tt9670894             Veergati        2019        Action
# 437151  tt9670894             Veergati        2019        Action
# 437152  tt9681728      A Russian Youth        2019     Drama,War
#
#         runtime_minutes          primary_name   person_id  averagerating  \
# 0                  96.0           Robin Hardy   nm0362736            3.9
# 1                  83.0     Alejandro Chomski   nm1145057            6.4
# 2                  83.0     Alejandro Chomski   nm1145057            6.4
# 3                  84.0     Alyssa R. Bennett   nm0707738            7.2
# 4                  84.0     Alyssa R. Bennett   nm0707738            7.2
# ...                 ...                   ...         ...            ...
# 437148             61.0          Vishal Desai   nm4039933            6.9
# 437149             61.0            Raju Desai   nm7840985            6.9
# 437150             61.0            Raju Desai   nm7840985            6.9
# 437151             61.0            Raju Desai   nm7840985            6.9
# 437152             72.0  Alexander Zolotukhin  nm10436661            6.6
#
#         numvotes  category
# 0           2328  director
# 1             80  director
# 2             80  director
# 3             88  director
# 4             88  director
# ...          ...       ...
# 437148        10  director
# 437149        10  director
# 437150        10  director
# 437151        10  director
# 437152        34  director
#
# [437153 rows x 10 columns]

# %% [markdown]
# Removing some duplicate entries. Need to investiagte why they are there!

# %%
df_movie_db=df_movie_db.drop_duplicates()

# %%
df_movie_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80341 entries, 0 to 437152
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   movie_id         80341 non-null  object
#  1   primary_title    80341 non-null  object
#  2   start_year       80341 non-null  int64
#  3   genres           79595 non-null  object
#  4   runtime_minutes  72027 non-null  float64
#  5   primary_name     80341 non-null  object
#  6   person_id        80341 non-null  object
#  7   averagerating    80341 non-null  float64
#  8   numvotes         80341 non-null  int64
#  9   category         80341 non-null  object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 6.7+ MB

# %%
df_movie_db["genres"].value_counts()
# Out:
# Drama                        12412
# Documentary                  11730
# Comedy                        5604
# Horror                        3523
# Comedy,Drama                  2740
#                              ...
# Comedy,History,News              1
# Biography,History,Romance        1
# Drama,War,Western                1
# History,Sci-Fi,Thriller          1
# Biography,History,Music          1
# Name: genres, Length: 893, dtype: int64

# %% [markdown]
# The genres are not so well defined and in many cases a movie falls under more than one category. This means
# the way my analysis is going to be done will have some uncertanity/errors associated to it
#
# Also I notice many duplicates. I dont quite understand the origin for that. But in any case I decide to drop
# further using *person_id* and *primary_title*

# %%
df_movie_db=df_movie_db.drop_duplicates(subset='person_id', keep="first")
#df_movie_db=df_movie_db.drop_duplicates(subset='primary_title', keep="first")
df_movie_db['primary_title'].value_counts()
# Out:
# World of Death                                       61
# Milano 55,1. Cronaca di una settimana di passioni    59
# Our RoboCop Remake                                   54
# 50 Kisses                                            45
# Hanky Code: The Movie                                30
#                                                      ..
# Sweeping Forward                                      1
# Kurangu Bommai                                        1
# The LXD: The Secrets of the Ra                        1
# Fósforo Frio                                          1
# The Class of 92                                       1
# Name: primary_title, Length: 43920, dtype: int64

# %% [markdown]
# It is not clear to me, why there are more than 1 entry for a given movie. It looks like thre are multiple
# directors associated with some movies which could be possible, but 61 is too many!!
# For now I will keep only the first entry, but will have to revisit!

# %%
df_movie_db[df_movie_db['primary_title']=='World of Death']
# Out:
#          movie_id   primary_title  start_year                genres  \
# 307815  tt4050462  World of Death        2016  Comedy,Horror,Sci-Fi
# 307907  tt4050462  World of Death        2016  Comedy,Horror,Sci-Fi
# 307953  tt4050462  World of Death        2016  Comedy,Horror,Sci-Fi
# 308045  tt4050462  World of Death        2016  Comedy,Horror,Sci-Fi
# 308229  tt4050462  World of Death        2016  Comedy,Horror,Sci-Fi
# ...           ...             ...         ...                   ...
# 311357  tt4050462  World of Death        2016  Comedy,Horror,Sci-Fi
# 311403  tt4050462  World of Death        2016  Comedy,Horror,Sci-Fi
# 311449  tt4050462  World of Death        2016  Comedy,Horror,Sci-Fi
# 311495  tt4050462  World of Death        2016  Comedy,Horror,Sci-Fi
# 311541  tt4050462  World of Death        2016  Comedy,Horror,Sci-Fi
#
#         runtime_minutes         primary_name  person_id  averagerating  \
# 307815            142.0     Jay Wade Edwards  nm0250080            7.2
# 307907            142.0        A Normale Jef  nm0340236            7.2
# 307953            142.0      Craig Ouellette  nm0653573            7.2
# 308045            142.0         Steven Payne  nm1121352            7.2
# 308229            142.0          Doug Turner  nm1726235            7.2
# ...                 ...                  ...        ...            ...
# 311357            142.0  Dimitri Castiglioni  nm7153452            7.2
# 311403            142.0        M.J. Koleszar  nm7403267            7.2
# 311449            142.0         Félix Catala  nm8337607            7.2
# 311495            142.0       Timothy Thomas  nm8372979            7.2
# 311541            142.0    Ryan Henry Knight  nm9160937            7.2
#
#         numvotes  category
# 307815        31  director
# 307907        31  director
# 307953        31  director
# 308045        31  director
# 308229        31  director
# ...          ...       ...
# 311357        31  director
# 311403        31  director
# 311449        31  director
# 311495        31  director
# 311541        31  director
#
# [61 rows x 10 columns]

# %%
df_movie_db['numvotes'].value_counts()
# Out:
# 6        2424
# 5        2213
# 7        2080
# 8        1873
# 9        1514
#          ...
# 74998       1
# 7409        1
# 5360        1
# 5328        1
# 4098        1
# Name: numvotes, Length: 4707, dtype: int64

# %%
df_movie_db=df_movie_db.drop_duplicates(subset='primary_title', keep="first")
df_movie_db["primary_name"].value_counts()
#df_movie_db.head(50)
# Out:
# Mark Lewis                   4
# Adam Green                   3
# Bing Wang                    3
# Ryan McKenna                 3
# John Williams                3
#                             ..
# Nick Brandestini             1
# Örn Marino Arnarson          1
# Georgiy Skomorovskiy         1
# Alfonso Cortés-Cavanillas    1
# Walmer Sitohang              1
# Name: primary_name, Length: 43654, dtype: int64

# %%
#df_genres=df_movie_db.groupby(['genres']).mean()
#df_genres
df_movie_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43920 entries, 0 to 437152
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   movie_id         43920 non-null  object
#  1   primary_title    43920 non-null  object
#  2   start_year       43920 non-null  int64
#  3   genres           43469 non-null  object
#  4   runtime_minutes  39468 non-null  float64
#  5   primary_name     43920 non-null  object
#  6   person_id        43920 non-null  object
#  7   averagerating    43920 non-null  float64
#  8   numvotes         43920 non-null  int64
#  9   category         43920 non-null  object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 3.7+ MB

# %%
df_movie_db[df_movie_db['genres'].isnull()]
# Out:
#          movie_id          primary_title  start_year genres  runtime_minutes  \
# 189     tt1472211      The Bounty Hunter        2010   None              NaN
# 2228    tt1790807      Pig Death Machine        2013   None             82.0
# 2414    tt1949541          Full Firearms        2012   None              NaN
# 2782    tt1543303     Die Haushaltshilfe        2010   None             60.0
# 2821    tt1603273        Bushidô Sixteen        2010   None            109.0
# ...           ...                    ...         ...    ...              ...
# 435007  tt7980216       From All Corners        2018   None             93.0
# 435099  tt9030796         Possible Faces        2018   None            132.0
# 435398  tt7308686                  Anaan        2017   None              NaN
# 435715  tt7131966   Sakura sakura sakura        2017   None              NaN
# 436576  tt7961082  Wangdrak's Rain Boots        2018   None             90.0
#
#              primary_name  person_id  averagerating  numvotes  category
# 189          Yugesh Walia  nm1288886            6.3        29  director
# 2228        Jon Moritsugu  nm0605748            6.0        20  director
# 2414        Emily Wardill  nm4484801            7.5        10  director
# 2782        Anna Hoffmann  nm3292830            9.2         6  director
# 2821    Tomoyuki Furumaya  nm0299197            6.6        59  director
# ...                   ...        ...            ...       ...       ...
# 435007    Ryusuke Okajima  nm3928208            7.6         5  director
# 435099      Kang-hyun Lee  nm6544270            6.4         7  director
# 435398      Rajesh Kushte  nm9234987            6.0         5  director
# 435715       Masami Murai  nm5814328            1.0        76  director
# 436576        Lhapal Gyal  nm9603882            7.4        12  director
#
# [451 rows x 10 columns]

# %%
df_movie_db.sort_values(by=['start_year'], ascending=False).head(20)
# Out:
#           movie_id                           primary_title  start_year  \
# 437152   tt9681728                         A Russian Youth        2019
# 430606   tt8083606                                  Rebels        2019
# 6442    tt10135068     1964: O Brasil entre armas e livros        2019
# 291765   tt6155456                                 Juanita        2019
# 6445    tt10215026                             Mon Jane na        2019
# 6446    tt10366330                               Night Out        2019
# 108756   tt1673732                            Break Clause        2019
# 291813   tt6354568                            Camp Wedding        2019
# 358569   tt7257718                                  Kalavu        2019
# 430610   tt8090580                               Noah Land        2019
# 411899   tt8995268                    An Engineer Imagines        2019
# 411844   tt8336022                                The Toad        2019
# 421923   tt6927492                                    Mope        2019
# 421916   tt6916348             The Warrior Queen of Jhansi        2019
# 411859   tt8529134                              Ham on Rye        2019
# 53485   tt10279010  Chasing the Dragon II: Wild Wild Bunch        2019
# 430700   tt8768868                           Out of Bounds        2019
# 53482   tt10077998                       The Unknown Saint        2019
# 6440    tt10078290               The Spy Behind Home Plate        2019
# 430501   tt7534102                   The Swallows of Kabul        2019
#
#                         genres  runtime_minutes          primary_name  \
# 437152               Drama,War             72.0  Alexander Zolotukhin
# 430606                  Comedy             87.0         Allan Mauduit
# 6442               Documentary            127.0        Lucas Ferrugem
# 291765                   Drama             90.0         Clark Johnson
# 6445                    Action              NaN      Shagufta Rafique
# 6446           Comedy,Thriller            116.0          Rakesh Adiga
# 108756          Drama,Thriller              NaN        Andrew Tiernan
# 291813   Comedy,Horror,Mystery             97.0           Greg Emetaz
# 358569                Thriller              NaN       Murali Karthick
# 430610                   Drama            109.0           Cenk Ertürk
# 411899             Documentary             80.0       Marcus Robinson
# 411844                Thriller             84.0   Gabriel Rios-Hannon
# 421923            Comedy,Drama            105.0           Lucas Heyne
# 421916                   Drama              NaN           Swati Bhise
# 411859            Comedy,Drama             85.0        Tyler Taormina
# 53485   Action,Biography,Crime            101.0            Jason Kwan
# 430700       Crime,Drama,Sport             82.0              SD Green
# 53482                  Mystery              NaN     Alaa Eddine Aljem
# 6440               Documentary            101.0         Aviva Kempner
# 430501               Animation             80.0   Eléa Gobbé-Mévellec
#
#          person_id  averagerating  numvotes  category
# 437152  nm10436661            6.6        34  director
# 430606   nm1879912            6.4       231  director
# 6442    nm10598050            6.9       230  director
# 291765   nm0424800            6.0      1535  director
# 6445     nm2756464            6.5        31  director
# 6446     nm5923758            8.1        10  director
# 108756   nm0862907            8.0        20  director
# 291813   nm1723456            8.5        10  director
# 358569   nm9204898            7.4        30  director
# 430610   nm4005848            9.4        63  director
# 411899  nm10120558            7.2         5  director
# 411844   nm7352130            7.2        13  director
# 421923   nm1627093            7.6        66  director
# 421916   nm2455306            8.6         7  director
# 411859   nm8272772            8.2        12  director
# 53485    nm1712317            6.1        37  director
# 430700  nm10006548            8.4        33  director
# 53482    nm5893763            6.4        10  director
# 6440     nm0447476            7.2        12  director
# 430501   nm4922287            6.2        54  director

# %% [markdown]
# Here I am just making different dataframes based on some genres that I picked. I am not droping NAN values because I am sliicing dataframe based on certain conditions which wont be affected by NAN values

# %%
df_action_db  =df_movie_db[df_movie_db['genres'].str.contains("Action|Thriller")==True]
df_drama_db   =df_movie_db[df_movie_db['genres'].str.contains("Drama")==True]
df_romance_db =df_movie_db[df_movie_db['genres'].str.contains("Romance")==True]
df_horror_db  =df_movie_db[df_movie_db['genres'].str.contains("Horror")==True]
df_comedy_db  =df_movie_db[df_movie_db['genres'].str.contains("Comedy")==True]
df_docu_db    =df_movie_db[df_movie_db['genres'].str.contains("Documentary|Biography|History")==True]
df_scifi_db   =df_movie_db[df_movie_db['genres'].str.contains("Sci-Fi")==True]
df_anime_db   =df_movie_db[df_movie_db['genres'].str.contains("Animation")==True]

# %%
df_anime_db
# Out:
#          movie_id                                      primary_title  \
# 18      tt0884726                    Legends of Oz: Dorothy's Return
# 51      tt1071809        The Amazing Adventures of the Living Corpse
# 806     tt1613031  Doraemon The Movie: Nobita's Great Battle of t...
# 966     tt1719580                                     Pequeñas voces
# 992     tt1753496                           Resident Evil: Damnation
# ...           ...                                                ...
# 436719  tt6685596                      Maya the Bee: The Honey Games
# 436981  tt7945396                                  Un homme est mort
# 437012  tt8194128                                Travelogue Tel Aviv
# 437020  tt8328740                                         Okko's Inn
# 437124  tt9255718                              The Royal Tutor Movie
#
#         start_year                         genres  runtime_minutes  \
# 18            2013     Adventure,Animation,Family             88.0
# 51            2012       Action,Animation,Fantasy             88.0
# 806           2010     Adventure,Animation,Comedy             99.0
# 966           2011    Animation,Documentary,Drama             76.0
# 992           2012        Action,Animation,Horror            100.0
# ...            ...                            ...              ...
# 436719        2018     Adventure,Animation,Comedy             85.0
# 436981        2018                Animation,Drama             66.0
# 437012        2017  Adventure,Animation,Biography              6.0
# 437020        2018      Adventure,Animation,Drama             94.0
# 437124        2019                      Animation             60.0
#
#                   primary_name  person_id  averagerating  numvotes  category
# 18                   Will Finn  nm0278181            5.5      5351  director
# 51          Justin Paul Ritter  nm0728772            3.6       220  director
# 806                Kôzô Kusuba  nm0476417            6.8       251  director
# 966     Jairo Eduardo Carrillo  nm2070616            7.6       113  director
# 992              Makoto Kamiya  nm0436780            6.6     17164  director
# ...                        ...        ...            ...       ...       ...
# 436719             Noel Cleary  nm0165866            5.6       562  director
# 436981           Olivier Cossu  nm5693323            6.6        62  director
# 437012          Samuel Patthey  nm9727113            6.8         8  director
# 437020           Kitarô Kôsaka  nm0466901            6.9       251  director
# 437124         Katsuya Kikuchi  nm2630770            6.7        10  director
#
# [1131 rows x 10 columns]

# %%
fig, axs = plt.subplots(3, 3, figsize=(10, 6), constrained_layout=True)
axs[0,0].hist(x=df_drama_db['averagerating'], bins=30,align='left', color='blue')
#ax1.hist(x=wins, bins=range(8), align="left", color="green")
#axs[0,0].set_xticks(range(20))
axs[0,0].set_xlabel("Avg. Ratings")
axs[0,0].set_ylabel("Counts")
axs[0,0].set_title("Drama")
axs[0,1].hist(x=df_action_db['averagerating'], bins=30,align='left', color='blue')
axs[0,1].set_xlabel("Avg. Ratings")
axs[0,1].set_ylabel("Counts")
axs[0,1].set_title("Action/Thriller")
axs[0,2].hist(x=df_horror_db['averagerating'], bins=30,align='left', color='blue')
axs[0,2].set_xlabel("Avg. Ratings")
axs[0,2].set_ylabel("Counts")
axs[0,2].set_title("Horror")
axs[1,0].hist(x=df_comedy_db['averagerating'], bins=30,align='left', color='blue')
axs[1,0].set_xlabel("Avg. Ratings")
axs[1,0].set_ylabel("Counts")
axs[1,0].set_title("Comedy")
axs[1,1].hist(x=df_romance_db['averagerating'], bins=30,align='left', color='blue')
axs[1,1].set_xlabel("Avg. Ratings")
axs[1,1].set_ylabel("Frequency")
axs[1,1].set_title("Counts")
axs[1,2].hist(x=df_docu_db['averagerating'], bins=30,align='left', color='blue')
axs[1,2].set_xlabel("Avg. Ratings")
axs[1,2].set_ylabel("Counts")
axs[1,2].set_title("Docu/Bio/Hist")
axs[2,0].hist(x=df_scifi_db['averagerating'], bins=30,align='left', color='blue')
axs[2,0].set_xlabel("Avg. Ratings")
axs[2,0].set_ylabel("Counts")
axs[2,0].set_title("Sci-Fi")
axs[2,1].hist(x=df_anime_db['averagerating'], bins=30,align='left', color='blue')
axs[2,1].set_xlabel("Avg. Ratings")
axs[2,1].set_ylabel("Counts")
axs[2,1].set_title("Animation")
axs[2,2].hist(x=df_scifi_db['numvotes'], align='left', color='blue')
axs[2,2].set_xlabel("Num of Votes")
axs[2,2].set_ylabel("Counts")
axs[2,2].set_title("cumulative # of votes")

#axs[2,2].scatter(df_genres['numvotes'], df_genres['averagerating'], color="green")
#axs[2,2].set_xlabel("Num of votes")
#axs[2,2].set_title("Avg. Ratings");
# Out:
# Text(0.5, 1.0, 'cumulative # of votes')

# %%
df_movie_db['primary_title'].value_counts()
# Out:
# Yowamushi Pedal Re: Ride    1
# Possum Walk                 1
# Belik                       1
# Doce Amianto                1
# Nowhere in Moravia          1
#                            ..
# Cam                         1
# The Age of Love             1
# Unfinished                  1
# The Way We Weren't          1
# The Class of 92             1
# Name: primary_title, Length: 43920, dtype: int64

# %%
df_movie_db["primary_name"].value_counts()
# Out:
# Mark Lewis                   4
# Adam Green                   3
# Bing Wang                    3
# Ryan McKenna                 3
# John Williams                3
#                             ..
# Nick Brandestini             1
# Örn Marino Arnarson          1
# Georgiy Skomorovskiy         1
# Alfonso Cortés-Cavanillas    1
# Walmer Sitohang              1
# Name: primary_name, Length: 43654, dtype: int64

# %%
df_movie_db[df_movie_db['primary_name']=='Mark Lewis']
# Out:
#          movie_id                             primary_title  start_year  \
# 16358   tt1568924                  Cane Toads: The Conquest        2010
# 117969  tt2375232                           Wild Girl Waltz        2012
# 220935  tt3838154                                 Invention        2015
# 368091  tt7301126  Silk Road: Drugs, Death and the Dark Web        2017
#
#                     genres  runtime_minutes primary_name  person_id  \
# 16358   Comedy,Documentary             85.0   Mark Lewis  nm0507503
# 117969              Comedy             82.0   Mark Lewis  nm3378947
# 220935                None             87.0   Mark Lewis  nm0507505
# 368091         Documentary             88.0   Mark Lewis  nm2129029
#
#         averagerating  numvotes  category
# 16358             7.0       403  director
# 117969            7.5        14  director
# 220935            6.7        17  director
# 368091            7.3       177  director

# %%
df_list=[df_action_db,df_drama_db,df_horror_db,df_romance_db,df_comedy_db,df_scifi_db,df_docu_db,df_anime_db]
list_genres=['action','drama','horror','romance','comedy','sci-fi','docu','anime']

# %%
means_genres_list = get_mean_values(df_list,'averagerating')
stds_genres_list  = get_std_values(df_list,'averagerating')
sum_votes_list    = get_sum_values(df_list,'numvotes')
means_votes_list  = get_mean_values(df_list,'numvotes')
stds_votes_list   = get_std_values(df_list,'numvotes')
stds_votes_list
# Out:
# 54865361
# 48625727
# 10773931
# 12177637
# 35015315
# 18050039
# 10808696
# 11603381
# [48516.49, 21919.16, 17945.21, 19375.3, 26851.26, 83095.45, 11191.24, 49890.4]

# %%
df_action_db.describe()
# Out:
#         start_year  runtime_minutes  averagerating      numvotes
# count  7570.000000      6878.000000    7570.000000  7.570000e+03
# mean   2013.852576        97.077930       5.727847  7.247736e+03
# std       2.584226        21.504832       1.473223  4.851649e+04
# min    2010.000000        10.000000       1.000000  5.000000e+00
# 25%    2012.000000        85.000000       4.700000  2.000000e+01
# 50%    2014.000000        93.000000       5.800000  9.500000e+01
# 75%    2016.000000       106.000000       6.800000  6.157500e+02
# max    2019.000000       321.000000       9.800000  1.841066e+06

# %%
#stds_genres_list=get_std_values(df_list,'averagerating')
#stds_genres_list

# %%
#print("mean # of votes {:0.2f}".format(df_action_db['numvotes'].sum()))
#print("mean # of votes {:0.2f}".format(df_docu_db['numvotes'].sum()))
#print("mean # of votes {:0.2f}".format(df_drama_db['numvotes'].sum()))
#print("mean # of votes {:0.2f}".format(df_scifi_db['numvotes'].sum()))
fig, axs = plt.subplots(2, 2, figsize=(10, 6), constrained_layout=True)
axs[0,0].bar(list_genres, sum_votes_list,  color='green', width=0.35)
axs[0,1].bar(list_genres, means_votes_list,  color='green', width=0.35,)#yerr=stds_votes_list)
axs[1,0].bar(list_genres, means_genres_list,color ='green',width = 0.35,yerr=stds_genres_list)
#axs[1,1].scatter(means_genres_list,mean_votes_list, color ='green', label=list_genres)
axs[0,0].set_ylabel('Sum of all votes')
axs[0,0].set_title('Total Votes')
#axs[0,0].legend()
axs[0,1].set_ylabel('Mean value of votes')
axs[0,1].set_title('Mean number of Votes')
#axs[0,1].legend()
axs[1,0].set_xlabel("Genres")
axs[1,0].set_ylabel("Mean Values")
axs[1,0].set_title("Mean Avg. Ratings as a function of genres")
#axs[1,1].legend()
plt.show()

# %% [markdown]
# I am unsure about if I need to use *movie_akas* which has languaue info and region. I will think about it at the end

# %% [markdown]
# Now I will look at the *csv* and *tsv (I converted it into csv file)* files

# %%
df_gross_movie = pd.read_csv("zippedData/bom.movie_gross.csv")
df_gross_movie
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# 0        652000000  2010
# 1        691300000  2010
# 2        664300000  2010
# 3        535700000  2010
# 4        513900000  2010
# ...            ...   ...
# 3382           NaN  2018
# 3383           NaN  2018
# 3384           NaN  2018
# 3385           NaN  2018
# 3386           NaN  2018
#
# [3387 rows x 5 columns]

# %%
df_gross_movie.studio.value_counts()
# Out:
# IFC      166
# Uni.     147
# WB       140
# Fox      136
# Magn.    136
#         ...
# ELS        1
# IVP        1
# U/P        1
# TVC        1
# CFI        1
# Name: studio, Length: 257, dtype: int64

# %%
#df_gross_movie[df_gross_movie['title'].str.contains('Harry')=='True']
df_gross_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
df_budgets_movie = pd.read_csv("zippedData/tn.movie_budgets.csv")
df_budgets_movie
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# 1         $410,600,000   $241,063,875  $1,045,663,875
# 2         $350,000,000    $42,762,350    $149,762,350
# 3         $330,600,000   $459,005,868  $1,403,013,963
# 4         $317,000,000   $620,181,382  $1,316,721,747
# ...                ...            ...             ...
# 5777            $7,000             $0              $0
# 5778            $6,000        $48,482        $240,495
# 5779            $5,000         $1,338          $1,338
# 5780            $1,400             $0              $0
# 5781            $1,100       $181,041        $181,041
#
# [5782 rows x 6 columns]

# %%
df_budgets_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
df_budgets_movie.movie.value_counts()
# Out:
# Halloween                                   3
# King Kong                                   3
# Home                                        3
# Total Recall                                2
# The Gambler                                 2
#                                            ..
# Pump                                        1
# XXX: State of the Union                     1
# School for Scoundrels                       1
# The Twilight Saga: Breaking Dawn, Part 2    1
# Friday                                      1
# Name: movie, Length: 5698, dtype: int64

# %%
df_budgets_movie[df_budgets_movie['movie']=='Halloween']
# Out:
#       id  release_date      movie production_budget domestic_gross  \
# 3014  15  Aug 31, 2007  Halloween       $15,000,000    $58,269,151
# 3535  36  Oct 19, 2018  Halloween       $10,000,000   $159,342,015
# 5536  37  Oct 17, 1978  Halloween          $325,000    $47,000,000
#
#      worldwide_gross
# 3014     $77,514,401
# 3535    $254,900,667
# 5536     $70,000,000

# %%
df_budgets_movie[df_budgets_movie.duplicated()==True]
# Out:
# Empty DataFrame
# Columns: [id, release_date, movie, production_budget, domestic_gross, worldwide_gross]
# Index: []

# %%
df_gross_movie.title.value_counts()
# Out:
# Bluebeard                                  2
# Red Riding Hood                            1
# Beauty and the Dogs                        1
# Monster Hunt 2                             1
# Saint John of Las Vegas                    1
#                                           ..
# The Company You Keep                       1
# The Warrior's Way                          1
# Circumstance                               1
# The Babadook                               1
# Antonio Lopez 1970: Sex Fashion & Disco    1
# Name: title, Length: 3386, dtype: int64

# %% [markdown]
# Looking at the two files, one named gross and other named budget, it seems budgets file has more entries and
# it contains production budget as well as gross income. So instead of merging, I will just use budgets file. The gross file might contain the info of movies that are not in budgets file, but without the production budget info, I cant do much there
#
# The functions below just convert the columns with dollars info into floats so that I can calculate profit

# %%
convert_dollars_to_float(df_budgets_movie,'production_budget')
convert_dollars_to_float(df_budgets_movie,'domestic_gross')
convert_dollars_to_float(df_budgets_movie,'worldwide_gross')
# Out:
# 0       2.776345e+09
# 1       1.045664e+09
# 2       1.497624e+08
# 3       1.403014e+09
# 4       1.316722e+09
#             ...
# 5777    0.000000e+00
# 5778    2.404950e+05
# 5779    1.338000e+03
# 5780    0.000000e+00
# 5781    1.810410e+05
# Name: worldwide_gross, Length: 5782, dtype: float64

# %% [markdown]
# I will define profit (in absolute dollars) using the worldwide gross income  and also domestic profit

# %%
df_budgets_movie['profit']=df_budgets_movie['worldwide_gross']-df_budgets_movie['production_budget']
df_budgets_movie['profit_dom']=df_budgets_movie['domestic_gross']-df_budgets_movie['production_budget']
df_budgets_movie
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross        profit  \
# 0           425000000.0     760507625.0     2.776345e+09  2.351345e+09
# 1           410600000.0     241063875.0     1.045664e+09  6.350639e+08
# 2           350000000.0      42762350.0     1.497624e+08 -2.002376e+08
# 3           330600000.0     459005868.0     1.403014e+09  1.072414e+09
# 4           317000000.0     620181382.0     1.316722e+09  9.997217e+08
# ...                 ...             ...              ...           ...
# 5777             7000.0             0.0     0.000000e+00 -7.000000e+03
# 5778             6000.0         48482.0     2.404950e+05  2.344950e+05
# 5779             5000.0          1338.0     1.338000e+03 -3.662000e+03
# 5780             1400.0             0.0     0.000000e+00 -1.400000e+03
# 5781             1100.0        181041.0     1.810410e+05  1.799410e+05
#
#        profit_dom
# 0     335507625.0
# 1    -169536125.0
# 2    -307237650.0
# 3     128405868.0
# 4     303181382.0
# ...           ...
# 5777      -7000.0
# 5778      42482.0
# 5779      -3662.0
# 5780      -1400.0
# 5781     179941.0
#
# [5782 rows x 8 columns]

# %%
#df_budgets_movie[df_budgets_movie['movie']=='King Kong']
df_budgets_movie.sort_values(by=['profit'], ascending=False).head(20)
# Out:
#      id  release_date                                          movie  \
# 0     1  Dec 18, 2009                                         Avatar
# 42   43  Dec 19, 1997                                        Titanic
# 6     7  Apr 27, 2018                         Avengers: Infinity War
# 5     6  Dec 18, 2015           Star Wars Ep. VII: The Force Awakens
# 33   34  Jun 12, 2015                                 Jurassic World
# 66   67   Apr 3, 2015                                      Furious 7
# 26   27   May 4, 2012                                   The Avengers
# 260  61  Jul 15, 2011  Harry Potter and the Deathly Hallows: Part II
# 41   42  Feb 16, 2018                                  Black Panther
# 112  13  Jun 22, 2018                 Jurassic World: Fallen Kingdom
# 155  56  Nov 22, 2013                                         Frozen
# 134  35  Mar 17, 2017                           Beauty and the Beast
# 672  73  Jul 10, 2015                                        Minions
# 3     4   May 1, 2015                        Avengers: Age of Ultron
# 425  26  Dec 17, 2003  The Lord of the Rings: The Return of the King
# 43   44  Jun 15, 2018                                  Incredibles 2
# 47   48   May 3, 2013                                     Iron Man 3
# 4     5  Dec 15, 2017              Star Wars Ep. VIII: The Last Jedi
# 135  36  Dec 21, 2018                                        Aquaman
# 22   23  Apr 14, 2017                        The Fate of the Furious
#
#      production_budget  domestic_gross  worldwide_gross        profit
# 0          425000000.0     760507625.0     2.776345e+09  2.351345e+09
# 42         200000000.0     659363944.0     2.208208e+09  2.008208e+09
# 6          300000000.0     678815482.0     2.048134e+09  1.748134e+09
# 5          306000000.0     936662225.0     2.053311e+09  1.747311e+09
# 33         215000000.0     652270625.0     1.648855e+09  1.433855e+09
# 66         190000000.0     353007020.0     1.518723e+09  1.328723e+09
# 26         225000000.0     623279547.0     1.517936e+09  1.292936e+09
# 260        125000000.0     381193157.0     1.341693e+09  1.216693e+09
# 41         200000000.0     700059566.0     1.348258e+09  1.148258e+09
# 112        170000000.0     417719760.0     1.305773e+09  1.135773e+09
# 155        150000000.0     400738009.0     1.272470e+09  1.122470e+09
# 134        160000000.0     504014165.0     1.259200e+09  1.099200e+09
# 672         74000000.0     336045770.0     1.160336e+09  1.086336e+09
# 3          330600000.0     459005868.0     1.403014e+09  1.072414e+09
# 425         94000000.0     377845905.0     1.141403e+09  1.047403e+09
# 43         200000000.0     608581744.0     1.242521e+09  1.042521e+09
# 47         200000000.0     408992272.0     1.215392e+09  1.015392e+09
# 4          317000000.0     620181382.0     1.316722e+09  9.997217e+08
# 135        160000000.0     335061807.0     1.146895e+09  9.868946e+08
# 22         250000000.0     225764765.0     1.234846e+09  9.848463e+08

# %%
#sorted_df_world = df_budgets_movie.sort_values(by=['profit'], ascending=False)
#sorted_df.head(10)

# %%
 #dftest.sort_values(by=['popularity'], ascending=False)
#print(df_gross_movie['title'].value_counts(), df_budgets_movie['movie'].value_counts(), df_Movie_comb['title'].value_counts())

# %% [markdown]
# ### Reading the other csv files, these files have ids for genres, but I do not know where the values for these ids are defined. So pretty mucg genre_id is uselss as of now

# %%
df_tmdb_movie = pd.read_csv("zippedData/tmdb.movies.csv",index_col=0)
df_tmdb_movie.head(50)
# Out:
#                    genre_ids     id original_language  \
# 0            [12, 14, 10751]  12444                en
# 1        [14, 12, 16, 10751]  10191                en
# 2              [12, 28, 878]  10138                en
# 3            [16, 35, 10751]    862                en
# 4              [28, 878, 12]  27205                en
# 5            [12, 14, 10751]  32657                en
# 6          [28, 12, 14, 878]  19995                en
# 7            [16, 10751, 35]  10193                en
# 8            [16, 10751, 35]  20352                en
# 9   [16, 28, 35, 10751, 878]  38055                en
# 10           [16, 35, 10751]    863                en
# 11           [10751, 14, 12]  12155                en
# 12              [53, 12, 28]  27578                en
# 13               [16, 10751]  38757                en
# 14                  [27, 80]  41439                en
# 15       [12, 14, 18, 10749]  24021                en
# 16             [28, 53, 878]  20504                en
# 17            [10402, 10749]  52371                nl
# 18              [28, 18, 53]   2502                en
# 19            [18, 53, 9648]  11324                en
# 20        [28, 18, 9648, 53]   2501                en
# 21                  [28, 35]  37834                en
# 22           [12, 10751, 14]  10140                en
# 23               [18, 10749]  41233                en
# 24      [53, 28, 12, 35, 80]  34544                en
# 25                  [18, 36]  45269                en
# 26          [28, 35, 80, 53]   9737                en
# 27       [28, 12, 10751, 14]  10196                en
# 28         [28, 878, 12, 53]  34851                en
# 29                      [18]  37799                en
# 30                  [28, 53]  38234                en
# 31                  [18, 36]    568                en
# 32         [28, 53, 878, 12]     95                en
# 33        [28, 18, 9648, 53]   2503                en
# 34              [12, 14, 28]  18823                en
# 35               [35, 10749]  34806                en
# 36              [28, 12, 18]  20662                en
# 37           [35, 14, 10751]  35019                en
# 38   [35, 12, 14, 16, 10751]  10192                en
# 39                      [35]  37735                en
# 40      [14, 12, 28, 35, 18]  27022                en
# 41           [28, 35, 10749]  22538                en
# 42                      [35]  38365                en
# 43               [35, 10749]    239                en
# 44          [80, 18, 28, 53]  41283                en
# 45                      [27]   7978                en
# 46                  [28, 53]  44048                en
# 47                  [18, 53]  44214                en
# 48       [16, 12, 10751, 14]  44683                en
# 49               [10749, 18]  61979                es
#
#                                        original_title  popularity  \
# 0        Harry Potter and the Deathly Hallows: Part 1      33.533
# 1                            How to Train Your Dragon      28.734
# 2                                          Iron Man 2      28.515
# 3                                           Toy Story      28.005
# 4                                           Inception      27.920
# 5   Percy Jackson & the Olympians: The Lightning T...      26.691
# 6                                              Avatar      26.526
# 7                                         Toy Story 3      24.445
# 8                                       Despicable Me      23.673
# 9                                            Megamind      22.855
# 10                                        Toy Story 2      22.698
# 11                                Alice in Wonderland      22.020
# 12                                    The Expendables      21.517
# 13                                            Tangled      21.511
# 14                                             Saw 3D      20.370
# 15                         The Twilight Saga: Eclipse      20.340
# 16                                    The Book of Eli      18.985
# 17                                         LelleBelle      18.586
# 18                               The Bourne Supremacy      18.199
# 19                                     Shutter Island      18.060
# 20                                The Bourne Identity      17.935
# 21                                     Knight and Day      17.713
# 22  The Chronicles of Narnia: The Voyage of the Da...      17.382
# 23                                         Step Up 3D      17.174
# 24                                         The A-Team      17.097
# 25                                  The King's Speech      16.798
# 26                                           Bad Boys      16.608
# 27                                 The Last Airbender      16.595
# 28                                          Predators      16.216
# 29                                 The Social Network      15.889
# 30                         Undisputed III: Redemption      15.886
# 31                                          Apollo 13      15.855
# 32                                         Armageddon      15.799
# 33                               The Bourne Ultimatum      15.620
# 34                                Clash of the Titans      15.574
# 35                                   The Back-Up Plan      15.490
# 36                                         Robin Hood      15.444
# 37                      Nanny McPhee and the Big Bang      15.213
# 38                                Shrek Forever After      15.041
# 39                                             Easy A      14.690
# 40                          The Sorcerer's Apprentice      14.463
# 41                        Scott Pilgrim vs. the World      14.383
# 42                                          Grown Ups      14.291
# 43                                   Some Like It Hot      14.200
# 44                                             Faster      14.172
# 45                                        The Wolfman      14.030
# 46                                        Unstoppable      14.010
# 47                                         Black Swan      13.745
# 48             Tinker Bell and the Great Fairy Rescue      13.724
# 49                         Tres metros sobre el cielo      13.721
#
#    release_date                                              title  \
# 0    2010-11-19       Harry Potter and the Deathly Hallows: Part 1
# 1    2010-03-26                           How to Train Your Dragon
# 2    2010-05-07                                         Iron Man 2
# 3    1995-11-22                                          Toy Story
# 4    2010-07-16                                          Inception
# 5    2010-02-11  Percy Jackson & the Olympians: The Lightning T...
# 6    2009-12-18                                             Avatar
# 7    2010-06-17                                        Toy Story 3
# 8    2010-07-09                                      Despicable Me
# 9    2010-11-04                                           Megamind
# 10   1999-11-24                                        Toy Story 2
# 11   2010-03-05                                Alice in Wonderland
# 12   2010-08-03                                    The Expendables
# 13   2010-11-24                                            Tangled
# 14   2010-10-28                             Saw: The Final Chapter
# 15   2010-06-23                         The Twilight Saga: Eclipse
# 16   2010-01-11                                    The Book of Eli
# 17   2010-10-09                                         LelleBelle
# 18   2004-07-23                               The Bourne Supremacy
# 19   2010-02-18                                     Shutter Island
# 20   2002-06-14                                The Bourne Identity
# 21   2010-06-23                                     Knight and Day
# 22   2010-12-10  The Chronicles of Narnia: The Voyage of the Da...
# 23   2010-08-06                                         Step Up 3D
# 24   2010-06-11                                         The A-Team
# 25   2010-09-06                                  The King's Speech
# 26   1995-04-07                                           Bad Boys
# 27   2010-07-01                                 The Last Airbender
# 28   2010-07-03                                          Predators
# 29   2010-10-01                                 The Social Network
# 30   2010-05-22                         Undisputed III: Redemption
# 31   1995-06-30                                          Apollo 13
# 32   1998-07-01                                         Armageddon
# 33   2007-08-03                               The Bourne Ultimatum
# 34   2010-04-02                                Clash of the Titans
# 35   2010-04-23                                   The Back-Up Plan
# 36   2010-05-14                                         Robin Hood
# 37   2010-08-20                      Nanny McPhee and the Big Bang
# 38   2010-05-16                                Shrek Forever After
# 39   2010-09-17                                             Easy A
# 40   2010-07-13                          The Sorcerer's Apprentice
# 41   2010-08-13                        Scott Pilgrim vs. the World
# 42   2010-06-24                                          Grown Ups
# 43   1959-03-18                                   Some Like It Hot
# 44   2010-11-23                                             Faster
# 45   2010-02-12                                        The Wolfman
# 46   2010-11-12                                        Unstoppable
# 47   2010-12-03                                         Black Swan
# 48   2010-09-21             Tinker Bell and the Great Fairy Rescue
# 49   2010-12-20                           Three Steps Above Heaven
#
#     vote_average  vote_count
# 0            7.7       10788
# 1            7.7        7610
# 2            6.8       12368
# 3            7.9       10174
# 4            8.3       22186
# 5            6.1        4229
# 6            7.4       18676
# 7            7.7        8340
# 8            7.2       10057
# 9            6.8        3635
# 10           7.5        7553
# 11           6.6        8713
# 12           6.1        4647
# 13           7.5        6407
# 14           6.0        1488
# 15           6.0        4909
# 16           6.7        3495
# 17           4.5          36
# 18           7.3        4367
# 19           8.1       12625
# 20           7.4        5406
# 21           6.0        2494
# 22           6.3        3196
# 23           6.7        1160
# 24           6.3        2703
# 25           7.7        5013
# 26           6.6        2936
# 27           4.6        2143
# 28           6.1        1979
# 29           7.2        6116
# 30           7.4         302
# 31           7.4        2821
# 32           6.7        4267
# 33           7.4        4440
# 34           5.7        3714
# 35           6.0         806
# 36           6.3        2569
# 37           6.1         953
# 38           6.1        3843
# 39           6.8        4168
# 40           5.9        2879
# 41           7.3        3882
# 42           6.1        3171
# 43           8.2        1562
# 44           6.2         895
# 45           5.7        1009
# 46           6.4        1913
# 47           7.6        8374
# 48           6.5         451
# 49           7.5         960

# %%
df_tmdb_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26517 entries, 0 to 26516
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   genre_ids          26517 non-null  object
#  1   id                 26517 non-null  int64
#  2   original_language  26517 non-null  object
#  3   original_title     26517 non-null  object
#  4   popularity         26517 non-null  float64
#  5   release_date       26517 non-null  object
#  6   title              26517 non-null  object
#  7   vote_average       26517 non-null  float64
#  8   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 2.0+ MB

# %%
df_tmdb_movie['title'].value_counts()
# Out:
# Home                        7
# Eden                        7
# The Gift                    5
# Truth or Dare               5
# The Box                     5
#                            ..
# The Bates Haunting          1
# Shanghai Belle              1
# Porcupine                   1
# Haunting of the Innocent    1
# Geography Club              1
# Name: title, Length: 24688, dtype: int64

# %%
df_tmdb_movie[df_tmdb_movie['title']=='Home']
# Out:
#                       genre_ids      id original_language original_title  \
# 3525                 [18, 9648]   79580                ru            Dom
# 9651                         []  237303                en           Home
# 14262  [14, 35, 16, 878, 10751]  228161                en           Home
# 19580                        []  409371                en           Home
# 20446           [27, 18, 10751]  381507                en           Home
# 20455                      [18]  388223                en           Home
# 23694                     [878]  496256                en           Home
#
#        popularity release_date title  vote_average  vote_count
# 3525        1.823   2011-11-11  Home           5.4          11
# 9651        0.840   2013-11-22  Home           7.0           2
# 14262      12.835   2015-03-27  Home           6.8        2372
# 19580       0.672   2016-08-01  Home           7.0           1
# 20446       0.600   2016-03-01  Home           4.7          14
# 20455       0.600   2016-03-17  Home           4.5           2
# 23694       0.600   2017-04-30  Home           4.0           1

# %%
#df.style.format({"DOB": lambda t: t.strftime("%m/%d/%Y")})
#df_budgets_movie.style.format({"release_date": lambda t: t.strftime("%Y-%m-%d")})
#df_budgets_movie['release_date'] = pd.to_datetime(df_budgets_movie['release_date'])

# %% [markdown]
# Changing the release_date column to datetime object and a format that I plan to use for tmdb data table as well so that I can merge on them

# %%
df_budgets_movie['release_date'] = pd.to_datetime(df_budgets_movie['release_date'])
df_budgets_movie.style.format({"release_date": lambda t: t.strftime("%Y-%m-%d")})
df_budgets_movie
# Out:
#       id release_date                                        movie  \
# 0      1   2009-12-18                                       Avatar
# 1      2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2      3   2019-06-07                                 Dark Phoenix
# 3      4   2015-05-01                      Avengers: Age of Ultron
# 4      5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
# ...   ..          ...                                          ...
# 5777  78   2018-12-31                                       Red 11
# 5778  79   1999-04-02                                    Following
# 5779  80   2005-07-13                Return to the Land of Wonders
# 5780  81   2015-09-29                         A Plague So Pleasant
# 5781  82   2005-08-05                            My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross        profit  \
# 0           425000000.0     760507625.0     2.776345e+09  2.351345e+09
# 1           410600000.0     241063875.0     1.045664e+09  6.350639e+08
# 2           350000000.0      42762350.0     1.497624e+08 -2.002376e+08
# 3           330600000.0     459005868.0     1.403014e+09  1.072414e+09
# 4           317000000.0     620181382.0     1.316722e+09  9.997217e+08
# ...                 ...             ...              ...           ...
# 5777             7000.0             0.0     0.000000e+00 -7.000000e+03
# 5778             6000.0         48482.0     2.404950e+05  2.344950e+05
# 5779             5000.0          1338.0     1.338000e+03 -3.662000e+03
# 5780             1400.0             0.0     0.000000e+00 -1.400000e+03
# 5781             1100.0        181041.0     1.810410e+05  1.799410e+05
#
#        profit_dom
# 0     335507625.0
# 1    -169536125.0
# 2    -307237650.0
# 3     128405868.0
# 4     303181382.0
# ...           ...
# 5777      -7000.0
# 5778      42482.0
# 5779      -3662.0
# 5780      -1400.0
# 5781     179941.0
#
# [5782 rows x 8 columns]

# %%
df_tmdb_movie['release_date'] = pd.to_datetime(df_tmdb_movie['release_date'])
df_tmdb_movie.style.format({"release_date": lambda t: t.strftime("%Y-%m-%d")})
df_tmdb_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26517 entries, 0 to 26516
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   genre_ids          26517 non-null  object
#  1   id                 26517 non-null  int64
#  2   original_language  26517 non-null  object
#  3   original_title     26517 non-null  object
#  4   popularity         26517 non-null  float64
#  5   release_date       26517 non-null  datetime64[ns]
#  6   title              26517 non-null  object
#  7   vote_average       26517 non-null  float64
#  8   vote_count         26517 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 3.3+ MB

# %% [markdown]
# #### Lets merge budgets information with popularity and vote info from tmdb file

# %%
df_budg_tmdb=pd.merge(df_budgets_movie,df_tmdb_movie,how='inner',left_on='movie', right_on='original_title')
df_budg_tmdb
# Out:
#       id_x release_date_x                                        movie  \
# 0        1     2009-12-18                                       Avatar
# 1        2     2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2        4     2015-05-01                      Avengers: Age of Ultron
# 3        7     2018-04-27                       Avengers: Infinity War
# 4        9     2017-11-17                               Justice League
# ...    ...            ...                                          ...
# 2311    49     2015-09-01                                       Exeter
# 2312    51     2015-04-21                                          Ten
# 2313    54     2014-12-31                                    Dry Spell
# 2314    56     2013-01-04                     All Superheroes Must Die
# 2315    73     2012-01-13                                    Newlyweds
#
#       production_budget  domestic_gross  worldwide_gross        profit  \
# 0           425000000.0     760507625.0     2.776345e+09  2.351345e+09
# 1           410600000.0     241063875.0     1.045664e+09  6.350639e+08
# 2           330600000.0     459005868.0     1.403014e+09  1.072414e+09
# 3           300000000.0     678815482.0     2.048134e+09  1.748134e+09
# 4           300000000.0     229024295.0     6.559452e+08  3.559452e+08
# ...                 ...             ...              ...           ...
# 2311            25000.0             0.0     4.897920e+05  4.647920e+05
# 2312            25000.0             0.0     0.000000e+00 -2.500000e+04
# 2313            22000.0             0.0     0.000000e+00 -2.200000e+04
# 2314            20000.0             0.0     0.000000e+00 -2.000000e+04
# 2315             9000.0          4584.0     4.584000e+03 -4.416000e+03
#
#        profit_dom           genre_ids    id_y original_language  \
# 0     335507625.0   [28, 12, 14, 878]   19995                en
# 1    -169536125.0        [12, 28, 14]    1865                en
# 2     128405868.0       [28, 12, 878]   99861                en
# 3     378815482.0        [12, 28, 14]  299536                en
# 4     -70975705.0   [28, 12, 14, 878]  141052                en
# ...           ...                 ...     ...               ...
# 2311     -25000.0            [53, 27]  226458                en
# 2312     -25000.0  [12, 27, 9648, 53]  279516                en
# 2313     -22000.0         [35, 10749]  255266                en
# 2314     -20000.0           [878, 53]   86304                en
# 2315      -4416.0         [35, 10749]   72766                en
#
#                                    original_title  popularity release_date_y  \
# 0                                          Avatar      26.526     2009-12-18
# 1     Pirates of the Caribbean: On Stranger Tides      30.579     2011-05-20
# 2                         Avengers: Age of Ultron      44.383     2015-05-01
# 3                          Avengers: Infinity War      80.773     2018-04-27
# 4                                  Justice League      34.953     2017-11-17
# ...                                           ...         ...            ...
# 2311                                       Exeter       5.934     2015-03-26
# 2312                                          Ten       1.575     2014-03-28
# 2313                                    Dry Spell       0.600     2013-02-14
# 2314                     All Superheroes Must Die       2.078     2013-01-04
# 2315                                    Newlyweds       1.973     2011-12-26
#
#                                             title  vote_average  vote_count
# 0                                          Avatar           7.4       18676
# 1     Pirates of the Caribbean: On Stranger Tides           6.4        8571
# 2                         Avengers: Age of Ultron           7.3       13457
# 3                          Avengers: Infinity War           8.3       13948
# 4                                  Justice League           6.2        7510
# ...                                           ...           ...         ...
# 2311                                       Exeter           4.7         121
# 2312                                          Ten           5.4           5
# 2313                                    Dry Spell           6.0           1
# 2314                     All Superheroes Must Die           3.9          19
# 2315                                    Newlyweds           5.4           7
#
# [2316 rows x 17 columns]

# %%
dftest2[dftest2.duplicated()==True]
df_budg_tmdb[df_budg_tmdb['title']=='Justice League']
# Out:
#    id_x release_date_x           movie  production_budget  domestic_gross  \
# 4     9     2017-11-17  Justice League        300000000.0     229024295.0
# 5     9     2017-11-17  Justice League        300000000.0     229024295.0
#
#    worldwide_gross       profit  profit_dom          genre_ids    id_y  \
# 4      655945209.0  355945209.0 -70975705.0  [28, 12, 14, 878]  141052
# 5      655945209.0  355945209.0 -70975705.0  [28, 12, 14, 878]  141052
#
#   original_language  original_title  popularity release_date_y  \
# 4                en  Justice League      34.953     2017-11-17
# 5                en  Justice League      34.953     2017-11-17
#
#             title  vote_average  vote_count
# 4  Justice League           6.2        7510
# 5  Justice League           6.2        7510

# %%
dftest2=df_budg_tmdb[df_budg_tmdb['release_date_x']==dftest['release_date_y']]
dftest2.shape
# Out:
# (1401, 17)

# %%
df_budg_tmdb.shape
# Out:
# (2316, 17)

# %%
df_budg_tmdb = df_budg_tmdb.drop_duplicates()
dftest2      = dftest2.drop_duplicates()

# %%
print(df_budg_tmdb.shape,dftest2.shape)
# Out:
# (2144, 17) (1271, 17)

# %%
dftest2['movie'].value_counts()
# Out:
# Legend                    2
# Robin Hood                2
# 300: Rise of an Empire    1
# Dinner for Schmucks       1
# The Dog Lover             1
#                          ..
# Carol                     1
# Widows                    1
# LOL                       1
# Zootopia                  1
# Bridesmaids               1
# Name: movie, Length: 1269, dtype: int64

# %%
dftest2=dftest2[dftest2['original_language']=='en']
dftest2['movie'].value_counts()
# Out:
# Robin Hood                2
# Legend                    2
# 300: Rise of an Empire    1
# Hot Tub Time Machine 2    1
# The First Purge           1
#                          ..
# Safe House                1
# Carol                     1
# Widows                    1
# LOL                       1
# Bridesmaids               1
# Name: movie, Length: 1239, dtype: int64

# %%
#dftest2=dftest2.drop_duplicates(subset='release_date_y', keep="first & last")
#dftest2=dftest2.drop_duplicates()
#dftest2[dftest2['title']=='Robin Hood']
dftest2
# Out:
#       id_x release_date_x                                        movie  \
# 0        1     2009-12-18                                       Avatar
# 1        2     2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2        4     2015-05-01                      Avengers: Age of Ultron
# 3        7     2018-04-27                       Avengers: Infinity War
# 4        9     2017-11-17                               Justice League
# ...    ...            ...                                          ...
# 2295    20     2015-07-31                                     Counting
# 2296    22     2014-02-14                           Down and Dangerous
# 2298    25     2015-09-01                               Run, Hide, Die
# 2308    38     2016-03-18                                       Krisha
# 2314    56     2013-01-04                     All Superheroes Must Die
#
#       production_budget  domestic_gross  worldwide_gross        profit  \
# 0           425000000.0     760507625.0     2.776345e+09  2.351345e+09
# 1           410600000.0     241063875.0     1.045664e+09  6.350639e+08
# 2           330600000.0     459005868.0     1.403014e+09  1.072414e+09
# 3           300000000.0     678815482.0     2.048134e+09  1.748134e+09
# 4           300000000.0     229024295.0     6.559452e+08  3.559452e+08
# ...                 ...             ...              ...           ...
# 2295            50000.0          8374.0     8.374000e+03 -4.162600e+04
# 2296            50000.0             0.0     0.000000e+00 -5.000000e+04
# 2298            50000.0             0.0     0.000000e+00 -5.000000e+04
# 2308            30000.0        144822.0     1.448220e+05  1.148220e+05
# 2314            20000.0             0.0     0.000000e+00 -2.000000e+04
#
#        profit_dom          genre_ids    id_y original_language  \
# 0     335507625.0  [28, 12, 14, 878]   19995                en
# 1    -169536125.0       [12, 28, 14]    1865                en
# 2     128405868.0      [28, 12, 878]   99861                en
# 3     378815482.0       [12, 28, 14]  299536                en
# 4     -70975705.0  [28, 12, 14, 878]  141052                en
# ...           ...                ...     ...               ...
# 2295     -41626.0               [99]  322745                en
# 2296     -50000.0       [80, 53, 18]  164286                en
# 2298     -50000.0           [53, 27]  290391                en
# 2308     114822.0               [18]  323929                en
# 2314     -20000.0          [878, 53]   86304                en
#
#                                    original_title  popularity release_date_y  \
# 0                                          Avatar      26.526     2009-12-18
# 1     Pirates of the Caribbean: On Stranger Tides      30.579     2011-05-20
# 2                         Avengers: Age of Ultron      44.383     2015-05-01
# 3                          Avengers: Infinity War      80.773     2018-04-27
# 4                                  Justice League      34.953     2017-11-17
# ...                                           ...         ...            ...
# 2295                                     Counting       0.600     2015-07-31
# 2296                           Down and Dangerous       2.621     2014-02-14
# 2298                               Run, Hide, Die       0.600     2015-09-01
# 2308                                       Krisha       5.288     2016-03-18
# 2314                     All Superheroes Must Die       2.078     2013-01-04
#
#                                             title  vote_average  vote_count
# 0                                          Avatar           7.4       18676
# 1     Pirates of the Caribbean: On Stranger Tides           6.4        8571
# 2                         Avengers: Age of Ultron           7.3       13457
# 3                          Avengers: Infinity War           8.3       13948
# 4                                  Justice League           6.2        7510
# ...                                           ...           ...         ...
# 2295                                     Counting           8.3           3
# 2296                           Down and Dangerous           4.3           9
# 2298                               Run, Hide, Die           3.5           2
# 2308                                       Krisha           6.8          86
# 2314                     All Superheroes Must Die           3.9          19
#
# [1241 rows x 17 columns]

# %% [markdown]
# Create a small dataframe with only a few columns that I want to use

# %%
df_profit_pop =dftest2[['movie','profit','profit_dom','popularity','vote_average']].copy()

# %%
#dftest_new.sort_values(by=['profit','popularity','vote_average'], ascending=False,inplace=True)
df_profit_pop.sort_values(by=['profit'], ascending=False,inplace=True)
df_profit_pop =df_profit_pop.reset_index()
df_small=df_profit_pop.loc[0:20]
df_small
# Out:
#     index                            movie        profit   profit_dom  \
# 0       0                           Avatar  2.351345e+09  335507625.0
# 1       3           Avengers: Infinity War  1.748134e+09  378815482.0
# 2      26                   Jurassic World  1.433855e+09  437270625.0
# 3      58                        Furious 7  1.328723e+09  163007020.0
# 4      20                     The Avengers  1.292936e+09  398279547.0
# 5      34                    Black Panther  1.148258e+09  500059566.0
# 6      95   Jurassic World: Fallen Kingdom  1.135773e+09  247719760.0
# 7     114             Beauty and the Beast  1.099200e+09  344014165.0
# 8     402                          Minions  1.086336e+09  262045770.0
# 9       2          Avengers: Age of Ultron  1.072414e+09  128405868.0
# 10     35                    Incredibles 2  1.042521e+09  408581744.0
# 11     40                       Iron Man 3  1.015392e+09  208992272.0
# 12    117                          Aquaman  9.868946e+08  175061807.0
# 13     18          The Fate of the Furious  9.848463e+08  -24235235.0
# 14    388                  Despicable Me 3  9.597278e+08  189624300.0
# 15    384                  Despicable Me 2  8.992168e+08  292065385.0
# 16     28  Transformers: Age of Extinction  8.940391e+08   35439076.0
# 17     13       Captain America: Civil War  8.900694e+08  158084349.0
# 18    316   Jumanji: Welcome to the Jungle  8.744962e+08  314508916.0
# 19    135                         Zootopia  8.694296e+08  191268248.0
# 20     36     Rogue One: A Star Wars Story  8.491029e+08  332177324.0
#
#     popularity  vote_average
# 0       26.526           7.4
# 1       80.773           8.3
# 2       20.709           6.6
# 3       20.396           7.3
# 4       50.289           7.6
# 5       44.140           7.4
# 6       34.958           6.5
# 7       31.793           6.9
# 8        9.338           6.4
# 9       44.383           7.3
# 10      36.286           7.6
# 11      32.093           6.9
# 12      38.102           6.8
# 13      28.668           6.9
# 14      16.407           6.3
# 15      19.014           6.9
# 16      20.961           5.8
# 17      39.137           7.4
# 18      20.395           6.7
# 19      27.549           7.7
# 20      21.401           7.5

# %% [markdown]
#  I am normalizing each column by its mean value so that I can plot popularity, profit and vote average on same plot. This may not be very kosher but I think its okay for this study.

# %%
df_small['profit']      =df_small['profit']/df_small['profit'].mean()
df_small['profit_dom']  =df_small['profit_dom']/df_small['profit_dom'].mean()
df_small['popularity']  =df_small['popularity']/df_small['popularity'].mean()
df_small['vote_average'] =df_small['vote_average']/df_small['vote_average'].mean()
# Out:
# <ipython-input-139-ca237730ed85>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_small['profit']      =df_small['profit']/df_small['profit'].mean()
# <ipython-input-139-ca237730ed85>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_small['profit_dom']  =df_small['profit_dom']/df_small['profit_dom'].mean()
# <ipython-input-139-ca237730ed85>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_small['popularity']  =df_small['popularity']/df_small['popularity'].mean()
# <ipython-input-139-ca237730ed85>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_small['vote_average'] =df_small['vote_average']/df_small['vote_average'].mean()

# %%
df_small.plot(x="movie", y=["popularity", "vote_average", "profit" ,"profit_dom"], kind="bar", figsize=(14, 8))
# Out:
# <AxesSubplot:xlabel='movie'>

# %%
#df_small.plot(x="movie", y=["popularity", "vote_average","profit"], kind="bar", figsize=(9, 8))

# %%
#dftest=dftest.drop_duplicates(subset='release_date_x', keep="first")
ax2 = df_profit_pop.plot.scatter(x='profit',
                    y='profit_dom',
                    colormap='viridis')

# %%
df_rt_reviews_movie = pd.read_csv("zippedData/rt.reviews.csv")
df_rt_reviews_movie#['review'][0]
# Out:
#          id                                             review rating   fresh  \
# 0         3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1         3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2         3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3         3  Continuing along a line introduced in last yea...    NaN   fresh
# 4         3             ... a perverse twist on neorealism...     NaN   fresh
# ...     ...                                                ...    ...     ...
# 54427  2000  The real charm of this trifle is the deadpan c...    NaN   fresh
# 54428  2000                                                NaN    1/5  rotten
# 54429  2000                                                NaN    2/5  rotten
# 54430  2000                                                NaN  2.5/5  rotten
# 54431  2000                                                NaN    3/5   fresh
#
#                   critic  top_critic         publisher                date
# 0             PJ Nabarro           0   Patrick Nabarro   November 10, 2018
# 1         Annalee Newitz           0           io9.com        May 23, 2018
# 2           Sean Axmaker           0  Stream on Demand     January 4, 2018
# 3          Daniel Kasman           0              MUBI   November 16, 2017
# 4                    NaN           0      Cinema Scope    October 12, 2017
# ...                  ...         ...               ...                 ...
# 54427      Laura Sinagra           1     Village Voice  September 24, 2002
# 54428  Michael Szymanski           0        Zap2it.com  September 21, 2005
# 54429       Emanuel Levy           0   EmanuelLevy.Com       July 17, 2005
# 54430   Christopher Null           0    Filmcritic.com   September 7, 2003
# 54431    Nicolas Lacroix           0      Showbizz.net   November 12, 2002
#
# [54432 rows x 8 columns]

# %%
df_rt_info_movie = pd.read_csv("zippedData/rt.movie_info.tsv",sep='\t')
df_rt_info_movie
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# 0                   Action and Adventure|Classics|Drama    William Friedkin
# 1                     Drama|Science Fiction and Fantasy    David Cronenberg
# 2                     Drama|Musical and Performing Arts      Allison Anders
# 3                            Drama|Mystery and Suspense      Barry Levinson
# 4                                         Drama|Romance      Rodney Bennett
# ...                                                 ...                 ...
# 1555   Action and Adventure|Horror|Mystery and Suspense                 NaN
# 1556                 Comedy|Science Fiction and Fantasy        Steve Barron
# 1557  Classics|Comedy|Drama|Musical and Performing Arts      Gordon Douglas
# 1558    Comedy|Drama|Kids and Family|Sports and Fitness  David Mickey Evans
# 1559  Action and Adventure|Art House and Internation...                 NaN
#
#                                                 writer  theater_date  \
# 0                                       Ernest Tidyman   Oct 9, 1971
# 1                         David Cronenberg|Don DeLillo  Aug 17, 2012
# 2                                       Allison Anders  Sep 13, 1996
# 3                      Paul Attanasio|Michael Crichton   Dec 9, 1994
# 4                                         Giles Cooper           NaN
# ...                                                ...           ...
# 1555                                               NaN  Aug 18, 2006
# 1556  Terry Turner|Tom Davis|Dan Aykroyd|Bonnie Turner  Jul 23, 1993
# 1557                                               NaN   Jan 1, 1962
# 1558                  David Mickey Evans|Robert Gunter   Apr 1, 1993
# 1559                                        Luc Besson  Sep 27, 2001
#
#           dvd_date currency  box_office      runtime             studio
# 0     Sep 25, 2001      NaN         NaN  104 minutes                NaN
# 1      Jan 1, 2013        $     600,000  108 minutes  Entertainment One
# 2     Apr 18, 2000      NaN         NaN  116 minutes                NaN
# 3     Aug 27, 1997      NaN         NaN  128 minutes                NaN
# 4              NaN      NaN         NaN  200 minutes                NaN
# ...            ...      ...         ...          ...                ...
# 1555   Jan 2, 2007        $  33,886,034  106 minutes    New Line Cinema
# 1556  Apr 17, 2001      NaN         NaN   88 minutes  Paramount Vantage
# 1557  May 11, 2004      NaN         NaN  111 minutes                NaN
# 1558  Jan 29, 2002      NaN         NaN  101 minutes                NaN
# 1559  Feb 11, 2003      NaN         NaN   94 minutes  Columbia Pictures
#
# [1560 rows x 12 columns]

# %%
df_rt_info_movie['genre'].value_counts().head(20)
# Out:
# Drama                                               151
# Comedy                                              110
# Comedy|Drama                                         80
# Drama|Mystery and Suspense                           67
# Art House and International|Drama                    62
# Action and Adventure|Drama                           42
# Action and Adventure|Drama|Mystery and Suspense      40
# Drama|Romance                                        35
# Comedy|Romance                                       32
# Horror                                               31
# Art House and International|Comedy|Drama             31
# Action and Adventure|Science Fiction and Fantasy     24
# Comedy|Drama|Romance                                 23
# Classics|Drama                                       21
# Action and Adventure|Mystery and Suspense            20
# Action and Adventure                                 19
# Classics|Drama|Mystery and Suspense                  18
# Horror|Mystery and Suspense                          17
# Drama|Musical and Performing Arts                    14
# Documentary|Special Interest                         14
# Name: genre, dtype: int64

# %%
df_rt_info_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1560 non-null   int64
#  1   synopsis      1498 non-null   object
#  2   rating        1557 non-null   object
#  3   genre         1552 non-null   object
#  4   director      1361 non-null   object
#  5   writer        1111 non-null   object
#  6   theater_date  1201 non-null   object
#  7   dvd_date      1201 non-null   object
#  8   currency      340 non-null    object
#  9   box_office    340 non-null    object
#  10  runtime       1530 non-null   object
#  11  studio        494 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 146.4+ KB

# %%
df_rt_info_movie.dropna(subset=['director','genre'],inplace=True)
df_rt_info_movie
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1553  1993  A former child actor turned talent agent is hi...     PG
# 1554  1995  Special government agent James West, long on c...  PG-13
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
#
#                                                   genre            director  \
# 0                   Action and Adventure|Classics|Drama    William Friedkin
# 1                     Drama|Science Fiction and Fantasy    David Cronenberg
# 2                     Drama|Musical and Performing Arts      Allison Anders
# 3                            Drama|Mystery and Suspense      Barry Levinson
# 4                                         Drama|Romance      Rodney Bennett
# ...                                                 ...                 ...
# 1553                                             Comedy        James Lapine
# 1554                Action and Adventure|Comedy|Western    Barry Sonnenfeld
# 1556                 Comedy|Science Fiction and Fantasy        Steve Barron
# 1557  Classics|Comedy|Drama|Musical and Performing Arts      Gordon Douglas
# 1558    Comedy|Drama|Kids and Family|Sports and Fitness  David Mickey Evans
#
#                                                 writer  theater_date  \
# 0                                       Ernest Tidyman   Oct 9, 1971
# 1                         David Cronenberg|Don DeLillo  Aug 17, 2012
# 2                                       Allison Anders  Sep 13, 1996
# 3                      Paul Attanasio|Michael Crichton   Dec 9, 1994
# 4                                         Giles Cooper           NaN
# ...                                                ...           ...
# 1553                                               NaN   Jun 4, 1993
# 1554                                               NaN  Jun 30, 1999
# 1556  Terry Turner|Tom Davis|Dan Aykroyd|Bonnie Turner  Jul 23, 1993
# 1557                                               NaN   Jan 1, 1962
# 1558                  David Mickey Evans|Robert Gunter   Apr 1, 1993
#
#           dvd_date currency box_office      runtime                 studio
# 0     Sep 25, 2001      NaN        NaN  104 minutes                    NaN
# 1      Jan 1, 2013        $    600,000  108 minutes      Entertainment One
# 2     Apr 18, 2000      NaN        NaN  116 minutes                    NaN
# 3     Aug 27, 1997      NaN        NaN  128 minutes                    NaN
# 4              NaN      NaN        NaN  200 minutes                    NaN
# ...            ...      ...        ...          ...                    ...
# 1553   Apr 8, 2003      NaN        NaN   95 minutes                    NaN
# 1554  Nov 30, 1999      NaN        NaN  107 minutes  Warner Bros. Pictures
# 1556  Apr 17, 2001      NaN        NaN   88 minutes      Paramount Vantage
# 1557  May 11, 2004      NaN        NaN  111 minutes                    NaN
# 1558  Jan 29, 2002      NaN        NaN  101 minutes                    NaN
#
# [1360 rows x 12 columns]

# %%
#df_rt_info_movie[df_rt_info_movie['director']=='Woody Allen']

# %%
df_rt_info_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1360 entries, 0 to 1558
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1360 non-null   int64
#  1   synopsis      1321 non-null   object
#  2   rating        1360 non-null   object
#  3   genre         1360 non-null   object
#  4   director      1360 non-null   object
#  5   writer        1042 non-null   object
#  6   theater_date  1083 non-null   object
#  7   dvd_date      1083 non-null   object
#  8   currency      299 non-null    object
#  9   box_office    299 non-null    object
#  10  runtime       1344 non-null   object
#  11  studio        440 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 138.1+ KB

# %%
#df_rt_info_movie.groupby('genres')
df_genres=df_rt_info_movie.groupby(['director']).sum()
df_genres
# Out:
#                                   id
# director
# Adam Ravetch|Sarah Robertson     596
# Adam Shankman                    491
# Alex Kendrick|Stephen Kendrick  1149
# Alex Proyas                     1935
# Alexander Payne                 1646
# ...                              ...
# Will Canon                      1747
# William Friedkin                 674
# Woody Allen                      458
# Yimou Zhang                     1955
# Youssef Delara                  1334
#
# [274 rows x 1 columns]

# %%
# Out:
#                   genre_ids     id original_language       original_title  \
# 38  [35, 12, 14, 16, 10751]  10192                en  Shrek Forever After
#
#     popularity release_date                title  vote_average  vote_count
# 38      15.041   2010-05-16  Shrek Forever After           6.1        3843

# %%
df_rt_info_movie[df_rt_info_movie['id']==3]
# Out:
#    id                                           synopsis rating  \
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
#
#                                genre          director  \
# 1  Drama|Science Fiction and Fantasy  David Cronenberg
#
#                          writer  theater_date     dvd_date currency  \
# 1  David Cronenberg|Don DeLillo  Aug 17, 2012  Jan 1, 2013        $
#
#   box_office      runtime             studio
# 1    600,000  108 minutes  Entertainment One

# %%
df_rt_reviews_movie[df_rt_reviews_movie['id']==3]
# Out:
#      id                                             review rating   fresh  \
# 0     3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1     3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2     3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3     3  Continuing along a line introduced in last yea...    NaN   fresh
# 4     3             ... a perverse twist on neorealism...     NaN   fresh
# ..   ..                                                ...    ...     ...
# 158   3  Beyond its withering critique of contemporary ...    NaN   fresh
# 159   3  Threatens to soar and to be important, but it ...    3/5   fresh
# 160   3            A parade of hollow didactic encounters.    NaN  rotten
# 161   3  [An] agonisingly self-conscious and meagre pie...    2/5  rotten
# 162   3                                                NaN      B   fresh
#
#               critic  top_critic             publisher               date
# 0         PJ Nabarro           0       Patrick Nabarro  November 10, 2018
# 1     Annalee Newitz           0               io9.com       May 23, 2018
# 2       Sean Axmaker           0      Stream on Demand    January 4, 2018
# 3      Daniel Kasman           0                  MUBI  November 16, 2017
# 4                NaN           0          Cinema Scope   October 12, 2017
# ..               ...         ...                   ...                ...
# 158    David Jenkins           0     Little White Lies       May 25, 2012
# 159     Dave Calhoun           1              Time Out       May 25, 2012
# 160  Owen Gleiberman           1  Entertainment Weekly       May 25, 2012
# 161   Peter Bradshaw           0              Guardian       May 25, 2012
# 162     Emanuel Levy           0       EmanuelLevy.Com  December 25, 2012
#
# [163 rows x 8 columns]

# %% [markdown]
# ### <span style="color:red"> I am not yet sure what to do with these two tables. I can probably use the "df_rt_info_movie" table and study different genres and may be directors. </span>

# %%
df_sql_budgets_db =pd.merge(df_budgets_movie,df_movie_db,how='inner',left_on='movie', right_on='primary_title')
df_sql_budgets_db
# Out:
#       id release_date                                        movie  \
# 0      1   2009-12-18                                       Avatar
# 1      2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2      3   2019-06-07                                 Dark Phoenix
# 3      9   2017-11-17                               Justice League
# 4     13   2013-07-02                              The Lone Ranger
# ...   ..          ...                                          ...
# 1301  52   2015-12-01                                  Dutch Kills
# 1302  59   2011-11-25                                   The Ridges
# 1303  62   2014-12-31                         Stories of Our Lives
# 1304  68   2001-07-06                                         Cure
# 1305  81   2015-09-29                         A Plague So Pleasant
#
#       production_budget  domestic_gross  worldwide_gross        profit  \
# 0           425000000.0     760507625.0     2.776345e+09  2.351345e+09
# 1           410600000.0     241063875.0     1.045664e+09  6.350639e+08
# 2           350000000.0      42762350.0     1.497624e+08 -2.002376e+08
# 3           300000000.0     229024295.0     6.559452e+08  3.559452e+08
# 4           275000000.0      89302115.0     2.600021e+08 -1.499788e+07
# ...                 ...             ...              ...           ...
# 1301            25000.0             0.0     0.000000e+00 -2.500000e+04
# 1302            17300.0             0.0     0.000000e+00 -1.730000e+04
# 1303            15000.0             0.0     0.000000e+00 -1.500000e+04
# 1304            10000.0         94596.0     9.459600e+04  8.459600e+04
# 1305             1400.0             0.0     0.000000e+00 -1.400000e+03
#
#        profit_dom   movie_id                                primary_title  \
# 0     335507625.0  tt1775309                                       Avatar
# 1    -169536125.0  tt1298650  Pirates of the Caribbean: On Stranger Tides
# 2    -307237650.0  tt6565702                                 Dark Phoenix
# 3     -70975705.0  tt0974015                               Justice League
# 4    -185697885.0  tt1210819                              The Lone Ranger
# ...           ...        ...                                          ...
# 1301     -25000.0  tt2759066                                  Dutch Kills
# 1302     -17300.0  tt1781935                                   The Ridges
# 1303     -15000.0  tt3973612                         Stories of Our Lives
# 1304      84596.0  tt1872026                                         Cure
# 1305      -1400.0  tt2107644                         A Plague So Pleasant
#
#       start_year                    genres  runtime_minutes      primary_name  \
# 0           2011                    Horror             93.0      Atsushi Wada
# 1           2011  Action,Adventure,Fantasy            136.0      Rob Marshall
# 2           2019   Action,Adventure,Sci-Fi            113.0     Simon Kinberg
# 3           2017  Action,Adventure,Fantasy            120.0       Zack Snyder
# 4           2013  Action,Adventure,Western            150.0    Gore Verbinski
# ...          ...                       ...              ...               ...
# 1301        2015      Crime,Drama,Thriller             90.0   Joseph Mazzella
# 1302        2011     Drama,Horror,Thriller             89.0   Brandon Landers
# 1303        2014                     Drama             60.0        Jim Chuchu
# 1304        2011                     Drama             93.0          Bill Yip
# 1305        2013     Drama,Horror,Thriller             76.0  Benjamin Roberds
#
#       person_id  averagerating  numvotes  category
# 0     nm3786927            6.1        43  director
# 1     nm0551128            6.6    447624  director
# 2     nm1334526            6.0     24451  director
# 3     nm0811583            6.5    329135  director
# 4     nm0893659            6.4    208827  director
# ...         ...            ...       ...       ...
# 1301  nm3556672            5.1        82  director
# 1302  nm4192760            2.9       127  director
# 1303  nm5874888            7.5        85  director
# 1304  nm0948107            4.9        11  director
# 1305  nm4766951            5.4        72  director
#
# [1306 rows x 18 columns]

# %%
df_sql_budgets_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1306 entries, 0 to 1305
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 1306 non-null   int64
#  1   release_date       1306 non-null   datetime64[ns]
#  2   movie              1306 non-null   object
#  3   production_budget  1306 non-null   float64
#  4   domestic_gross     1306 non-null   float64
#  5   worldwide_gross    1306 non-null   float64
#  6   profit             1306 non-null   float64
#  7   profit_dom         1306 non-null   float64
#  8   movie_id           1306 non-null   object
#  9   primary_title      1306 non-null   object
#  10  start_year         1306 non-null   int64
#  11  genres             1303 non-null   object
#  12  runtime_minutes    1259 non-null   float64
#  13  primary_name       1306 non-null   object
#  14  person_id          1306 non-null   object
#  15  averagerating      1306 non-null   float64
#  16  numvotes           1306 non-null   int64
#  17  category           1306 non-null   object
# dtypes: datetime64[ns](1), float64(7), int64(3), object(7)
# memory usage: 193.9+ KB

# %%
df_sql_budgets_db.genres.value_counts()
# Out:
# Drama                         132
# Documentary                    59
# Adventure,Animation,Comedy     56
# Comedy                         48
# Comedy,Drama                   46
#                              ...
# Action,Romance,Sport            1
# Crime,Fantasy,Thriller          1
# Comedy,Fantasy,Sci-Fi           1
# Horror,Romance,Thriller         1
# Horror,Music,Thriller           1
# Name: genres, Length: 244, dtype: int64

# %%
df_sql_budgets_db.primary_name.value_counts()
# Out:
# Tim Johnson            3
# Ross Whitaker          2
# Arshad Yusuf Pathan    2
# Jun Falkenstein        2
# Chad Zuver             2
#                       ..
# Trevor Wall            1
# Genndy Tartakovsky     1
# Mijke de Jong          1
# Jérôme Salle           1
# Kelly Fremon Craig     1
# Name: primary_name, Length: 1269, dtype: int64

# %%
ax2 = df_sql_budgets_db.plot.scatter(x='averagerating',
                    y='profit',
                    colormap='viridis')

# %%
df_sql_budtmdb_db =pd.merge(df_budg_tmdb,df_movie_db,how='inner',left_on='movie', right_on='primary_title')
df_sql_budtmdb_db
# Out:
#       id_x release_date_x                                        movie  \
# 0        1     2009-12-18                                       Avatar
# 1        2     2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2        9     2017-11-17                               Justice League
# 3       13     2013-07-02                              The Lone Ranger
# 4       14     2012-03-09                                  John Carter
# ...    ...            ...                                          ...
# 1206    38     2016-03-18                                       Krisha
# 1207    38     2016-03-18                                       Krisha
# 1208    45     2017-01-27                                        Emily
# 1209    49     2015-09-01                                       Exeter
# 1210    51     2015-04-21                                          Ten
#
#       production_budget  domestic_gross  worldwide_gross        profit  \
# 0           425000000.0     760507625.0     2.776345e+09  2.351345e+09
# 1           410600000.0     241063875.0     1.045664e+09  6.350639e+08
# 2           300000000.0     229024295.0     6.559452e+08  3.559452e+08
# 3           275000000.0      89302115.0     2.600021e+08 -1.499788e+07
# 4           275000000.0      73058679.0     2.827781e+08  7.778100e+06
# ...                 ...             ...              ...           ...
# 1206            30000.0        144822.0     1.448220e+05  1.148220e+05
# 1207            30000.0        144822.0     1.448220e+05  1.148220e+05
# 1208            27000.0          3547.0     3.547000e+03 -2.345300e+04
# 1209            25000.0             0.0     4.897920e+05  4.647920e+05
# 1210            25000.0             0.0     0.000000e+00 -2.500000e+04
#
#        profit_dom           genre_ids    id_y  ...   movie_id  \
# 0     335507625.0   [28, 12, 14, 878]   19995  ...  tt1775309
# 1    -169536125.0        [12, 28, 14]    1865  ...  tt1298650
# 2     -70975705.0   [28, 12, 14, 878]  141052  ...  tt0974015
# 3    -185697885.0        [28, 12, 37]   57201  ...  tt1210819
# 4    -201941321.0       [28, 12, 878]   49529  ...  tt0401729
# ...           ...                 ...     ...  ...        ...
# 1206     114822.0                [18]  259043  ...  tt4266638
# 1207     114822.0                [18]  323929  ...  tt4266638
# 1208     -23453.0                [18]  359406  ...  tt4393036
# 1209     -25000.0            [53, 27]  226458  ...  tt1945044
# 1210     -25000.0  [12, 27, 9648, 53]  279516  ...  tt2309562
#
#                                     primary_title  start_year  \
# 0                                          Avatar        2011
# 1     Pirates of the Caribbean: On Stranger Tides        2011
# 2                                  Justice League        2017
# 3                                 The Lone Ranger        2013
# 4                                     John Carter        2012
# ...                                           ...         ...
# 1206                                       Krisha        2015
# 1207                                       Krisha        2015
# 1208                                        Emily        2017
# 1209                                       Exeter        2015
# 1210                                          Ten        2013
#
#                         genres runtime_minutes        primary_name  person_id  \
# 0                       Horror            93.0        Atsushi Wada  nm3786927
# 1     Action,Adventure,Fantasy           136.0        Rob Marshall  nm0551128
# 2     Action,Adventure,Fantasy           120.0         Zack Snyder  nm0811583
# 3     Action,Adventure,Western           150.0      Gore Verbinski  nm0893659
# 4      Action,Adventure,Sci-Fi           132.0      Andrew Stanton  nm0004056
# ...                        ...             ...                 ...        ...
# 1206                     Drama            83.0  Trey Edward Shults  nm4099092
# 1207                     Drama            83.0  Trey Edward Shults  nm4099092
# 1208                     Drama            83.0         Ryan Graves  nm6254824
# 1209   Horror,Mystery,Thriller            91.0       Marcus Nispel  nm1197971
# 1210                     Drama           118.0        Craig Wyting  nm5188399
#
#      averagerating numvotes  category
# 0              6.1       43  director
# 1              6.6   447624  director
# 2              6.5   329135  director
# 3              6.4   208827  director
# 4              6.6   241792  director
# ...            ...      ...       ...
# 1206           7.2     5917  director
# 1207           7.2     5917  director
# 1208           6.8       13  director
# 1209           4.5     5156  director
# 1210           5.5       31  director
#
# [1211 rows x 27 columns]

# %%
ax2 = df_sql_budtmdb_db.plot.scatter(x='averagerating',
                    y='popularity',
                    colormap='viridis')
